# %%
import json
import openai

# %%
openai.api_key ='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'

# %%
prediction_dir='/home/donaldo9603/workspace/numeric/data/nq/500samples/r2d2/8512_nq_num_500_r2d2.json'

# %%
with open(prediction_dir) as f:
    pred=json.load(f)

# %% [markdown]
# ### R2D2

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.954
# 0.908

# %% [markdown]
# ### LLAMA zero

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.656
# 0.846

# %% [markdown]
# ### LLAMA-few

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.908
# 0.89

# %%
for d in pred:
    if d['insteval']!=d['insteval_few']:
        print(d['question'])
        print(d['prediction'])
        print(d['answer'])
        print(d['insteval'])
        print(d['insteval_few'])
        print(d['human'])
# Out:
# when does rick and morty play on tv
#  Adult Swim
# ['late-night']
# 1
# 0
# 0
# when is the opening ceremonies of the olympics 2018
#  February 9th
# ['9 February 2018']
# 0
# 1
# 1
# when was the cleveland browns last winning game
#  December 24, 2016
# ['2016']
# 1
# 0
# 1
# what is the share of agriculture in indian economy
#  17%
# ['17.32%', '23%']
# 1
# 0
# 1
# when did i'm like a bird come out
#  2000
# ['October 24, 2000']
# 1
# 0
# 1
# how old is baby in dirty dancing movie
#  Frances “Baby” Houseman
# ['17-year-old', '17']
# 1
# 0
# 0
# when did marathon change its name to snickers
#  1990
# ['19 July 1990']
# 1
# 0
# 1
# when was the last time new zealand had an earthquake
#  2016 Kaikoura earthquake
# ['11 Jul 2017']
# 1
# 0
# 0
# when do the walking dead comics come out
#  Every 4-6 weeks
# ['October 2003 - present', '2003']
# 1
# 0
# 0
# when do they put the rockefeller tree up
#  early November
# ['mid November', 'late November or early December']
# 0
# 1
# 0
# ...

# %% [markdown]
# ### Inst-zero

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.662
# 0.88

# %% [markdown]
# ### Inst-few

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.908
# 0.89

# %%
for d in pred:
    if d['insteval']!=d['insteval_few']:
        print(d['question'])
        print(d['prediction'])
        print(d['answer'])
        print(d['insteval'])
        print(d['insteval_few'])
        print(d['human'])
# Out:
# when does rick and morty play on tv
#  Adult Swim
# ['late-night']
# 1
# 0
# 0
# when is the opening ceremonies of the olympics 2018
#  February 9th
# ['9 February 2018']
# 0
# 1
# 1
# when was the cleveland browns last winning game
#  December 24, 2016
# ['2016']
# 1
# 0
# 1
# what is the share of agriculture in indian economy
#  17%
# ['17.32%', '23%']
# 1
# 0
# 1
# when did i'm like a bird come out
#  2000
# ['October 24, 2000']
# 1
# 0
# 1
# how old is baby in dirty dancing movie
#  Frances “Baby” Houseman
# ['17-year-old', '17']
# 1
# 0
# 0
# when did marathon change its name to snickers
#  1990
# ['19 July 1990']
# 1
# 0
# 1
# when was the last time new zealand had an earthquake
#  2016 Kaikoura earthquake
# ['11 Jul 2017']
# 1
# 0
# 0
# when do the walking dead comics come out
#  Every 4-6 weeks
# ['October 2003 - present', '2003']
# 1
# 0
# 0
# when do they put the rockefeller tree up
#  early November
# ['mid November', 'late November or early December']
# 0
# 1
# 0
# ...

# %% [markdown]
# ### EMDR

# %%
inst_zero=0
inst_few=0
for d in pred:
    if d['insteval']==d['human']:
        inst_zero+=1
    
    if d['insteval_few']==d['human']:
        inst_few+=1
print(inst_zero/len(pred))
print(inst_few/len(pred))
# Out:
# 0.924
# 0.904

# %% [markdown]
# ### InstGPTeval zero

# %%
for d in pred:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.".format(d['question'], answers, d['prediction'])
    response = openai.Completion.create(
                    model='text-davinci-003',
                        prompt=prompt,
                        temperature=0.7,
                        max_tokens=20,
                        top_p=1,
                        frequency_penalty=0.0,
                        presence_penalty=0.0)
    d['insteval']=response['choices'][0]['text']

# %%
print(pred[0])
# Out:
# {'question': 'what was the population of the roman empire at its height', 'answer': ['50 to 90\xa0million inhabitants', '70\xa0million', '55–60 million', 'an estimated 70\xa0million people'], 'ans_type': 'CARDINAL', 'prediction': '70 million people', 'human': 1, 'id': 3064, 'bs': 0.8264985084533691, 'bs_th': 1, 'em': False, 'f1': 0.8571428571428571, 'f1_th': 1, 'bem': 1, 'nem_ans': 1, 'nem_sen': 1, 'nem_integ': 1, 'emnem': 1, 'insteval': '\n\n1'}

# %%
for d in pred:
    if type(d['insteval'])==int:
        continue
    if 'Answer:' in str(d['insteval']):
        d['insteval']=d['insteval'].replace('Answer:', '')
    d['insteval']=d['insteval'].replace('\n', '')
    d['insteval']=d['insteval'].replace(' ', '')
    d['insteval']=int(d['insteval'])

# %%
for d in pred:
    if d['insteval']!=1 and d['insteval']!=0:
        print(d)

# %%
inst_hum=0
for d in pred:
    if (d['human'])==d['insteval']:
        inst_hum+=1
    if d['human']!=d['insteval']:
        print(d['question'])
        print(d['prediction'])
        print(d['answer'])
        print(d['ans_type'])
        print(d['human'])
        print(d['insteval'])
        print()  
print(inst_hum/len(pred))
# Out:
# when is the flash coming back after christmas
# 2018
# ['January\xa016,\xa02018']
# DATE
# 1
# 0
#
# what is the share of agriculture in indian economy
# 15.4%
# ['17.32%', '23%']
# PERCENT
# 0
# 1
#
# when do the walking dead comics come out
# monthly
# ['October\xa02003\xa0– present', '2003']
# DATE
# 0
# 1
#
# how tall is the actor who plays hagrid in harry potter
# Robbie Coltrane
# ['6ft 1in']
# QUANTITY
# 0
# 1
#
# when did france and belgium invade the ruhr
# between 1923 and 1925
# ['11 January 1923', 'January 1923', '1923']
# DATE
# 1
# 0
#
# when does the dlc for rainbow six siege come out
# post-launch
# ['January 2018']
# DATE
# 0
# 1
#
# when does the world cup of hockey start
# 28 November
# ['2020']
# DATE
# 0
# 1
#
# what do mobile numbers start with in the uk
# 077
# ['0']
# CARDINAL
# 1
# 0
#
# when does the next warrior book come out
# 2018
# ['April 10, 2018']
# DATE
# 1
# 0
#
# how many pitchers does a major league team have
# five
# ...

# %%
with open(prediction_dir, 'w') as f:
    json.dump(pred, f)

# %% [markdown]
# ### Few_shot

# %%
from tqdm import tqdm

# %%
for d in tqdm(pred):
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    if d['ans_type']=='DATE':
        prompt=few_shot_dic[d['ans_type']]+"Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n".format(d['question'], answers, d['prediction'])
        response = openai.Completion.create(
                        model='text-davinci-003',
                            prompt=prompt,
                            temperature=0.7,
                            max_tokens=20,
                            top_p=1,
                            frequency_penalty=0.0,
                            presence_penalty=0.0)
        d['insteval_few']=response['choices'][0]['text']
    else:
        continue
# Out:
#  14%|█▍        | 72/500 [00:15<01:27,  4.91it/s]

# %%
for d in pred:
    if type(d['insteval_few'])==int:
        continue
    if 'Answer:' in str(d['insteval_few']):
        d['insteval_few']=d['insteval_few'].replace('Answer:', '')
    d['insteval_few']=d['insteval_few'].replace('\n', '')
    d['insteval_few']=d['insteval_few'].replace(' ', '')
    d['insteval_few']=int(d['insteval_few'])

# %%
for d in pred:
    if d['insteval_few']!=1 and d['insteval_few']!=0:
        print(d)

# %%
inst_hum=0
for d in pred:
    if (d['human'])==d['insteval_few']:
        inst_hum+=1
    if d['human']!=d['insteval_few']:
        print(d['question'])
        print(d['prediction'])
        print(d['answer'])
        print(d['ans_type'])
        print(d['human'])
        print(d['insteval_few'])
        print()  
print(inst_hum/len(pred))

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/r2d2/8512_nq_num_500_r2d2_insteval_few_change.json', 'w') as f:
    json.dump(pred, f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/8508_nq_dev_num_500_llama2_few_insteval_few_change.json') as f:
    check=json.load(f)

# %%
inst_hum=0
for d in check:
    if (d['human'])==d['insteval_few']:
        inst_hum+=1
print(inst_hum/len(check))
# Out:
# 0.93

# %% [markdown]
# ### Few shot sampling

# %%
train_dir='/home/donaldo9603/workspace/numeric/data/ours/numeric_train.json'

# %%
with open(train_dir) as f:
    train=json.load(f)

# %%
train[0]
# Out:
# {'question': "when's the last time the eagles went to the playoffs",
#  'answer': ['2017'],
#  'ans_type': 'DATE',
#  'ans_pos': ['2017-01-01',
#   '01/01/2017',
#   'during 2017',
#   'in 2017',
#   'Jan 1 2017'],
#  'sen_pos': ['The Eagles went to the playoffs last in 2017'],
#  'ans_neg': ['2013',
#   '2012-01-01',
#   '227-2-2',
#   '267-6-6',
#   '6/6/267',
#   '4/4/247',
#   '01/01/2033',
#   'during 2015',
#   'in 2030',
#   'jun 1 2017',
#   'Jan 4 2047',
#   'Jan 1 2004']}

# %%
cnt=0
for d in train:
    pos_ans=[]
    negative_sen=[]
    pos_ans.extend(d['answer'])
    pos_ans.extend(d['ans_pos'])
    
    gold_in_sen=False
    
    # Find gold answer presentend in Positive sentence
    for idx, ans in enumerate(pos_ans):
        if ans in d['sen_pos'][0]:
            gold_in_sen=True
            gold_idx=idx
            gold_ans=ans
    
    if gold_in_sen:
        cnt+=1
        # Positive sentence extend
        for ans in (pos_ans):
            if gold_ans!=ans:
                d['sen_pos'].append(d['sen_pos'][0].replace(gold_ans, ans))
        
        # Negative sentence extend
        for ans in d['ans_neg']:
            negative_sen.append(d['sen_pos'][0].replace(gold_ans, ans))

        d['sen_neg']=negative_sen
print(cnt)
# Out:
# 2407

# %%
date=[d for d in train if d['ans_type']=="DATE"]
card=[d for d in train if d['ans_type']=="CARDINAL"]
time=[d for d in train if d['ans_type']=="TIME"]
quant=[d for d in train if d['ans_type']=="QUANTITY"]
perc=[d for d in train if d['ans_type']=="PERCENT"]
mon=[d for d in train if d['ans_type']=="MONEY"]

# %%
import random

# %%
date_ans_neg=[d for d in date if 'ans_neg' in d.keys()]
date_sen_neg=[d for d in date if 'sen_neg' in d.keys()]

card_ans_neg=[d for d in card if 'ans_neg' in d.keys()]
card_sen_neg=[d for d in card if 'sen_neg' in d.keys()]

time_ans_neg=[d for d in time if 'ans_neg' in d.keys()]
time_sen_neg=[d for d in time if 'sen_neg' in d.keys()]

quant_ans_neg=[d for d in quant if 'ans_neg' in d.keys()]
quant_sen_neg=[d for d in quant if 'sen_neg' in d.keys()]

perc_ans_neg=[d for d in perc if 'ans_neg' in d.keys()]
perc_sen_neg=[d for d in perc if 'sen_neg' in d.keys()]

mon_ans_neg=[d for d in mon if 'ans_neg' in d.keys()]
mon_sen_neg=[d for d in mon if 'sen_neg' in d.keys()]

# %%
random.seed(1001)

# %%
date_ans_pos=random.sample(date, 8)
date_sen_pos=random.sample(date, 2)
date_ans_neg=random.sample(date_ans_neg, 4)
date_sen_neg=random.sample(date_sen_neg, 2)

card_ans_pos=random.sample(card, 4)
card_sen_pos=random.sample(card, 4)
card_ans_neg=random.sample(card_ans_neg, 4)
card_sen_neg=random.sample(card_sen_neg, 4)

time_ans_pos=random.sample(time, 6)
time_sen_pos=random.sample(time, 2)
time_ans_neg=random.sample(time_ans_neg, 6)
time_sen_neg=random.sample(time_sen_neg, 2)

quant_ans_pos=random.sample(quant, 4)
quant_sen_pos=random.sample(quant, 4)
quant_ans_neg=random.sample(quant_ans_neg, 4)
quant_sen_neg=random.sample(quant_sen_neg, 4)

perc_ans_pos=random.sample(perc, 4)
perc_sen_pos=random.sample(perc, 4)
perc_ans_neg=random.sample(perc_ans_neg, 4)
perc_sen_neg=random.sample(perc_sen_neg, 4)

mon_ans_pos=random.sample(mon, 4)
mon_sen_pos=random.sample(mon, 4)
mon_ans_neg=random.sample(mon_ans_neg, 4)
mon_sen_neg=random.sample(mon_sen_neg, 4)

# %%
date_list=[]
for d in date_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    date_list.append(prompt)

for d in date_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    date_list.append(prompt)

for d in date_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    date_list.append(prompt)

for d in date_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    date_list.append(prompt)

# %%
card_list=[]
for d in card_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    card_list.append(prompt)

for d in card_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    card_list.append(prompt)

for d in card_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    card_list.append(prompt)

for d in card_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    card_list.append(prompt)

# %%
time_list=[]
for d in time_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    time_list.append(prompt)

for d in time_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    time_list.append(prompt)

for d in time_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    print(d)
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    time_list.append(prompt)

for d in time_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    time_list.append(prompt)
# Out:
# {'question': 'game of thrones season 1 episode 1 running time', 'answer': ['62 minutes'], 'ans_type': 'TIME', 'ans_pos': ['62 min', '1 hr 2 min', '1 hour and 2 minutes', 'one hour and two minutes'], 'sen_pos': ['The running time of Game of Thrones season 1 episode 1 is 62 minutes.', 'The running time of Game of Thrones season 1 episode 1 is 62 minutesutes.', 'The running time of Game of Thrones season 1 episode 1 is 1 hr 2 minutes.', 'The running time of Game of Thrones season 1 episode 1 is 1 hour and 2 minutesutes.', 'The running time of Game of Thrones season 1 episode 1 is one hour and two minutesutes.'], 'ans_neg': ['72 minutes', '64 min', '3 hr 2 min', '1 hr 6 min', '3 hour and 2 minutes', '1 hour and 1 minutes', 'zero hour and two minutes', 'one hour and thirteen minutes'], 'sen_neg': ['The running time of Game of Thrones season 1 episode 1 is 72 minutesutes.', 'The running time of Game of Thrones season 1 episode 1 is 64 minutes.', 'The running time of Game of Thrones season 
# ...

# %%
quant_list=[]
for d in quant_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    quant_list.append(prompt)

for d in quant_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    quant_list.append(prompt)

for d in quant_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    quant_list.append(prompt)

for d in quant_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    quant_list.append(prompt)

# %%
perc_list=[]
for d in perc_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    perc_list.append(prompt)

for d in perc_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    perc_list.append(prompt)

for d in perc_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    perc_list.append(prompt)

for d in perc_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    perc_list.append(prompt)

# %%
mon_list=[]
for d in mon_ans_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_pos'][0],str(1))
    mon_list.append(prompt)

for d in mon_sen_pos:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_pos'][0],str(1))
    mon_list.append(prompt)

for d in mon_ans_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['ans_neg'][0],str(0))
    mon_list.append(prompt)

for d in mon_sen_neg:
    answers=''
    for ans in d['answer']:
        answers+=ans+', '
    answers=answers[:-2]
    prompt="Question: {}\nAnswer: {}\nCandidate: {}\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n{}\n".format(d['question'], answers, d['sen_neg'][0],str(0))
    mon_list.append(prompt)

# %%
few_shot_dic={"DATE":"", "CARDINAL":"", "TIME":"", "QUANTITY":"", "PERCENT":"", "MONEY":""}

# %%
for d in random.sample(date,4):
    print(d)
# Out:
# {'question': 'how long was the russian war in afghanistan', 'answer': ['over nine years'], 'ans_type': 'DATE', 'ans_pos': ['1979-1989', '1979 to 1989', 'from 1979 to 1989', 'from 1979 till 1989', 'nine years and few months'], 'sen_pos': ['Russian War in Afghanistan lasted for over nine years - 1979-1989', 'Russian War in Afghanistan lasted for over nine years - over nine years', 'Russian War in Afghanistan lasted for over nine years - 1979 to 1989', 'Russian War in Afghanistan lasted for over nine years - from 1979 to 1989', 'Russian War in Afghanistan lasted for over nine years - from 1979 till 1989', 'Russian War in Afghanistan lasted for over nine years - nine years and few months'], 'ans_neg': ['1992-1989', '1979-1995', '1986 to 1989', '1979 to 1980', 'from 1960 to 1989', 'from 1979 to 1987', 'from 1998 till 1989', 'from 1979 till 1998'], 'sen_neg': ['Russian War in Afghanistan lasted for over nine years - 1992-1989', 'Russian War in Afghanistan lasted for over nine years - 1979-
# ...

# %%
date_list
# Out:
# ['Question: During what era was The Defence Research and Development Organisation founded?\nAnswer: From the 1950s to the 1970s\nCandidate: 1950s-70s\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n',
#  'Question: In which year was there a cover article on the National Geographic regarding diet recommendations?\nAnswer: 2005\nCandidate: in 2005\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n',
#  'Question: when did world war 2 become a world war\nAnswer: 1939\nCandidate: 1939-09-01\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n',
#  'Question: For how long does the fixed rate of tuition last?\nAnswer: 48 months\nCandidate: 4 years\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n',
#  "Question: thank god it's friday expression based casual restaurant\nAnswer: TGI Fridays\nCandidate: TGIF\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n",
# ...

# %%
date_list[-4]='Question: when did the first super mario come out\nAnswer: September 13, 1985\nCandidate: 1985\nPrint 1 if candidate is correct, print 0 if candidate is wrong.\n1\n'

# %%
date_few_shot=''
random.shuffle(date_list)
for d in date_list:
    date_few_shot+=d
few_shot_dic['DATE']=date_few_shot

# %%
card_few_shot=''
random.shuffle(card_list)
for d in card_list:
    card_few_shot+=d
few_shot_dic['CARDINAL']=card_few_shot

# %%
quant_few_shot=''
random.shuffle(quant_list)
for d in quant_list:
    quant_few_shot+=d
few_shot_dic['QUANTITY']=quant_few_shot

# %%
perc_few_shot=''
random.shuffle(perc_list)
for d in perc_list:
    perc_few_shot+=d
few_shot_dic['PERCENT']=perc_few_shot

# %%
time_few_shot=''
random.shuffle(time_list)
for d in time_list:
    time_few_shot+=d
few_shot_dic['TIME']=time_few_shot

# %%
mon_few_shot=''
random.shuffle(mon_list)
for d in mon_list:
    mon_few_shot+=d
few_shot_dic['MONEY']=mon_few_shot

# %%
print(few_shot_dic['DATE'])
# Out:
# Question: For how long does the fixed rate of tuition last?
# Answer: 48 months
# Candidate: Fixed rate of tuition lasts for 48 months or 4 years.
# Print 1 if candidate is correct, print 0 if candidate is wrong.
# 1
# Question: when was sergeant pepper released in the us
# Answer: 2 June 1967
# Candidate: Sergeant Pepper was released in the US on 4 June 1967
# Print 1 if candidate is correct, print 0 if candidate is wrong.
# 0
# Question: WHen was Black Wednesday?
# Answer: September 1992
# Candidate: Black Wednesday was in September 1992
# Print 1 if candidate is correct, print 0 if candidate is wrong.
# 1
# Question: when does the i phone 7 come out
# Answer: September 16, 2016
# Candidate: iPhone 7 was released in december 16, 2016
# Print 1 if candidate is correct, print 0 if candidate is wrong.
# 0
# Question: For how long does the fixed rate of tuition last?
# Answer: 48 months
# Candidate: 4 years
# Print 1 if candidate is correct, print 0 if candidate is wrong.
# 1
# ...
