# %%
import json
import jsonlines
import random

# %%
numeric_type=['CARDINAL', 'DATE', 'MONEY', 'PERCENT', 'QUANTITY', 'TIME']
nonnumeric_type=['EVENT',
 'FAC',
 'GPE',
 'LANGUAGE',
 'LAW',
 'LOC',
 'NORP',
 'ORG',
 'PERSON',
 'PRODUCT',
 'WORK_OF_ART']

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/original_nq_dev_anstype.json') as f:
    dev=json.load(f)

# %%
num=[]
non=[]
for d in dev:
    if d['ans_type'] in numeric_type:
        num.append(d)
    elif d['ans_type'] in nonnumeric_type:
        non.append(d)

# %%
print(len(num))
print(len(non))
# Out:
# 917
# 1818

# %% [markdown]
# ### Previous 150 samples

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/150samples/nq_num_150_zero_human_final.json') as f:
    num150=json.load(f)

# %%
id_question_dict={d['question']:d['id'] for d in num150}

# %%
id_question_dict
# Out:
# {'what was the population of the roman empire at its height': 3064,
#  'when does wonder woman come out on blue ray': 2900,
#  'when was the tower of london finished being built': 3587,
#  'how many times have the winter olympics been in the usa since 1924': 696,
#  'when will the la sagrada familia be finished': 3362,
#  'when did canada get rid of the death penalty': 318,
#  'when does rick and morty play on tv': 2065,
#  'when was the last time the seattle seahawks won the superbowl': 1396,
#  'how many grams of alcohol in one beer': 3008,
#  'when will the next episode of flash be aired': 556,
#  'where does the donkey talk in the bible': 1528,
#  'when does the new season of lost in space come out': 2772,
#  'when is the flash coming back after christmas': 1387,
#  'when did hollywood video go out of business': 2103,
#  'when is the opening ceremonies of the olympics 2018': 2394,
#  "when does season 13 of america's got talent premiere": 2946,
#  'when does season 8 of shameless come back': 1476,
#  'the atomic number of indium which belongs to 5th period is': 2967,
#  'when did the tv show the waltons first air': 2120,
#  'when did the smoking ban in public places start': 698,
#  'when does the good doctor episode 8 air': 2266,
#  'when was the cleveland browns last winning game': 3425,
#  'when is season 2 of jessica jones being released': 166,
#  'what is the share of agriculture in indian economy': 111,
#  'the old man and the sea page count': 2822,
#  'how many strong verbs are there in german': 2700,
#  "what's the nba record for most points in a half": 2856,
#  'when did where are you now come out': 1803,
#  "when did i'm like a bird come out": 2739,
#  'how old is baby in dirty dancing movie': 2682,
#  'when did krakow become the capital of poland': 2449,
#  'when was the peak to peak gondola built': 2280,
#  'when did the black death end in england': 3487,
#  'when is the end of the football season': 649,
#  'when did the song holiday road come out': 1854,
#  'when did world war one begin and end': 2810,
#  'when did the celebrities enter the big brother house': 2278,
#  'when was the first book made into a movie': 530,
#  'when did marathon change its name to snickers': 77,
#  'how many episodes in season 2 of fargo': 3527,
#  'when will miraculous ladybug season 2 episode 12 come out': 3416,
#  'when was the last time new zealand had an earthquake': 345,
#  'when did avatar the last airbender first air': 2349,
#  'when did the dust bowl end in oklahoma': 3541,
#  'when did they stop making the nissan xterra': 2596,
#  'when did seattle slew win the triple crown': 444,
#  'when did the golden state warriors win the finals': 342,
#  'when was the last time.michigan beat ohio state': 3577,
#  'when was the first ford f 150 made': 896,
#  'how many steps does the cn tower have': 1616,
#  'when was the first mad max movie release': 2217,
#  'when did mcgee became a regular on ncis': 278,
#  'when was nepal declared a secular state in bs': 2027,
#  'how many nfl teams has st louis had': 2067,
#  'when do the walking dead comics come out': 3041,
#  'how much venom can a king cobra produce': 1449,
#  'when did response to state of the union start': 316,
#  'how many ammendments to the constitution have there been': 1110,
#  'when did the continental congress vote to adopt the declaration of independence': 1291,
#  'how long did it take to build the great pyramid of egypt': 570,
#  'when do they put the rockefeller tree up': 1472,
#  'what year does the quiet man take place': 124,
#  'when did fortnite save the world first come out': 3454,
#  'what episode does goku give up against cell': 333,
#  'when was the last time tug-of-war was an official olympic sport': 3564,
#  'when was the first orca put in captivity': 741,
#  'what age do you need to be to buy a bb gun': 19,
#  'when does the team find out prentiss is alive': 1615,
#  'when did john hart play the lone ranger': 2153,
#  'how many times have real madrid won the european cup.in paris': 3226,
#  'when was theme from a summer place released': 2923,
#  'when did how you remind me come out': 1235,
#  'when does kc undercover season 3 episode 10 air': 708,
#  'when was the last time ny rangers won stanley cup': 3265,
#  'who does the democratic republic of congo trade with': 2949,
#  'how many dominoes do you need for mexican train': 3261,
#  'when was the debating club established in almora': 475,
#  "when did billy don't be a hero come out": 2017,
#  'when did all night long come out lionel richie': 1646,
#  "when did korn's follow the leader come out": 767,
#  'when did the jurassic park movies come out': 2126,
#  'what percentage of sunlight is captured by plants to convert it into food energy': 130,
#  'when was the last summer olympics in the usa': 3599,
#  'when did the revolution begin in the united states': 1375,
#  'how many seasons has greys anatomy been on tv': 3404,
#  'how many pennsylvania house of representatives are there': 628,
#  'what is small business tax rate in canada': 3231,
#  'how many customers does edf have in the uk': 392,
#  'when does the new season of are you the one come on': 2601,
#  'how long has tom brady been playing professional football': 1302,
#  'when did red dead redemption 1 come out': 1967,
#  'season 2 attack on titan how many episodes': 763,
#  'when did bird is the word come out': 135,
#  'how many co2 molecules are produced in aerobic respiration': 2284,
#  'what time can you legally buy alcohol in michigan': 3375,
#  'when did the nfl adopt a salary cap': 811,
#  'when did the ouija board first come out': 1917,
#  'when is season 4 of flash coming out': 2207,
#  'when did little polveir win the grand national': 1341,
#  'when is the womens ice skating for the olympics': 1715,
#  'when did toyota start making cars in the us': 85,
#  'how many points did lebron james scored in his career': 2793,
#  'when was to god be the glory written': 2526,
#  'when does wentworth season 6 start in australia': 2879,
#  'when does star trek discovery air on tv': 1679,
#  'what is the current population of bora bora': 182,
#  'how many countries are a part of opec': 2377,
#  'when did vat change from 17.5 to 20': 443,
#  'when was the first super bowl the eagles ever won': 524,
#  'when was harry potter and the philosophers stone published': 419,
#  'when did a wrinkle in time start filming': 2756,
#  'when was the original stephen king it movie made': 1733,
#  'when did the first pokemon game come out': 2399,
#  'when is the next step season 3 coming out': 951,
#  'when is if loving you is wrong coming back season 4': 916,
#  'when was the first nuclear power plant opened': 335,
#  'what is the angle of the tower of pisa': 110,
#  'how many hoops are used in a game of croquet': 781,
#  'how many national parks are present in india': 2965,
#  'how many seasons are there for lost girl': 397,
#  'when was the japanese videogame company nintendo founded': 1766,
#  'how long is a whale shark in meters': 710,
#  'when did season 4 of glee come out': 2068,
#  'when did one child policy end in china': 1927,
#  'when does the little couples new season start': 1379,
#  'when was the biltmore house opened to the public': 370,
#  'rizal finished all the chapters of the novel noli me tangere in': 245,
#  'when did harvard become an ivy league school': 2275,
#  'when did day light savings start in the us': 1209,
#  'what channel is abc on in phoenix arizona': 1969,
#  'when did the log flume closed at alton towers': 1156,
#  'when does the new death of superman come out': 3126,
#  'the chinese dragons are protectors of how many seas diggy': 108,
#  'when did the last volcano erupt in iceland': 2986,
#  'when did teenage mutant ninja turtles come out': 1709,
#  'when did slave to the rhythm come out': 888,
#  'when does the black panther movie soundtrack come out': 1214,
#  'when did hollywood become the centre of the film industry': 1783,
#  'when was the last time someone won the super bowl back to back': 1442,
#  'when did canada sign the un declaration of indigenous rights': 1101,
#  'when was the death penalty reinstated in oregon': 3458,
#  'when does south by southwest start in austin texas': 2023,
#  'when did the uk and us become allies': 1220,
#  "when's the last time scotland won the calcutta cup": 2689,
#  'love is not love that alters when it alteration finds meaning': 3234,
#  'when was the last time giants won superbowl': 339,
#  'how many indian astronauts have gone to space': 1129,
#  'when did the steel mills closed in youngstown ohio': 439,
#  'when was the abacus invented in ancient china': 2351,
#  "when did australia 2 win the america's cup": 2792}

# %%
num150[0]
# Out:
# {'question': 'what was the population of the roman empire at its height',
#  'answer': ['50 to 90\xa0million inhabitants',
#   '70\xa0million',
#   '55–60 million',
#   'an estimated 70\xa0million people'],
#  'ans_type': 'CARDINAL',
#  'prediction': '\n\nThe population of the Roman Empire at its height is estimated to have been between 50 and 80 million people.',
#  'human': 1}

# %%
for d in num150:
    d['id']=id_question_dict[d['question']]

# %%
num150_idx=[d['id'] for d in num150]

# %%
num=[d for d in num if d['id'] not in num150_idx]

# %%
len(num)
# Out:
# 767

# %%
nq_num_fewshot="""Answer the following question. [Question]: when did the us not go to the olympics [Answer]: The 1980 Summer Olympics
Answer the following question. [Question]: paul walkers cars in fast and furious list [Answer]: 1995 Toyota Supra
Answer the following question. [Question]: when did movies start coming out in color [Answer]: introduced around 1940
Answer the following question. [Question]: what is the population of st petersburg fl [Answer]: 260,999
Answer the following question. [Question]: how many tornado planes does the uk have [Answer]: 138
Answer the following question. [Question]: when was the land rover defender first built [Answer]: 1991
Answer the following question. [Question]: what percentage of the us population lives below the poverty line [Answer]: 13.5%
Answer the following question. [Question]: when did virgin australia (formerly virgin blue) commence flying in australia [Answer]: November 1999
Answer the following question. [Question]: when did the movie karate kid come out [Answer]: 2010
Answer the following question. [Question]: how much of the world's diamonds does de beers own [Answer]: 33% in 2013
Answer the following question. [Question]: how many episodes in my name is earl season 4 [Answer]: 27
Answer the following question. [Question]: what is the population of keystone heights florida [Answer]: 1,350
Answer the following question. [Question]: when did michael jordan get his last ring [Answer]: 1998
Answer the following question. [Question]: who discovered the atom and in what year [Answer]: early 1800s
Answer the following question. [Question]: when will the flash season 4 episode 14 coming out [Answer]: February 27, 2018
Answer the following question. [Question]: when's the last time philly won the superbowl [Answer]: 2017
Answer the following question. [Question]: when was 1 john 5 7 added to the bible [Answer]: the 9th century
Answer the following question. [Question]: how many episodes of season 5 of curse of oak island [Answer]: 18
Answer the following question. [Question]: how many episodes of greys anatomy season 14 [Answer]: 24
Answer the following question. [Question]: when are general elections held in the us [Answer]: every two to six years
Answer the following question. [Question]: how many hospitals are there in the united states [Answer]: 5,534 registered hospitals
Answer the following question. [Question]: los angeles stadium at hollywood park opening date [Answer]: 2020
Answer the following question. [Question]: what percentage of the earth's surface is water [Answer]: 78%
Answer the following question. [Question]: what is the minimum size of a udp datagram [Answer]: 8 bytes
Answer the following question. [Question]: what is the limit of resolution of the human eye in micrometers [Answer]: ~55-75 micrometers
Answer the following question. [Question]: when was the last time miss texas won miss america [Answer]: 1975
Answer the following question. [Question]: when did they start 3 pointers in basketball [Answer]: 1961
Answer the following question. [Question]: when did the first movie of harry potter come out [Answer]: 16 November 2001
Answer the following question. [Question]: royal society for the protection of birds number of members [Answer]: more than a million
Answer the following question. [Question]: how many nuclear power plants in washington state [Answer]: 3
Answer the following question. [Question]: when did the usa join world war one [Answer]: April 1917
Answer the following question. [Question]: when did the military plane crash in mississippi [Answer]: July 10, 2017
Answer the following question. [Question]: how many pieces in a terry's chocolate orange [Answer]: six
Answer the following question. [Question]: when was the first temple built in jerusalem [Answer]: the mid-10th century BCE
Answer the following question. [Question]: when was the first star wars film released [Answer]: 1977
Answer the following question. [Question]: when did world war 2 officially start and end [Answer]: 1939
Answer the following question. [Question]: when does walking dead season 8 second half start [Answer]: October 22, 2017
Answer the following question. [Question]: when was the young and the restless first aired [Answer]: March 26, 1973
Answer the following question. [Question]: when was the movie cool hand luke made [Answer]: 1967
Answer the following question. [Question]: when does it's a wonderful life comes on [Answer]: Christmas season
Answer the following question. [Question]: how many cracker barrels in the united states [Answer]: 639
Answer the following question. [Question]: when does madea's family funeral come out [Answer]: 2018
Answer the following question. [Question]: how many plane surfaces does a cylinder have [Answer]: two parallel planes
Answer the following question. [Question]: when did the age of new media began [Answer]: the 1980s
Answer the following question. [Question]: when did this season of american idol start [Answer]: March 11, 2018
Answer the following question. [Question]: when was the last time the ducks won the stanley cup [Answer]: (2006-07)
Answer the following question. [Question]: big bang theory season 11 how many episodes [Answer]: 14
Answer the following question. [Question]: when was the internet introduced to the public [Answer]: September 1993
Answer the following question. [Question]: what is the term of an official in the house of representatives [Answer]: two-year
Answer the following question. [Question]: when did the first wireless beats come out [Answer]: October 2012
Answer the following question. [Question]: when's the last time army won the army navy game [Answer]: 2017
Answer the following question. [Question]: when does season 6 of the next step start [Answer]: 2018
Answer the following question. [Question]: how many pages are in the book inside out and back again [Answer]: 263
Answer the following question. [Question]: ethiopia flight 961 crashes in to the sea [Answer]: 23 November 1996
Answer the following question. [Question]: when does the new mlp movie come out [Answer]: September 24, 2017
Answer the following question. [Question]: when was the last year the raiders won the superbowl [Answer]: 1983
Answer the following question. [Question]: when did the united states acquired puerto rico [Answer]: 1898
Answer the following question. [Question]: how many farmers are there in the usa [Answer]: 3.2 million
Answer the following question. [Question]: when was the last time university of michigan won a national championship [Answer]: 1997
Answer the following question. [Question]: when was the last time there was a school shooting in canada [Answer]: January 22, 2016
Answer the following question. [Question]: when did last podcast on the left start [Answer]: 2011
Answer the following question. [Question]: when was the abacus invented in ancient china [Answer]: 2nd century BC
Answer the following question. [Question]: when will the flash season 4 episode 17 come out [Answer]: April 10, 2018
Answer the following question. [Question]: when did hootie and the blowfish come out [Answer]: 2003"""

# %%
num=[d for d in num if d['question'] not in nq_num_fewshot]

# %%
len(num)
# Out:
# 707

# %%
random.seed(1001)

# %%
num=random.sample(num, 350)

# %%
num[-1]
# Out:
# {'id': 1623,
#  'question': 'who invented the printing press and what year',
#  'answer': ['circa 1439', 'Johannes Gutenberg'],
#  'ans_type': 'CARDINAL'}

# %%
for d in num150:
    del d['prediction']

# %%
num150.extend(num)

# %%
len(num150)
# Out:
# 500

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/nq_num_500_inst3.5_zero.json', 'w') as f:
    json.dump(num150, f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_800.json', 'w') as f:
    json.dump(num150, f)

# %% [markdown]
# ### Previous 150 non-numeric

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/150samples/nq_non_150_zero_human_final.json') as f:
    non150=json.load(f)

# %%
id_question_dict={d['question']:d['id'] for d in non150}

# %%
non150[0]
# Out:
# {'question': 'who is the head of the department of homeland security 2017',
#  'answer': ['Kirstjen Nielsen'],
#  'ans_type': 'PERSON',
#  'prediction': '\n\nThe head of the Department of Homeland Security (DHS) in 2017 is Kirstjen Nielsen.',
#  'human': 1}

# %%
for d in non150:
    d['id']=id_question_dict[d['question']]

# %%
non150_idx=[d['id'] for d in non150]
print(len(non150_idx))
# Out:
# 150

# %%
non_idx=[d['id'] for d in non]
for d in non150:
    if d['id'] not in non_idx:
        print(d)
# Out:
# {'id': 1982, 'question': 'who is the head of the department of homeland security 2017', 'answer': ['Kirstjen Nielsen'], 'ans_type': 'PERSON', 'prediction': 'kirstjen nielsen'}
# {'id': 740, 'question': 'who sang our god is an awesome god', 'answer': ['Rich Mullins'], 'ans_type': 'PERSON', 'prediction': 'rich mullins'}
# {'id': 294, 'question': 'who sang rip it up and start again', 'answer': ['Scottish post-punk band Orange Juice', 'Orange Juice'], 'ans_type': 'NORP', 'prediction': 'scottish post - punk band orange juice'}
# {'id': 3015, 'question': 'who made the first to record with the electric guitar', 'answer': ['George Warren Barnes'], 'ans_type': 'PERSON', 'prediction': 'charlie christian'}
# {'id': 868, 'question': 'who plays the beast on the new beauty and the beast', 'answer': ['Dan Stevens'], 'ans_type': 'PERSON', 'prediction': 'dan stevens'}
# {'id': 3068, 'question': 'who were the first kings to issue coins bearing their names', 'answer': ['the Indo-Greek kings'], 'ans_type': 'NORP', 'prediction': 'offa of mercia'}
# {'id': 1004, 'question': 'who has scored the most tries in rugby union', 'answer': ['Daisuke Ohata'], 'ans_type': 'PERSON', 'prediction': 'daisuke ohata'}
# {'id': 2176, 'question': 'who sang never gonna let you go', 'answer': ['Joe Pizzulo and Leeza Miller', 'Joe Pizzulo', 'Leeza Miller'], 'ans_type': 'PERSON', 'prediction': 'tina moore'}
# {'id': 3448, 'question': 'days of our lives cast doug and julie', 'answer': ['Susan Seaforth Hayes', 'Susan Seaforth', 'Bill Hayes'], 'ans_type': 'PERSON', 'prediction': 'bill hayes'}
# {'id': 3392, 'question': 'who does the music for shimmer and shine', 'answer': ['Bobby Tahouri', 'Joachim Svare', 'Joleen Belle', 'Melanie Fontana'], 'ans_type': 'PERSON', 'prediction': 'bobby tahouri'}
# {'id': 1208, 'question': 'who wrote the theme to last of the mohicans', 'answer': ['Dougie MacLean'], 'ans_type': 'PERSON', 'prediction': 'dougie maclean'}
# {'id': 250, 'question': 'who plays timon in lion king on broadway', 'answer': ['Max Casella'], 'ans_type': 'PERSON', 'prediction': 'max casella'}
# {'id': 450, 'question': 'who wrote lyrics for phantom of the opera', 'answer': ['Charles Hart', 'Charles Hart and Richard Stilgoe', 'Richard Stilgoe'], 'ans_type': 'PERSON', 'prediction': 'richard stilgoe'}
# {'id': 461, 'question': 'who is jojo in horton hears a who', 'answer': ['Jesse McCartney'], 'ans_type': 'PERSON', 'prediction': 'jesse mccartney'}
# {'id': 3540, 'question': "who played sonny in lemony snicket's a series of unfortunate events", 'answer': ['Presley Smith'], 'ans_type': 'PERSON', 'prediction': 'patrick breen'}
# {'id': 388, 'question': 'who did puerto rico belong to before the u.s', 'answer': ['Taino', 'indigenous Taino people', 'Spain'], 'ans_type': 'NORP', 'prediction': 'spain'}
# {'id': 3379, 'question': 'what is the shannara chronicles season 2 based on', 'answer': ['The Sword of Shannara Trilogy'], 'ans_type': 'WORK_OF_ART', 'prediction': 'the sword of shannara'}
# {'id': 347, 'question': 'who played gino in a place to call home', 'answer': ['Aldo Mignone'], 'ans_type': 'PERSON', 'prediction': 'aldo mignone'}
# {'id': 3394, 'question': 'how do you spell padawan from star wars', 'answer': ['Padawan'], 'ans_type': 'PERSON', 'prediction': 'learner'}
# {'id': 2829, 'question': "who wrote ain't living long like this", 'answer': ['Rodney Crowell'], 'ans_type': 'PERSON', 'prediction': 'rodney crowell'}
# {'id': 982, 'question': 'a town in west yorkshire on the river aire home to a rugby league team', 'answer': ['Castleford'], 'ans_type': 'PERSON', 'prediction': 'castleford'}
# {'id': 2599, 'question': 'who sang theme song for dukes of hazard', 'answer': ['Waylon Jennings'], 'ans_type': 'PERSON', 'prediction': 'waylon jennings'}
# {'id': 3485, 'question': 'who won nfl football coach of the year', 'answer': ['Sean McVay'], 'ans_type': 'PERSON', 'prediction': 'sean mcvay'}
# {'id': 254, 'question': 'what languages are spoken in india the most', 'answer': ['Bengali', 'Telugu', 'Marathi', 'Hindi', 'English'], 'ans_type': 'NORP', 'prediction': 'hindi'}
# {'id': 819, 'question': 'who plays peter in what we do in the shadows', 'answer': ['Ben Fransham'], 'ans_type': 'PERSON', 'prediction': 'matt berry'}
# {'id': 2005, 'question': "who won season 8 of america's next top model", 'answer': ['Jaslene Gonzalez'], 'ans_type': 'PERSON', 'prediction': 'jaslene gonzalez'}
# {'id': 1847, 'question': "who plays elsa's aunt in once upon a time", 'answer': ['Elizabeth Mitchell'], 'ans_type': 'PERSON', 'prediction': 'elizabeth mitchell'}
# {'id': 1602, 'question': 'who plays dr. sloan on kevin saves the world', 'answer': ['Richard Masur'], 'ans_type': 'PERSON', 'prediction': 'richard masur'}
# {'id': 2071, 'question': 'who were the major countries involved in the cold war', 'answer': ['the Soviet Union', 'the United States'], 'ans_type': 'GPE', 'prediction': 'united states'}
# {'id': 2254, 'question': 'delhi is on the banks of which river', 'answer': ['Yamuna'], 'ans_type': 'LOC', 'prediction': 'yamuna'}
# {'id': 3415, 'question': 'in which regions are most of africa petroleum and natural gas found', 'answer': ['Nigeria'], 'ans_type': 'GPE', 'prediction': 'north africa'}
# {'id': 501, 'question': 'animals that are active at dawn and dusk', 'answer': ['Crepuscular', 'crepuscular', 'Crepuscular animals'], 'ans_type': 'ORG', 'prediction': 'crepuscular'}
# {'id': 1830, 'question': 'where is salt mined in the united states', 'answer': ['Avery Island, Louisiana', 'Houston, Texas', 'Avery Island', 'Saltville, Virginia', 'Central New York', 'Hutchinson, Kansas', 'Syracuse', 'Grand Saline in East Texas', 'Detroit, Michigan', 'Western New York'], 'ans_type': 'LOC', 'prediction': 'great salt lake, utah'}
# {'id': 239, 'question': 'who wrote the french declaration of the rights of man and of the citizen', 'answer': ['General Lafayette', 'Honore Mirabeau', 'Lafayette', 'Thomas Jefferson'], 'ans_type': 'PERSON', 'prediction': 'honore mirabeau'}
# {'id': 845, 'question': 'who wrote the first declaration of human rights', 'answer': ['Cyrus'], 'ans_type': 'PERSON', 'prediction': 'rene cassin'}
# {'id': 3482, 'question': 'where does the water come from to fill lake eyre', 'answer': ['Warburton River'], 'ans_type': 'LOC', 'prediction': 'warburton river'}
# {'id': 1321, 'question': 'who sponsored the phoenix open before waste management', 'answer': ['Friedman Billings Ramsey'], 'ans_type': 'PERSON', 'prediction': 'friedman billings ramsey'}
# {'id': 3058, 'question': 'gestational sac and yolk sac but no baby at 7 weeks', 'answer': ['an anembryonic gestation'], 'ans_type': 'ORG', 'prediction': 'blighted ovum'}
# {'id': 2069, 'question': 'who sings i want to dance with you', 'answer': ['George Strait'], 'ans_type': 'PERSON', 'prediction': "daniel o'donnell"}
# {'id': 1970, 'question': 'where does the brazos river start and stop', 'answer': ['Gulf of Mexico', 'Llano Estacado'], 'ans_type': 'ORG', 'prediction': 'gulf of mexico'}
# {'id': 145, 'question': 'who is the real killer in basic instinct 2', 'answer': ['Catherine Tramell'], 'ans_type': 'PERSON', 'prediction': 'catherine tramell'}
# {'id': 2586, 'question': 'what is the name of the chief justice of ghana', 'answer': ['Sophia Akuffo'], 'ans_type': 'PERSON', 'prediction': 'sophia akuffo'}
# {'id': 3396, 'question': 'who is the minister of youth in namibia', 'answer': ['Erastus Utoni'], 'ans_type': 'PERSON', 'prediction': 'erastus uutoni'}
# {'id': 3124, 'question': 'who performed the halftime show at super bowl 51', 'answer': ['Lady Gaga'], 'ans_type': 'PERSON', 'prediction': 'lady gaga'}
# {'id': 257, 'question': 'what was the real name of saudi arabia', 'answer': ['the Saudi Arab kingdom'], 'ans_type': 'NORP', 'prediction': 'kingdom of saudi arabia'}
# {'id': 252, 'question': 'most passing yards in nfl history in a game', 'answer': ['Norm Van Brocklin', '554'], 'ans_type': 'PERSON', 'prediction': '505'}
# {'id': 1800, 'question': 'where was the movie jeremiah johnson filmed at', 'answer': ['Utah'], 'ans_type': 'GPE', 'prediction': 'utah'}
# {'id': 960, 'question': 'who is the highest paid baseball player in the major leagues', 'answer': ['Clayton Kershaw', 'Alex Rodriguez'], 'ans_type': 'PERSON', 'prediction': 'clayton kershaw'}
# {'id': 823, 'question': "who wrote there's a guy works down the chip shop lyrics", 'answer': ['Philip Rambow', 'Kirsty MacColl/Philip Rambow', 'Kirsty MacColl'], 'ans_type': 'PERSON', 'prediction': 'hasse olsson'}
# {'id': 2807, 'question': 'who has become the new chairman of sebi', 'answer': ['Ajay Tyagi'], 'ans_type': 'PERSON', 'prediction': 'ajay tyagi'}
# {'id': 2938, 'question': 'who wrote hallelujah i just love her so', 'answer': ['Ray Charles'], 'ans_type': 'PERSON', 'prediction': 'ray charles'}
# {'id': 2538, 'question': 'who developed the first printing press in 1430s', 'answer': ['Johannes Gutenberg'], 'ans_type': 'PERSON', 'prediction': 'johannes gutenberg'}
# {'id': 2562, 'question': 'who sang the song with reba does he love you', 'answer': ['Linda Davis'], 'ans_type': 'PERSON', 'prediction': 'linda kaye davis'}
# {'id': 1770, 'question': 'when did indoor toilets become common in america', 'answer': ['After World War I'], 'ans_type': 'EVENT', 'prediction': 'by 1890'}
# {'id': 617, 'question': 'who played gareth in four weddings and a funeral', 'answer': ['Simon Callow'], 'ans_type': 'PERSON', 'prediction': 'rowan atkinson'}
# {'id': 578, 'question': 'who was the girl in the video brenda got a baby', 'answer': ['Ethel "Edy" Proctor'], 'ans_type': 'PERSON', 'prediction': "ethel ` ` edy'' proctor"}
# {'id': 2359, 'question': 'who was the actor who played grizzly adams', 'answer': ['"Dan" Haggerty'], 'ans_type': 'PERSON', 'prediction': 'daniel francis haggerty'}
# {'id': 1320, 'question': 'turkish finnish and hungarian belong to which family of languages', 'answer': ['Uralic languages'], 'ans_type': 'NORP', 'prediction': 'uralic languages'}
# {'id': 1119, 'question': 'who holds the record for most everest summits', 'answer': ['Kami Rita', 'Phurba Tashi Sherpa', 'Apa Sherpa', 'Phurba Tashi', 'Kami Rita Sherpa'], 'ans_type': 'GPE', 'prediction': 'kami rita sherpa'}
# {'id': 2894, 'question': "the world's tallest jain statue is located in which state of india", 'answer': ['Maharashtra'], 'ans_type': 'NORP', 'prediction': 'maharashtra'}
# {'id': 2430, 'question': 'country with most olympic gold medals all time', 'answer': ['United States'], 'ans_type': 'GPE', 'prediction': 'united states'}
# {'id': 1197, 'question': 'who is given credit for inventing the aqua lung', 'answer': ['Jacques Cousteau', 'engineer Emile Gagnan', 'Emile Gagnan'], 'ans_type': 'PERSON', 'prediction': 'emile gagnan'}
# {'id': 1785, 'question': 'who brought the idea of castles to england', 'answer': ['Norman invaders'], 'ans_type': 'PERSON', 'prediction': 'edward the confessor'}
# {'id': 2485, 'question': 'who sings i just want to use your love tonight', 'answer': ['English rock band the Outfield'], 'ans_type': 'NORP', 'prediction': 'elvis presley'}
# {'id': 306, 'question': 'who is tinker air force base named after', 'answer': ['Major General Clarence L. Tinker'], 'ans_type': 'PERSON', 'prediction': 'major general clarence tinker'}
# {'id': 3083, 'question': 'where was the movie the glass castle filmed', 'answer': ['in Welch, West Virginia', 'Welch, West Virginia'], 'ans_type': 'GPE', 'prediction': 'welch, west virginia'}
# {'id': 1911, 'question': 'who is the girl that died in eyes wide shut', 'answer': ['Mandy'], 'ans_type': 'PERSON', 'prediction': 'mandy'}
# {'id': 482, 'question': 'who won the award for best goalkeeper in football world cup 2006', 'answer': ['Gianluigi Buffon'], 'ans_type': 'PERSON', 'prediction': 'gianluigi buffon'}
# {'id': 1014, 'question': 'who has won the most united states championships', 'answer': ['Lex Luger', 'Ric Flair'], 'ans_type': 'PERSON', 'prediction': 'bill tilden'}
# {'id': 1141, 'question': 'who is the current cruiserweight champion in wwe', 'answer': ['Cedric Alexander', 'Cedric Alexander,'], 'ans_type': 'PERSON', 'prediction': 'buddy murphy'}
# {'id': 3497, 'question': 'where are they building the new raiders stadium', 'answer': ['Paradise, Nevada', 'in Paradise, Nevada'], 'ans_type': 'GPE', 'prediction': 'paradise, nevada'}
# {'id': 1632, 'question': "who sings the song you'll never find another love like mine", 'answer': ['Lou Rawls'], 'ans_type': 'PERSON', 'prediction': 'lou rawls'}
# {'id': 2817, 'question': 'who introduced the first chrismas tree to the uk', 'answer': ['Charlotte of Mecklenburg-Strelitz'], 'ans_type': 'GPE', 'prediction': 'charlotte of mecklenburg - strelitz'}
# {'id': 1846, 'question': 'who owned the colts when they left baltimore', 'answer': ['Robert Irsay', 'Irsay'], 'ans_type': 'PERSON', 'prediction': 'robert irsay'}
# {'id': 117, 'question': 'who does stefan marry in the vampire diaries', 'answer': ['Caroline Forbes'], 'ans_type': 'PERSON', 'prediction': 'caroline forbes'}
# {'id': 3549, 'question': 'tujhe dekha toh yeh jana sanam movie name', 'answer': ['Dilwale Dulhania Le Jayenge'], 'ans_type': 'PERSON', 'prediction': 'sanam re', 'human': 0}
# {'id': 686, 'question': 'who came out first batman or spider man', 'answer': ['Batman', 'Superman'], 'ans_type': 'WORK_OF_ART', 'prediction': 'batman', 'human': 1}
# {'id': 1747, 'question': 'ajay devgan preity zinta and madhuri dixit movie', 'answer': ['Yeh Raaste Hain Pyaar Ke'], 'ans_type': 'PERSON', 'prediction': 'yeh raaste hain pyaar ke', 'human': 1}
# {'id': 512, 'question': 'who were the members of the traveling wilburys group', 'answer': ['Roy Orbison', 'Jeff Lynne', 'George Harrison', 'Bob Dylan', 'Tom Petty'], 'ans_type': 'PERSON', 'prediction': 'tom petty', 'human': 1}
# {'id': 1868, 'question': 'who is considered the father of modern behaviorism', 'answer': ['John B. Watson'], 'ans_type': 'PERSON', 'prediction': 'john b. watson', 'human': 1}
# {'id': 2053, 'question': 'who conducted the opening concert at carnegie hall', 'answer': ['Pyotr Ilyich Tchaikovsky', 'maestro Walter Damrosch', 'Walter Damrosch'], 'ans_type': 'PERSON', 'prediction': 'walter and russian composer piotr ilyich tchaikovsky', 'human': 0}
# {'id': 1059, 'question': 'which state is the richest state in nigeria', 'answer': ['Lagos State'], 'ans_type': 'GPE', 'prediction': 'ugbo', 'human': 0}
# {'id': 2686, 'question': 'who was the first baseball player to be featured on a postage stamp', 'answer': ['Jackie Robinson'], 'ans_type': 'PERSON', 'prediction': 'mickey mantle', 'human': 0}
# {'id': 862, 'question': 'who sings why does it hurt when i pee', 'answer': ['Frank Zappa', "Frank Zappa's"], 'ans_type': 'PERSON', 'prediction': 'frank zappa', 'human': 1}
# {'id': 402, 'question': 'who was elected president in mexico in 2000', 'answer': ['Vicente Fox'], 'ans_type': 'PERSON', 'prediction': 'vicente fox quesada', 'human': 1}
# {'id': 3436, 'question': 'where does sex and the city take place', 'answer': ['New York City'], 'ans_type': 'GPE', 'prediction': 'new york city', 'human': 1}
# {'id': 2529, 'question': 'who played skeletor in the movie masters of the universe', 'answer': ['Frank Langella'], 'ans_type': 'PERSON', 'prediction': 'frank langella', 'human': 1}
# {'id': 2016, 'question': 'who does the voice of the gorilla in the movie sing', 'answer': ['Taron Egerton'], 'ans_type': 'PERSON', 'prediction': 'matthew mcconaughey', 'human': 0}
# {'id': 2367, 'question': 'who sang raindrops keep fallin on my head', 'answer': ['B. J. Thomas'], 'ans_type': 'PERSON', 'prediction': 'b. j. thomas', 'human': 1}
# {'id': 1461, 'question': 'who plays justin on the haves and the have nots', 'answer': ['Nicholas James'], 'ans_type': 'PERSON', 'prediction': 'nicholas james', 'human': 1}
# {'id': 3500, 'question': 'the actual name of the confederate force at gettysburg was', 'answer': ['Confederate States Army'], 'ans_type': 'ORG', 'prediction': 'robert e. lee', 'human': 0}
# {'id': 2146, 'question': "german word for pleasure from someone else's pain", 'answer': ['Schadenfreude'], 'ans_type': 'ORG', 'prediction': 'schadenfreude', 'human': 1}
# {'id': 3024, 'question': 'who plays the voice of chucky in seed of chucky', 'answer': ['Brad Dourif'], 'ans_type': 'PERSON', 'prediction': 'brad dourif', 'human': 1}
# {'id': 2060, 'question': 'who owns spirit of the suwannee music park', 'answer': ['The Cornett family'], 'ans_type': 'PERSON', 'prediction': 'the cornett family', 'human': 1}
# {'id': 1905, 'question': 'where was the witch of blackbird pond published', 'answer': ['United States', '1958', 'Houghton Mifflin'], 'ans_type': 'GPE', 'prediction': 'united states', 'human': 1}
# {'id': 1852, 'question': 'where did they get the tree for rockefeller center', 'answer': ['State College, PA'], 'ans_type': 'ORG', 'prediction': 'upstate new york', 'human': 0}
# {'id': 681, 'question': 'who plays jack in battle of the sexes', 'answer': ['Bill Pullman', '(Bill Pullman'], 'ans_type': 'PERSON', 'prediction': 'bill pullman', 'human': 1}
# {'id': 2011, 'question': 'list of strict nature reserve in the philippines', 'answer': ['Palawan', 'Lake Malimanga', 'Olango Island', 'Calauit Safari Park', 'Lake Buluan', 'Calavite and FB Harrison'], 'ans_type': 'GPE', 'prediction': 'mount hamiguitan range wildlife sanctuary', 'human': 0}
# {'id': 647, 'question': 'how did the dominican republic get its name', 'answer': ['patron saint, Saint Dominic'], 'ans_type': 'PERSON', 'prediction': 'the spanish island', 'human': 0}
# {'id': 785, 'question': 'who was elected senator of illinois in 1858', 'answer': ['Stephen A. Douglas'], 'ans_type': 'PERSON', 'prediction': 'stephen a. douglas', 'human': 1}
# {'id': 2123, 'question': 'when was the statue of liberty in france built', 'answer': ['Paris'], 'ans_type': 'GPE', 'prediction': 'july 1884', 'human': 0}
# {'id': 622, 'question': 'what book of the bible is the song of solomon in', 'answer': ['Song of Solomon', 'Song of Songs'], 'ans_type': 'GPE', 'prediction': 'old testament', 'human': 0}
# {'id': 1117, 'question': 'who are considered to be the founding fathers', 'answer': ['George Washington', 'Benjamin Franklin', 'John Adams', 'Alexander Hamilton', 'John Jay', 'James Madison', 'Thomas Jefferson'], 'ans_type': 'PERSON', 'prediction': 'john jay', 'human': 1}
# {'id': 61, 'question': 'who are nominated for president of india 2017', 'answer': ['Meira Kumar', 'Ram Nath Kovind'], 'ans_type': 'PERSON', 'prediction': 'ram nath kovind', 'human': 1}
# {'id': 3522, 'question': 'who is the leader of the ontario pc party', 'answer': ['Patrick Brown', 'Patrick Walter Brown MPP', 'Patrick Walter Brown'], 'ans_type': 'PERSON', 'prediction': 'doug ford', 'human': 0}
# {'id': 1042, 'question': 'who wrote the song mary had a little lamb', 'answer': ['John Roulstone', 'Sarah Josepha Hale'], 'ans_type': 'PERSON', 'prediction': 'sarah josepha hale', 'human': 1}
# {'id': 1539, 'question': 'who in germany signed the treaty of versailles', 'answer': ['Gustav Bauer', 'colonial minister Johannes Bell', 'Foreign minister Hermann Muller'], 'ans_type': 'PERSON', 'prediction': 'foreign minister hermann muller', 'human': 1}
# {'id': 2764, 'question': 'where are the winter olympic games being held this year', 'answer': ['Pyeongchang County, South Korea'], 'ans_type': 'GPE', 'prediction': 'pyeongchang county, south korea', 'human': 1}
# {'id': 3296, 'question': 'where did they film the show the crossing', 'answer': ['British Columbia, Canada'], 'ans_type': 'GPE', 'prediction': 'britannia beach', 'human': 0}
# {'id': 3356, 'question': 'who designed the first toy released by nintendo', 'answer': ['Gunpei Yokoi', 'Fusajiro Yamauchi'], 'ans_type': 'PERSON', 'prediction': 'gunpei yokoi', 'human': 1}
# {'id': 10, 'question': 'which state is located in the centre of india', 'answer': ['Chhattisgarh', 'Madhya Pradesh'], 'ans_type': 'LOC', 'prediction': 'madhya pradesh', 'human': 1}
# {'id': 3463, 'question': 'what is the longest pier in the uk', 'answer': ['Southend Pier'], 'ans_type': 'FAC', 'prediction': 'southend pier', 'human': 1}
# {'id': 488, 'question': 'who has been appointed as the election commissioner of india', 'answer': ['Om Prakash Rawat'], 'ans_type': 'PERSON', 'prediction': 'om prakash rawat', 'human': 1}
# {'id': 2419, 'question': 'which is the first private medical college in kerala', 'answer': ['Government Medical College, Thiruvananthapuram', '1998'], 'ans_type': 'ORG', 'prediction': 'government medical college, thiruvananthapuram', 'human': 1}
# {'id': 3393, 'question': 'who starred in the film far from the madding crowd', 'answer': ['Juno Temple', 'Carey Mulligan', 'Tom Sturridge', 'Matthias Schoenaerts', 'Michael Sheen'], 'ans_type': 'PRODUCT', 'prediction': 'juno temple', 'human': 1}
# {'id': 2650, 'question': 'who won the 7 man elimination chamber match', 'answer': ['Roman Reigns'], 'ans_type': 'PERSON', 'prediction': 'roman reigns', 'human': 1}
# {'id': 2134, 'question': 'who developed a set of postulates to prove that specific microorganisms cause disease', 'answer': ['Robert Koch', 'Friedrich Loeffler'], 'ans_type': 'PERSON', 'prediction': 'robert koch', 'human': 1}
# {'id': 1801, 'question': 'where does a wrinkle in time take place', 'answer': ['Connecticut'], 'ans_type': 'GPE', 'prediction': 'earth', 'human': 0}
# {'id': 1206, 'question': 'who took over the dutch colony in north america', 'answer': ['England', 'English'], 'ans_type': 'GPE', 'prediction': 'england', 'human': 1}
# {'id': 3606, 'question': 'what college does everyone in gossip girl go to', 'answer': ['New York University', 'Columbia University'], 'ans_type': 'ORG', 'prediction': 'new york university', 'human': 1}
# {'id': 2381, 'question': 'who plays max voice in a goofy movie', 'answer': ['Jason Marsden'], 'ans_type': 'PERSON', 'prediction': 'jason marsden', 'human': 1}
# {'id': 1002, 'question': 'who was the person who escaped from alcatraz', 'answer': ['Clarence Anglin', 'John Anglin', 'Frank Morris'], 'ans_type': 'PERSON', 'prediction': 'john anglin', 'human': 1}
# {'id': 1478, 'question': 'who scored the most points in their nba career', 'answer': ['Kareem Abdul-Jabbar'], 'ans_type': 'PERSON', 'prediction': 'kareem abdul - jabbar', 'human': 1}
# {'id': 329, 'question': 'who played the creature on jeepers creepers 3', 'answer': ['Jonathan Breck'], 'ans_type': 'PERSON', 'prediction': 'jonathan breck', 'human': 1}
# {'id': 2197, 'question': 'who is the original singer of just when i needed you most', 'answer': ['Randy VanWarmer'], 'ans_type': 'PERSON', 'prediction': 'randy vanwarmer', 'human': 1}
# {'id': 25, 'question': 'when was the first australian prime minister elected', 'answer': ['Sir Edmund Barton', '1901'], 'ans_type': 'PERSON', 'prediction': '1901', 'human': 1}
# {'id': 3477, 'question': 'who are the nbc olympic ice skating commentators', 'answer': ['Jonny Moseley', 'Tanith White', 'Chris Vosters', 'Luke Van Valin', 'Charlie White', 'Johnny Weir', 'Tara Lipinski', 'Andrea Joyce', 'Terry Gannon'], 'ans_type': 'PERSON', 'prediction': 'tara lipinski', 'human': 1}
# {'id': 1244, 'question': "who wrote the song oh lord won't you buy me a mercedes benz", 'answer': ['Janis Joplin', 'Bob Neuwirth', 'Michael McClure'], 'ans_type': 'PERSON', 'prediction': 'michael mcclure', 'human': 1}
# {'id': 1984, 'question': 'what part of dc is howard university in', 'answer': ['in northwest Washington', 'northwest', 'northwest Washington'], 'ans_type': 'GPE', 'prediction': 'northwest washington, dc', 'human': 1}
# {'id': 2858, 'question': 'who owns and operates the panama canal today', 'answer': ['Panama Canal Authority', 'Panamanian government', 'Panama'], 'ans_type': 'ORG', 'prediction': 'panama canal authority', 'human': 1}
# {'id': 2773, 'question': 'where are the organ mountains in new mexico', 'answer': ['southern New Mexico'], 'ans_type': 'GPE', 'prediction': 'dona ana county', 'human': 0}
# {'id': 3596, 'question': 'what mall did they use in back to the future', 'answer': ['Puente Hills Mall'], 'ans_type': 'GPE', 'prediction': 'puente hills mall', 'human': 1}
# {'id': 1780, 'question': 'who plays the dad in drake and josh', 'answer': ['Jonathan Goldstein'], 'ans_type': 'PERSON', 'prediction': 'jonathan goldstein', 'human': 1}
# {'id': 738, 'question': 'the cast of a good day to die hard', 'answer': ['Mary Elizabeth Winstead', 'Sebastian Koch', 'Radivoje Bukvic', 'Jai Courtney', 'Bruce Willis', 'Yuliya Snigir', 'Sergei Kolesnikov'], 'ans_type': 'PERSON', 'prediction': 'amaury nolasco', 'human': 0}
# {'id': 1578, 'question': 'who plays bongos on sympathy for the devil', 'answer': ['Rocky Dzidzornu', 'Rocky Dzidzornu - congas'], 'ans_type': 'PERSON', 'prediction': 'bill wyman', 'human': 0}
# {'id': 1139, 'question': 'who won the most mvp awards in the nba', 'answer': ['Kareem Abdul-Jabbar'], 'ans_type': 'PERSON', 'prediction': 'kareem abdul-jabbar', 'human': 1}
# {'id': 2352, 'question': "who's playing in the sec championship 2017", 'answer': ['Auburn Tigers', 'Georgia Bulldogs'], 'ans_type': 'ORG', 'prediction': 'georgia bulldogs', 'human': 1}
# {'id': 688, 'question': "who kills barry's mom in the flash", 'answer': ['Professor Eobard Thawne', 'Thawne'], 'ans_type': 'PERSON', 'prediction': 'thawne', 'human': 1}
# {'id': 882, 'question': 'where is dakar located on the world map', 'answer': ['Senegal'], 'ans_type': 'GPE', 'prediction': 'westernmost city on the african mainland', 'human': 0}
# {'id': 63, 'question': 'where does route 66 start on the west coast', 'answer': ['in Santa Monica'], 'ans_type': 'GPE', 'prediction': 'chicago, illinois', 'human': 0}
# {'id': 2076, 'question': 'who plays janie in the search for santa paws', 'answer': ['G. Hannelius'], 'ans_type': 'PERSON', 'prediction': 'g hannelius', 'human': 1}
# {'id': 1056, 'question': 'who is the highest selling r&b artist of all time', 'answer': ['Rihanna', 'Michael Jackson'], 'ans_type': 'PERSON', 'prediction': 'r. kelly', 'human': 0}
# {'id': 3486, 'question': 'who played the virgin in conan the destroyer', 'answer': ["Olivia d'Abo"], 'ans_type': 'PERSON', 'prediction': "olivia d'abo", 'human': 1}
# {'id': 2831, 'question': 'where is the new football stadium in atlanta', 'answer': ['Mercedes-Benz Stadium'], 'ans_type': 'ORG', 'prediction': 'adjacent to the south', 'human': 0}
# {'id': 2885, 'question': 'what nfl player has the most nfl rings', 'answer': ['Charles Haley', 'Neal Dahlen', 'Bill Belichick', 'Tom Brady', '"Mean Joe" Greene'], 'ans_type': 'PERSON', 'prediction': 'bill belichick', 'human': 1}
# {'id': 1549, 'question': 'who wrote the treasure of the sierra madre', 'answer': ['B. Traven', 'bilingual German author B. Traven'], 'ans_type': 'PERSON', 'prediction': 'b. traven', 'human': 1}
# {'id': 1406, 'question': 'china in chinese is called zhongguo which means', 'answer': ['Central States'], 'ans_type': 'GPE', 'prediction': "` ` middle kingdom''", 'human': 0}
# {'id': 1848, 'question': 'which president supported the creation of the environmental protection agency (epa)', 'answer': ['Richard Nixon', 'President Richard Nixon'], 'ans_type': 'PERSON', 'prediction': 'richard nixon', 'human': 1}
# {'id': 506, 'question': 'who sang gonna sit right down and write myself a letter', 'answer': ['Fats Waller'], 'ans_type': 'PERSON', 'prediction': 'fats waller', 'human': 1}
# {'id': 2443, 'question': 'who established the idea that microorganisms play a role in disease', 'answer': ['Robert Koch', 'Agostino Bassi'], 'ans_type': 'PERSON', 'prediction': 'girolamo fracastoro', 'human': 0}

# %%
print(len(non))
non=[d for d in non if d['id'] not in non150_idx]
print(len(non))
# Out:
# 1818
# 1673

# %%
non=[d for d in non if d['question'] not in nq_non_fewshot]
print(len(non))
# Out:
# 1611

# %%
nq_non_fewshot="""
Answer the following question. [Question]: who was the first to say i'm going to disney world [Answer]: Jeana Yeager
Answer the following question. [Question]: who played ice queen in chronicles of narnia [Answer]: Tilda Swinton
Answer the following question. [Question]: who has won the most college football national champions [Answer]: Princeton
Answer the following question. [Question]: who came up with the idea of the transcontinental railroad [Answer]: Dr. Hartwell Carver
Answer the following question. [Question]: who sang in the movie i walk the line [Answer]: Reese Witherspoon
Answer the following question. [Question]: who has the most followers on the instagram [Answer]: Instagram's own account
Answer the following question. [Question]: where is thank you for your service based [Answer]: Kansas
Answer the following question. [Question]: what is the name of the last episode of spongebob [Answer]: "Bottle Burglars"
Answer the following question. [Question]: in 1945 which party came into power in england [Answer]: Labour Party
Answer the following question. [Question]: who played david on the assassination of gianni versace [Answer]: Cody Fern
Answer the following question. [Question]: where does porter fly out of in toronto [Answer]: Billy Bishop Toronto City Airport
Answer the following question. [Question]: who were the the continent of the americas named after logically [Answer]: Amerigo Vespucci
Answer the following question. [Question]: where do they put the tomb vampires in order to burn them during founders day [Answer]: the Gilbert building
Answer the following question. [Question]: who was the original host of what's my line [Answer]: John Daly
Answer the following question. [Question]: who plays artemisia in 300 rise of an empire [Answer]: Caitlin Carmichael
Answer the following question. [Question]: who is the actor who plays king joffrey [Answer]: Jack Gleeson
Answer the following question. [Question]: who plays christian in 50 shades of grey [Answer]: James "Jamie" Dornan
Answer the following question. [Question]: cast of the have and have nots play [Answer]: Tony Hightower as Frank
Answer the following question. [Question]: where was the italian episode of everybody loves raymond filmed [Answer]: Anguillara Sabazia outside of Rome
Answer the following question. [Question]: where does the paraguay river start and end [Answer]: Parana River
Answer the following question. [Question]: who is playing the halftime show at super bowl 2016 [Answer]: Beyonce
Answer the following question. [Question]: where is season 3 of the detour filmed [Answer]: Alaska
Answer the following question. [Question]: dogs name in the grinch who stole christmas [Answer]: Max
Answer the following question. [Question]: who won season 2 of great british baking show [Answer]: Joanne Wheatley
Answer the following question. [Question]: who do the characters represent in 8 mile [Answer]: loosely on Eminem
Answer the following question. [Question]: who is the coach of university of kentucky basketball [Answer]: John Calipari
Answer the following question. [Question]: who developed the central processing unit (cpu) [Answer]: John von Neumann
Answer the following question. [Question]: who will get ticket to finale in rising star 2 [Answer]: Hemant Brijwasi
Answer the following question. [Question]: who discovered that plants were made of cells [Answer]: Parashara
Answer the following question. [Question]: guardians of the galaxy blue guy in prison [Answer]: Michael Rooker
Answer the following question. [Question]: who discovered that neural communication between cells occurs through chemicals [Answer]: Charles Sherrington
Answer the following question. [Question]: who won the first season of america's got talent [Answer]: Bianca Ryan
Answer the following question. [Question]: where did the term spirits for alcohol come from [Answer]: Middle Eastern alchemy
Answer the following question. [Question]: who added a press room to the white house [Answer]: Richard Nixon
Answer the following question. [Question]: who wrote the country song i can only imagine [Answer]: Bart Millard
Answer the following question. [Question]: who won the 30 man royal rumble match [Answer]: Shinsuke Nakamura
Answer the following question. [Question]: who plays colin on young and the restless [Answer]: Tristan Rogers
Answer the following question. [Question]: who validated the civil rights movement by proclaiming we shall overcome [Answer]: President Lyndon Johnson
Answer the following question. [Question]: product-market fit means being in a good market with a product that can satisfy that market [Answer]: Mark Andreessen
Answer the following question. [Question]: who is currently serving as president of the senate [Answer]: Orrin Hatch
Answer the following question. [Question]: who plays the characters in yo gabba gabba [Answer]: DJ Lance Rock
Answer the following question. [Question]: who has the most 70 point games in nba history [Answer]: Wilt Chamberlain*
Answer the following question. [Question]: who are the judges on do you think you can dance [Answer]: Nigel Lythgoe
Answer the following question. [Question]: who founded amazon where is the headquarters of amazon [Answer]: Seattle, Washington
Answer the following question. [Question]: where are the first nations located in canada [Answer]: south of the Arctic
Answer the following question. [Question]: where did hope on bold and beautiful go [Answer]: Milan, Italy
Answer the following question. [Question]: where is the snooker world open currently held [Answer]: Hainan International Exhibition Center
Answer the following question. [Question]: who won the world cup in cricket 2017 [Answer]: Pakistan
Answer the following question. [Question]: who played nathan scott on one tree hill [Answer]: James Martin Lafferty
Answer the following question. [Question]: who plays the dad in pretty in pink [Answer]: Harry Dean Stanton
Answer the following question. [Question]: what is the order of the netflix marvel shows [Answer]: Marvel's Iron Fist
Answer the following question. [Question]: in which sea pearl is found in india [Answer]: the Indian Ocean
Answer the following question. [Question]: what are the top five wine producing states [Answer]: Washington
Answer the following question. [Question]: who challenged the aristotelian model of a geocentric universe [Answer]: Copernicus
Answer the following question. [Question]: what is the biggest town in west virginia [Answer]: Charleston
Answer the following question. [Question]: who wrote the phantom of the opera music [Answer]: Andrew Lloyd Webber
Answer the following question. [Question]: where does new york drinking water come from [Answer]: the eastern Catskill Mountains
Answer the following question. [Question]: who plays scrooge mcduck in the new ducktales [Answer]: David Tennant
Answer the following question. [Question]: who plays the walking boss in cool hand luke [Answer]: Morgan Woodward
Answer the following question. [Question]: who won the womens 2017 ncaa basketball tournament [Answer]: South Carolina
Answer the following question. [Question]: cast of a nightmare on elm street 1984 [Answer]: Heather Langenkamp
Answer the following question. [Question]: which river separates the bronx in new york city from manhattan island [Answer]: Harlem River
Answer the following question. [Question]: nobel laureate who began career as accountant in calcutta [Answer]: Amartya Sen
Answer the following question. [Question]: the part of the cytoskeleton made from the protein actin is called [Answer]: Microfilaments"""

# %%
random.seed(1001)

# %%
non=random.sample(non, 350)

# %%
non[-1]
# Out:
# {'id': 3407,
#  'question': 'who is the head a in pretty little liars',
#  'answer': ['CeCe Drake'],
#  'ans_type': 'PERSON'}

# %%
for d in non150:
    del d['prediction']

# %%
non150.extend(non)

# %%
len(non150)
# Out:
# 500

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/nq_non_500_instgpt3.5_zero.json', 'w') as f:
    json.dump(non150, f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_800.json', 'w') as f:
    json.dump(non150, f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_500.json') as f:
    sam_500=json.load(f)

# %%
sam_500[-1]
# Out:
# {'id': 3407,
#  'question': 'who is the head a in pretty little liars',
#  'answer': ['CeCe Drake'],
#  'ans_type': 'PERSON'}

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_500.json') as f:
    nq_dev_non=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_num_500.json') as f:
    nq_dev_num=json.load(f)

# %%
print(len(nq_dev_non))
print(len(nq_dev_num))
# Out:
# 500
# 500

# %%
non_id=[d['id'] for d in nq_dev_non]
non_q=[d['question'] for d in nq_dev_non]
num_id=[d['id'] for d in nq_dev_num]
num_q=[d['question'] for d in nq_dev_num]

# %%
# instgpt
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/instgpt/nq_non_500_inst3_few.json') as f:
    non_few=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/instgpt/nq_non_500_inst3_zero.json') as f:
    non_zero=json.load(f)

with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/instgpt/nq_num_500_inst3_few.json') as f:
    num_few=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/instgpt/nq_num_500_inst3_zero.json') as f:
    num_zero=json.load(f)
    
# LLAMA2
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_non_500_llama2_few.json') as f:
    ll_non_few=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_non_500_llama2_zero.json') as f:
    ll_non_zero=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_num_500_llama2_few.json') as f:
    ll_num_few=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_num_500_llama2_zero.json') as f:
    ll_num_zero=json.load(f)

# EMDR
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/emdr/nq_non_500_emdr.json') as f:
    ed_non=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/emdr/nq_num_500_emdr.json') as f:
    ed_num=json.load(f)

# R2D2
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/r2d2/nq_non_500_r2d2.json') as f:
    rd_non=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/r2d2/nq_num_500_r2d2.json') as f:
    rd_num=json.load(f)

# %%
for d in non_few:
    assert (d['question'] in non_q)
    assert (d['id'] in non_id)

# %%
for d in non_zero:
    assert (d['question'] in non_q)
    assert (d['id'] in non_id)

# %%
for d in num_few:
    assert (d['question'] in num_q)
    assert (d['id'] in num_id)

# %%
for d in num_zero:
    assert (d['question'] in num_q)
    assert (d['id'] in num_id)

# %%
for idx in range(500):
    assert (non_few[idx]['question']==non_zero[idx]['question'])
    assert (non_few[idx]['question']==nq_dev_non[idx]['question'])
    assert (non_few[idx]['question']==ll_non_few[idx]['question'])
    assert (non_few[idx]['question']==ll_non_zero[idx]['question'])
    assert (non_few[idx]['question']==ed_non[idx]['question'])
    assert (non_few[idx]['question']==rd_non[idx]['question'])
    
    
    assert (non_few[idx]['id']==non_zero[idx]['id'])
    assert (non_few[idx]['id']==nq_dev_non[idx]['id'])
    assert (non_few[idx]['id']==ll_non_few[idx]['id'])
    assert (non_few[idx]['id']==ll_non_zero[idx]['id'])
    assert (non_few[idx]['id']==ed_non[idx]['id'])
    assert (non_few[idx]['id']==rd_non[idx]['id'])

# %%
for idx in range(500):
    assert (num_few[idx]['question']==num_zero[idx]['question'])
    assert (num_few[idx]['question']==nq_dev_num[idx]['question'])
    assert (num_few[idx]['question']==ll_num_few[idx]['question'])
    assert (num_few[idx]['question']==ll_num_zero[idx]['question'])
    assert (num_few[idx]['question']==ed_num[idx]['question'])
    assert (num_few[idx]['question']==rd_num[idx]['question'])
    
    
    assert (num_few[idx]['id']==num_zero[idx]['id'])
    assert (num_few[idx]['id']==nq_dev_num[idx]['id'])
    assert (num_few[idx]['id']==ll_num_few[idx]['id'])
    assert (num_few[idx]['id']==ll_num_zero[idx]['id'])
    assert (num_few[idx]['id']==ed_num[idx]['id'])
    assert (non_few[idx]['id']==rd_non[idx]['id'])

# %% [markdown]
# ### EMDR, R2D2 확장

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_500.json') as f:
    nq_dev_non=json.load(f)
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_num_500.json') as f:
    nq_dev_num=json.load(f)

# %%
nq_dev_non[0]
# Out:
# {'id': 1982,
#  'question': 'who is the head of the department of homeland security 2017',
#  'answer': ['Kirstjen Nielsen'],
#  'ans_type': 'PERSON'}

# %% [markdown]
# ### Numeric

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/150samples/nq_non_150_emdr_human_final.json') as f:
    emdr150=json.load(f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/150samples/nq_non_150_r2d2_human_final.json') as f:
    rd150=json.load(f)

# %%
print(len(emdr150))
print(len(rd150))
# Out:
# 150
# 150

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_500.json') as f:
    nq_dev_num=json.load(f)
emdr150.extend((nq_dev_num[150:]))

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/nq_dev_non_500.json') as f:
    nq_dev_num=json.load(f)
rd150.extend((nq_dev_num[150:]))

# %%
print(len(emdr150))
print(len(rd150))
# Out:
# 500
# 500

# %%
# 각각 question-prediction
emdr_pred_dic={}
rd_pred_dic={}
with jsonlines.open('/home/donaldo9603/workspace/numeric/data/openqa_eval/NQ_EMDR2.jsonl') as f:
    for line in f:
        emdr_pred_dic[line['question']]=line['prediction']

        
with jsonlines.open('/home/donaldo9603/workspace/numeric/data/openqa_eval/NQ_R2D2.jsonl') as f:
    for line in f:
        rd_pred_dic[line['question']]=line['prediction']

# %%
cnt=0
for d in emdr150:
    if 'prediction' not in d.keys():
        cnt+=1
        d['prediction']=emdr_pred_dic[d['question']]
print(cnt)
# Out:
# 350

# %%
cnt=0
for d in rd150:
    if 'prediction' not in d.keys():
        cnt+=1
        d['prediction']=rd_pred_dic[d['question']]
print(cnt)
# Out:
# 350

# %% [markdown]
# ### EM 우선 tag

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_num_500_llama2_zero.json') as f:
    data=json.load(f)

# %%
from eval import metric_max_over_ground_truths, soft_exact_match_score

# %%
for d in data:
    em=metric_max_over_ground_truths(soft_exact_match_score, d['prediction'], d['answer'])
    if em==1:
        d['human']=1

# %%
cnt=0
for d in data:
    if 'human' not in d.keys():
        cnt+=1
print(cnt)
# Out:
# 296

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/llama2/nq_dev_num_500_llama2_zero.json', 'w') as f:
    json.dump(data, f)

# %%
for d in rd150[150:]:
    em=metric_max_over_ground_truths(soft_exact_match_score, d['prediction'], d['answer'])
    if em==1:
        d['human']=1

# %%
cnt=0
for d in emdr150:
    if 'human' not in d.keys():
        cnt+=1
print(cnt)
# Out:
# 137

# %%
cnt=0
for d in rd150:
    if 'human' not in d.keys():
        cnt+=1
print(cnt)
# Out:
# 147

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/emdr/nq_non_500_emdr.json', 'w') as f:
    json.dump(emdr150, f)

# %%
with open('/home/donaldo9603/workspace/numeric/data/nq/500samples/r2d2/nq_non_500_r2d2.json', 'w') as f:
    json.dump(rd150, f)

# %%
emdr150
# Out:
# [{'id': 3064,
#   'question': 'what was the population of the roman empire at its height',
#   'answer': ['50 to 90 million inhabitants',
#    '70 million',
#    '55-60 million',
#    'an estimated 70 million people'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'about 60 - - 70 million',
#   'human': 1},
#  {'id': 2900,
#   'question': 'when does wonder woman come out on blue ray',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 19, 2017',
#   'human': 1},
#  {'id': 3587,
#   'question': 'when was the tower of london finished being built',
#   'answer': ['1078'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1100',
#   'human': 0},
#  {'id': 696,
#   'question': 'how many times have the winter olympics been in the usa since 1924',
#   'answer': ['1960', '2002', 'four', 'four times', '1932', '1980'],
#   'ans_type': 'DATE',
#   'prediction': 'four',
#   'human': 1},
#  {'id': 3362,
#   'question': 'when will the la sagrada familia be finished',
#   'answer': ['by 2026', '2026', '2026-2028'],
#   'ans_type': 'DATE',
#   'prediction': '2026',
#   'human': 1},
#  {'id': 318,
#   'question': 'when did canada get rid of the death penalty',
#   'answer': ['July 14, 1976', '1976', '1998'],
#   'ans_type': 'DATE',
#   'prediction': 'july 14, 1976',
#   'human': 1},
#  {'id': 2065,
#   'question': 'when does rick and morty play on tv',
#   'answer': ['late-night'],
#   'ans_type': 'TIME',
#   'prediction': 'late - night programming block adult swim',
#   'human': 1},
#  {'id': 1396,
#   'question': 'when was the last time the seattle seahawks won the superbowl',
#   'answer': ['2013'],
#   'ans_type': 'DATE',
#   'prediction': '2013',
#   'human': 1},
#  {'id': 3008,
#   'question': 'how many grams of alcohol in one beer',
#   'answer': ['14', 'about 14 grams of alcohol', '14 grams'],
#   'ans_type': 'CARDINAL',
#   'prediction': '15. 2',
#   'human': 0},
#  {'id': 556,
#   'question': 'when will the next episode of flash be aired',
#   'answer': ['May 15, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'october 10, 2017',
#   'human': 0},
#  {'id': 1528,
#   'question': 'where does the donkey talk in the bible',
#   'answer': ['Numbers 22:28'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'numbers 22 - - 24',
#   'human': 0},
#  {'id': 2772,
#   'question': 'when does the new season of lost in space come out',
#   'answer': ['April 13, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'april 13, 2018',
#   'human': 1},
#  {'id': 1387,
#   'question': 'when is the flash coming back after christmas',
#   'answer': ['January 16, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'december 11, 2017',
#   'human': 0},
#  {'id': 2103,
#   'question': 'when did hollywood video go out of business',
#   'answer': ['2005.', 'May 2010'],
#   'ans_type': 'DATE',
#   'prediction': 'july 31, 2010',
#   'human': 0},
#  {'id': 2394,
#   'question': 'when is the opening ceremonies of the olympics 2018',
#   'answer': ['9 February 2018'],
#   'ans_type': 'DATE',
#   'prediction': '9 february 2018',
#   'human': 1},
#  {'id': 2946,
#   'question': "when does season 13 of america's got talent premiere",
#   'answer': ['May 29, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'may 29, 2018',
#   'human': 1},
#  {'id': 1476,
#   'question': 'when does season 8 of shameless come back',
#   'answer': ['November 5, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'november 5, 2017',
#   'human': 1},
#  {'id': 2967,
#   'question': 'the atomic number of indium which belongs to 5th period is',
#   'answer': ['49'],
#   'ans_type': 'CARDINAL',
#   'prediction': '49',
#   'human': 1},
#  {'id': 2120,
#   'question': 'when did the tv show the waltons first air',
#   'answer': ['September 1972'],
#   'ans_type': 'DATE',
#   'prediction': 'september 1972',
#   'human': 1},
#  {'id': 698,
#   'question': 'when did the smoking ban in public places start',
#   'answer': ['August 2, 1990', '1995'],
#   'ans_type': 'DATE',
#   'prediction': '2 october 2008',
#   'human': 0},
#  {'id': 2266,
#   'question': 'when does the good doctor episode 8 air',
#   'answer': ['November 20, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'january 9, 2018',
#   'human': 0},
#  {'id': 3425,
#   'question': 'when was the cleveland browns last winning game',
#   'answer': ['2016'],
#   'ans_type': 'DATE',
#   'prediction': '2016',
#   'human': 1},
#  {'id': 166,
#   'question': 'when is season 2 of jessica jones being released',
#   'answer': ['March 8, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'march 8, 2018',
#   'human': 1},
#  {'id': 111,
#   'question': 'what is the share of agriculture in indian economy',
#   'answer': ['17.32%', '23%'],
#   'ans_type': 'PERCENT',
#   'prediction': '23 % of the gdp',
#   'human': 0},
#  {'id': 2822,
#   'question': 'the old man and the sea page count',
#   'answer': ['127'],
#   'ans_type': 'CARDINAL',
#   'prediction': '286',
#   'human': 0},
#  {'id': 2700,
#   'question': 'how many strong verbs are there in german',
#   'answer': ['more than 200', 'more than 200 strong'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'more than 200',
#   'human': 1},
#  {'id': 2856,
#   'question': "what's the nba record for most points in a half",
#   'answer': ['59'],
#   'ans_type': 'CARDINAL',
#   'prediction': '39',
#   'human': 0},
#  {'id': 1803,
#   'question': 'when did where are you now come out',
#   'answer': ['February 27, 2015', 'February 27, 2015'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 0},
#  {'id': 2739,
#   'question': "when did i'm like a bird come out",
#   'answer': ['October 24, 2000'],
#   'ans_type': 'DATE',
#   'prediction': 'september 22, 2001',
#   'human': 0},
#  {'id': 2682,
#   'question': 'how old is baby in dirty dancing movie',
#   'answer': ['17-year-old', '17'],
#   'ans_type': 'DATE',
#   'prediction': '17',
#   'human': 1},
#  {'id': 2449,
#   'question': 'when did krakow become the capital of poland',
#   'answer': ['1038'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1038',
#   'human': 1},
#  {'id': 2280,
#   'question': 'when was the peak to peak gondola built',
#   'answer': ['in 2007 and 2008'],
#   'ans_type': 'DATE',
#   'prediction': 'december 12, 2008',
#   'human': 0},
#  {'id': 3487,
#   'question': 'when did the black death end in england',
#   'answer': ['December 1349'],
#   'ans_type': 'DATE',
#   'prediction': 'by the 17th century',
#   'human': 0},
#  {'id': 649,
#   'question': 'when is the end of the football season',
#   'answer': ['February 4, 2018'],
#   'ans_type': 'DATE',
#   'prediction': '13 may 2018',
#   'human': 0},
#  {'id': 1854,
#   'question': 'when did the song holiday road come out',
#   'answer': ['1983', 'June 24, 1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'id': 2810,
#   'question': 'when did world war one begin and end',
#   'answer': ['28 July 1914', '11 November 1918'],
#   'ans_type': 'DATE',
#   'prediction': '11 november 1918',
#   'human': 1},
#  {'id': 2278,
#   'question': 'when did the celebrities enter the big brother house',
#   'answer': ['February 7, 2018', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '9 march 2001',
#   'human': 0},
#  {'id': 530,
#   'question': 'when was the first book made into a movie',
#   'answer': ['1924'],
#   'ans_type': 'DATE',
#   'prediction': '1940',
#   'human': 0},
#  {'id': 77,
#   'question': 'when did marathon change its name to snickers',
#   'answer': ['19 July 1990'],
#   'ans_type': 'DATE',
#   'prediction': '1990',
#   'human': 1},
#  {'id': 3527,
#   'question': 'how many episodes in season 2 of fargo',
#   'answer': ['10', 'ten'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'ten',
#   'human': 1},
#  {'id': 3416,
#   'question': 'when will miraculous ladybug season 2 episode 12 come out',
#   'answer': ['30 March 2018'],
#   'ans_type': 'DATE',
#   'prediction': '19 october 2017',
#   'human': 0},
#  {'id': 345,
#   'question': 'when was the last time new zealand had an earthquake',
#   'answer': ['11 Jul 2017'],
#   'ans_type': 'DATE',
#   'prediction': '13 june 2011',
#   'human': 0},
#  {'id': 2349,
#   'question': 'when did avatar the last airbender first air',
#   'answer': ['February 2005', 'February 21, 2005', 'February 21, 2005'],
#   'ans_type': 'DATE',
#   'prediction': 'february 21, 2005',
#   'human': 1},
#  {'id': 3541,
#   'question': 'when did the dust bowl end in oklahoma',
#   'answer': ['1940'],
#   'ans_type': 'DATE',
#   'prediction': '1940',
#   'human': 1},
#  {'id': 2596,
#   'question': 'when did they stop making the nissan xterra',
#   'answer': ['2015', 'after the 2015 model year'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 1},
#  {'id': 444,
#   'question': 'when did seattle slew win the triple crown',
#   'answer': ['1977', 'in 1977'],
#   'ans_type': 'DATE',
#   'prediction': '1977',
#   'human': 1},
#  {'id': 342,
#   'question': 'when did the golden state warriors win the finals',
#   'answer': ['1947', '1975', '1956', '2015', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 3577,
#   'question': 'when was the last time.michigan beat ohio state',
#   'answer': ['2011'],
#   'ans_type': 'DATE',
#   'prediction': '2011',
#   'human': 1},
#  {'id': 896,
#   'question': 'when was the first ford f 150 made',
#   'answer': ['1975'],
#   'ans_type': 'DATE',
#   'prediction': '1975',
#   'human': 1},
#  {'id': 1616,
#   'question': 'how many steps does the cn tower have',
#   'answer': ['2,579 steps', '2,579'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1,776',
#   'human': 0},
#  {'id': 2217,
#   'question': 'when was the first mad max movie release',
#   'answer': ['12 April 1979', 'April 1979', '1979'],
#   'ans_type': 'DATE',
#   'prediction': '1979',
#   'human': 1},
#  {'id': 278,
#   'question': 'when did mcgee became a regular on ncis',
#   'answer': ['in season two', 'season two'],
#   'ans_type': 'DATE',
#   'prediction': 'season two',
#   'human': 1},
#  {'id': 2027,
#   'question': 'when was nepal declared a secular state in bs',
#   'answer': ['January 15, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'january 2007',
#   'human': 1},
#  {'id': 2067,
#   'question': 'how many nfl teams has st louis had',
#   'answer': ['four'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four',
#   'human': 1},
#  {'id': 3041,
#   'question': 'when do the walking dead comics come out',
#   'answer': ['October 2003 - present', '2003'],
#   'ans_type': 'DATE',
#   'prediction': 'monthly',
#   'human': 0},
#  {'id': 1449,
#   'question': 'how much venom can a king cobra produce',
#   'answer': ['420 mg', 'up to 7 ml', '200 to 500 mg'],
#   'ans_type': 'QUANTITY',
#   'prediction': '420 mg',
#   'human': 1},
#  {'id': 316,
#   'question': 'when did response to state of the union start',
#   'answer': ['in 1966', '1966'],
#   'ans_type': 'DATE',
#   'prediction': '1966',
#   'human': 1},
#  {'id': 1110,
#   'question': 'how many ammendments to the constitution have there been',
#   'answer': ['Twenty-seven', 'Thirty-three'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'twenty-seven',
#   'human': 1},
#  {'id': 1291,
#   'question': 'when did the continental congress vote to adopt the declaration of independence',
#   'answer': ['July 2, 1776'],
#   'ans_type': 'DATE',
#   'prediction': 'july 4, 1776',
#   'human': 0},
#  {'id': 570,
#   'question': 'how long did it take to build the great pyramid of egypt',
#   'answer': ['20-year period'],
#   'ans_type': 'DATE',
#   'prediction': '20 years',
#   'human': 1},
#  {'id': 1472,
#   'question': 'when do they put the rockefeller tree up',
#   'answer': ['mid November', 'late November or early December'],
#   'ans_type': 'DATE',
#   'prediction': 'mid november',
#   'human': 1},
#  {'id': 124,
#   'question': 'what year does the quiet man take place',
#   'answer': ['the 1920s', 'In the 1920s'],
#   'ans_type': 'DATE',
#   'prediction': '1920s',
#   'human': 1},
#  {'id': 3454,
#   'question': 'when did fortnite save the world first come out',
#   'answer': ['July 25, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'july 25, 2017',
#   'human': 1},
#  {'id': 333,
#   'question': 'what episode does goku give up against cell',
#   'answer': ['165', '180'],
#   'ans_type': 'CARDINAL',
#   'prediction': '25',
#   'human': 0},
#  {'id': 3564,
#   'question': 'when was the last time tug-of-war was an official olympic sport',
#   'answer': ['1920'],
#   'ans_type': 'DATE',
#   'prediction': '1920',
#   'human': 1},
#  {'id': 741,
#   'question': 'when was the first orca put in captivity',
#   'answer': ['in the 1960s', 'November 1961'],
#   'ans_type': 'DATE',
#   'prediction': 'november 1961',
#   'human': 1},
#  {'id': 19,
#   'question': 'what age do you need to be to buy a bb gun',
#   'answer': ['18'],
#   'ans_type': 'CARDINAL',
#   'prediction': '18',
#   'human': 1},
#  {'id': 1615,
#   'question': 'when does the team find out prentiss is alive',
#   'answer': ['In the season seven premiere', 'the season seven premiere'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'season seven',
#   'human': 1},
#  {'id': 2153,
#   'question': 'when did john hart play the lone ranger',
#   'answer': ['from 1952 until 1953'],
#   'ans_type': 'DATE',
#   'prediction': 'from 1952 to 1954',
#   'human': 0},
#  {'id': 3226,
#   'question': 'how many times have real madrid won the european cup.in paris',
#   'answer': ['twelve'],
#   'ans_type': 'CARDINAL',
#   'prediction': '13',
#   'human': 0},
#  {'id': 2923,
#   'question': 'when was theme from a summer place released',
#   'answer': ['1960', '1959', 'September 1959'],
#   'ans_type': 'DATE',
#   'prediction': 'september 1959',
#   'human': 1},
#  {'id': 1235,
#   'question': 'when did how you remind me come out',
#   'answer': ['August 21, 2001', 'August 21, 2001'],
#   'ans_type': 'DATE',
#   'prediction': 'august 21, 2001',
#   'human': 1},
#  {'id': 708,
#   'question': 'when does kc undercover season 3 episode 10 air',
#   'answer': ['November 10, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'august 30, 2017',
#   'human': 0},
#  {'id': 3265,
#   'question': 'when was the last time ny rangers won stanley cup',
#   'answer': ['1993-94'],
#   'ans_type': 'DATE',
#   'prediction': '1993 - - 94',
#   'human': 1},
#  {'id': 2949,
#   'question': 'who does the democratic republic of congo trade with',
#   'answer': ['Group of 77',
#    'WTO',
#    'Zimbabwe',
#    'Belgium',
#    'SADC',
#    'Kenya',
#    'South Africa',
#    'China',
#    'AU',
#    'Zambia',
#    'IMF',
#    'World Bank',
#    'African Development Bank',
#    'France'],
#   'ans_type': 'CARDINAL',
#   'prediction': "people's republic of china",
#   'human': 1},
#  {'id': 3261,
#   'question': 'how many dominoes do you need for mexican train',
#   'answer': ['A double-twelve set'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'a double-twelve set',
#   'human': 1},
#  {'id': 475,
#   'question': 'when was the debating club established in almora',
#   'answer': ['1871 A.D.', '1871'],
#   'ans_type': 'DATE',
#   'prediction': '1871',
#   'human': 1},
#  {'id': 2017,
#   'question': "when did billy don't be a hero come out",
#   'answer': ['1974'],
#   'ans_type': 'DATE',
#   'prediction': '1974',
#   'human': 1},
#  {'id': 1646,
#   'question': 'when did all night long come out lionel richie',
#   'answer': ['1983', 'August 31, 1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'id': 767,
#   'question': "when did korn's follow the leader come out",
#   'answer': ['August 18, 1998'],
#   'ans_type': 'DATE',
#   'prediction': 'august 18, 1998',
#   'human': 1},
#  {'id': 2126,
#   'question': 'when did the jurassic park movies come out',
#   'answer': ['Jurassic Park (1993)',
#    '2001',
#    '2015',
#    '2018',
#    '1993',
#    'Jurassic World (2015)',
#    '1997'],
#   'ans_type': 'DATE',
#   'prediction': '1993',
#   'human': 1},
#  {'id': 130,
#   'question': 'what percentage of sunlight is captured by plants to convert it into food energy',
#   'answer': ['45%', '3 to 6%'],
#   'ans_type': 'PERCENT',
#   'prediction': '3 to 6%',
#   'human': 1},
#  {'id': 3599,
#   'question': 'when was the last summer olympics in the usa',
#   'answer': ['1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'id': 1375,
#   'question': 'when did the revolution begin in the united states',
#   'answer': ['1775', '1765'],
#   'ans_type': 'DATE',
#   'prediction': 'april 19, 1775',
#   'human': 1},
#  {'id': 3404,
#   'question': 'how many seasons has greys anatomy been on tv',
#   'answer': ['14'],
#   'ans_type': 'CARDINAL',
#   'prediction': '14',
#   'human': 1},
#  {'id': 628,
#   'question': 'how many pennsylvania house of representatives are there',
#   'answer': ['203', '203 members'],
#   'ans_type': 'CARDINAL',
#   'prediction': '203',
#   'human': 1},
#  {'id': 3231,
#   'question': 'what is small business tax rate in canada',
#   'answer': ['10.5%'],
#   'ans_type': 'PERCENT',
#   'prediction': '10%',
#   'human': 0},
#  {'id': 392,
#   'question': 'how many customers does edf have in the uk',
#   'answer': ['5.7 million customer accounts', '5.7 million'],
#   'ans_type': 'CARDINAL',
#   'prediction': '5.7 million',
#   'human': 1},
#  {'id': 2601,
#   'question': 'when does the new season of are you the one come on',
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': 'august 15, 2018',
#   'human': 1},
#  {'id': 1302,
#   'question': 'how long has tom brady been playing professional football',
#   'answer': ['18-season career'],
#   'ans_type': 'DATE',
#   'prediction': '2000 - - present',
#   'human': 0},
#  {'id': 1967,
#   'question': 'when did red dead redemption 1 come out',
#   'answer': ['May 18, 2010', 'May 2010'],
#   'ans_type': 'DATE',
#   'prediction': 'may 2010',
#   'human': 1},
#  {'id': 763,
#   'question': 'season 2 attack on titan how many episodes',
#   'answer': ['12'],
#   'ans_type': 'CARDINAL',
#   'prediction': '12',
#   'human': 1},
#  {'id': 135,
#   'question': 'when did bird is the word come out',
#   'answer': ['1963'],
#   'ans_type': 'DATE',
#   'prediction': '1963',
#   'human': 1},
#  {'id': 2284,
#   'question': 'how many co2 molecules are produced in aerobic respiration',
#   'answer': ['6'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1 molecule of atp',
#   'human': 0},
#  {'id': 3375,
#   'question': 'what time can you legally buy alcohol in michigan',
#   'answer': ['7 a.m.'],
#   'ans_type': 'TIME',
#   'prediction': '6 a. m. - - 2 a. m.',
#   'human': 0},
#  {'id': 811,
#   'question': 'when did the nfl adopt a salary cap',
#   'answer': ['the 1994 season', 'for the 1994 season', '1994', '1994 season'],
#   'ans_type': 'DATE',
#   'prediction': '1994',
#   'human': 1},
#  {'id': 1917,
#   'question': 'when did the ouija board first come out',
#   'answer': ['July 1, 1890'],
#   'ans_type': 'DATE',
#   'prediction': 'july 1, 1890',
#   'human': 1},
#  {'id': 2207,
#   'question': 'when is season 4 of flash coming out',
#   'answer': ['October 10, 2017', 'on October 10, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'october 10, 2017',
#   'human': 1},
#  {'id': 1341,
#   'question': 'when did little polveir win the grand national',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '8 april 1989',
#   'human': 1},
#  {'id': 1715,
#   'question': 'when is the womens ice skating for the olympics',
#   'answer': ['21 February', '21-23 February', '23 February'],
#   'ans_type': 'DATE',
#   'prediction': '21 - - 23 february',
#   'human': 1},
#  {'id': 85,
#   'question': 'when did toyota start making cars in the us',
#   'answer': ['by the early 1980s', '1984'],
#   'ans_type': 'DATE',
#   'prediction': '1957',
#   'human': 0},
#  {'id': 2793,
#   'question': 'how many points did lebron james scored in his career',
#   'answer': ['31,038'],
#   'ans_type': 'CARDINAL',
#   'prediction': '30, 000',
#   'human': 0},
#  {'id': 2526,
#   'question': 'when was to god be the glory written',
#   'answer': ['around 1872'],
#   'ans_type': 'DATE',
#   'prediction': 'around 1872',
#   'human': 1},
#  {'id': 2879,
#   'question': 'when does wentworth season 6 start in australia',
#   'answer': ['2019', '19 June 2018'],
#   'ans_type': 'DATE',
#   'prediction': '19 june 2018',
#   'human': 1},
#  {'id': 1679,
#   'question': 'when does star trek discovery air on tv',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 24',
#   'human': 0},
#  {'id': 182,
#   'question': 'what is the current population of bora bora',
#   'answer': ['10,605'],
#   'ans_type': 'CARDINAL',
#   'prediction': '10,605',
#   'human': 1},
#  {'id': 2377,
#   'question': 'how many countries are a part of opec',
#   'answer': ['14'],
#   'ans_type': 'CARDINAL',
#   'prediction': '15',
#   'human': 0},
#  {'id': 443,
#   'question': 'when did vat change from 17.5 to 20',
#   'answer': ['4 January 2011'],
#   'ans_type': 'DATE',
#   'prediction': '4 january 2011',
#   'human': 1},
#  {'id': 524,
#   'question': 'when was the first super bowl the eagles ever won',
#   'answer': ['2017', '1948'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 419,
#   'question': 'when was harry potter and the philosophers stone published',
#   'answer': ['in 1997', '1997'],
#   'ans_type': 'DATE',
#   'prediction': '1997',
#   'human': 1},
#  {'id': 2756,
#   'question': 'when did a wrinkle in time start filming',
#   'answer': ['November 2, 2016'],
#   'ans_type': 'DATE',
#   'prediction': 'november 2, 2016',
#   'human': 1},
#  {'id': 1733,
#   'question': 'when was the original stephen king it movie made',
#   'answer': ['1990'],
#   'ans_type': 'DATE',
#   'prediction': '1990',
#   'human': 1},
#  {'id': 2399,
#   'question': 'when did the first pokemon game come out',
#   'answer': ['October 2000', '1996'],
#   'ans_type': 'DATE',
#   'prediction': 'february 27, 1996',
#   'human': 0},
#  {'id': 951,
#   'question': 'when is the next step season 3 coming out',
#   'answer': ['March 16, 2015'],
#   'ans_type': 'DATE',
#   'prediction': 'march 16, 2015',
#   'human': 1},
#  {'id': 916,
#   'question': 'when is if loving you is wrong coming back season 4',
#   'answer': ['September 19, 2017', 'March 7, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'september 19, 2017',
#   'human': 1},
#  {'id': 335,
#   'question': 'when was the first nuclear power plant opened',
#   'answer': ['December 20, 1951',
#    'June 27, 1954',
#    'On June 27, 1954',
#    'the USSR',
#    'December 2, 1942'],
#   'ans_type': 'DATE',
#   'prediction': 'october 17, 1956',
#   'human': 0},
#  {'id': 110,
#   'question': 'what is the angle of the tower of pisa',
#   'answer': ['about 3.99 degrees', '3.99 degrees', 'at about 3.99 degrees'],
#   'ans_type': 'QUANTITY',
#   'prediction': '3. 97 degrees',
#   'human': 1},
#  {'id': 781,
#   'question': 'how many hoops are used in a game of croquet',
#   'answer': ['six', 'eight'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'six',
#   'human': 1},
#  {'id': 2965,
#   'question': 'how many national parks are present in india',
#   'answer': ['103'],
#   'ans_type': 'CARDINAL',
#   'prediction': '105',
#   'human': 0},
#  {'id': 397,
#   'question': 'how many seasons are there for lost girl',
#   'answer': ['5', 'five'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'five',
#   'human': 1},
#  {'id': 1766,
#   'question': 'when was the japanese videogame company nintendo founded',
#   'answer': ['23 September 1889'],
#   'ans_type': 'DATE',
#   'prediction': '23 september 1889',
#   'human': 1},
#  {'id': 710,
#   'question': 'how long is a whale shark in meters',
#   'answer': ['12.65 m', 'estimated at 9.7 m', '9.7 m'],
#   'ans_type': 'QUANTITY',
#   'prediction': '12',
#   'human': 0},
#  {'id': 2068,
#   'question': 'when did season 4 of glee come out',
#   'answer': ['September 13, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'september 13, 2012',
#   'human': 1},
#  {'id': 1927,
#   'question': 'when did one child policy end in china',
#   'answer': ['January 1, 2016'],
#   'ans_type': 'DATE',
#   'prediction': 'the end of 2015',
#   'human': 0},
#  {'id': 1379,
#   'question': 'when does the little couples new season start',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 19, 2017',
#   'human': 1},
#  {'id': 370,
#   'question': 'when was the biltmore house opened to the public',
#   'answer': ['March 1930'],
#   'ans_type': 'DATE',
#   'prediction': 'christmas eve 1895',
#   'human': 0},
#  {'id': 245,
#   'question': 'rizal finished all the chapters of the novel noli me tangere in',
#   'answer': ['December 1886', 'Spanish'],
#   'ans_type': 'DATE',
#   'prediction': 'december 1886',
#   'human': 1},
#  {'id': 2275,
#   'question': 'when did harvard become an ivy league school',
#   'answer': ['1945'],
#   'ans_type': 'DATE',
#   'prediction': '1954',
#   'human': 0},
#  {'id': 1209,
#   'question': 'when did day light savings start in the us',
#   'answer': ['March 31, 1918', '1918', 'March 19, 1918', 'March 11'],
#   'ans_type': 'DATE',
#   'prediction': 'march 19, 1918',
#   'human': 1},
#  {'id': 1969,
#   'question': 'what channel is abc on in phoenix arizona',
#   'answer': ['15'],
#   'ans_type': 'CARDINAL',
#   'prediction': '15',
#   'human': 1},
#  {'id': 1156,
#   'question': 'when did the log flume closed at alton towers',
#   'answer': ['10 October 2015', '2015'],
#   'ans_type': 'DATE',
#   'prediction': 'march 16, 2016',
#   'human': 0},
#  {'id': 3126,
#   'question': 'when does the new death of superman come out',
#   'answer': ['2019', '2018', 'in 2018 and 2019', 'late 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'august 7, 2018',
#   'human': 1},
#  {'id': 108,
#   'question': 'the chinese dragons are protectors of how many seas diggy',
#   'answer': ['Four Seas', 'Four'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four',
#   'human': 1},
#  {'id': 2986,
#   'question': 'when did the last volcano erupt in iceland',
#   'answer': ['2010'],
#   'ans_type': 'DATE',
#   'prediction': '25 may 2011',
#   'human': 0},
#  {'id': 1709,
#   'question': 'when did teenage mutant ninja turtles come out',
#   'answer': ['1984'],
#   'ans_type': 'DATE',
#   'prediction': '1984',
#   'human': 1},
#  {'id': 888,
#   'question': 'when did slave to the rhythm come out',
#   'answer': ['May 8, 2014', '2010'],
#   'ans_type': 'DATE',
#   'prediction': '1985',
#   'human': 0},
#  {'id': 1214,
#   'question': 'when does the black panther movie soundtrack come out',
#   'answer': ['February 9, 2018', 'February 16, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'february 9, 2018',
#   'human': 1},
#  {'id': 1783,
#   'question': 'when did hollywood become the centre of the film industry',
#   'answer': ['1912', 'By 1912'],
#   'ans_type': 'DATE',
#   'prediction': 'the early 20th century',
#   'human': 1},
#  {'id': 1442,
#   'question': 'when was the last time someone won the super bowl back to back',
#   'answer': ['2004'],
#   'ans_type': 'DATE',
#   'prediction': '2003 - - 2004',
#   'human': 1},
#  {'id': 1101,
#   'question': 'when did canada sign the un declaration of indigenous rights',
#   'answer': ['May 2016', '12 November 2010'],
#   'ans_type': 'DATE',
#   'prediction': '2016',
#   'human': 1},
#  {'id': 3458,
#   'question': 'when was the death penalty reinstated in oregon',
#   'answer': ['1984'],
#   'ans_type': 'DATE',
#   'prediction': '1978',
#   'human': 0},
#  {'id': 2023,
#   'question': 'when does south by southwest start in austin texas',
#   'answer': ['mid-March'],
#   'ans_type': 'DATE',
#   'prediction': 'mid-march',
#   'human': 1},
#  {'id': 1220,
#   'question': 'when did the uk and us become allies',
#   'answer': ['Since 1940', '1940'],
#   'ans_type': 'DATE',
#   'prediction': '1940',
#   'human': 1},
#  {'id': 2689,
#   'question': "when's the last time scotland won the calcutta cup",
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': '26 february 2006',
#   'human': 0},
#  {'id': 3234,
#   'question': 'love is not love that alters when it alteration finds meaning',
#   'answer': ['Sonnet 116'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'love that seeks after',
#   'human': 0},
#  {'id': 339,
#   'question': 'when was the last time giants won superbowl',
#   'answer': ['2011'],
#   'ans_type': 'DATE',
#   'prediction': '2011',
#   'human': 1},
#  {'id': 1129,
#   'question': 'how many indian astronauts have gone to space',
#   'answer': ['2'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'kalpana chawla',
#   'human': 0},
#  {'id': 439,
#   'question': 'when did the steel mills closed in youngstown ohio',
#   'answer': ['September 19, 1977'],
#   'ans_type': 'DATE',
#   'prediction': 'september 19, 1977',
#   'human': 1},
#  {'id': 2351,
#   'question': 'when was the abacus invented in ancient china',
#   'answer': ['2nd century BC'],
#   'ans_type': 'DATE',
#   'prediction': '2nd century bc',
#   'human': 1},
#  {'id': 2792,
#   'question': "when did australia 2 win the america's cup",
#   'answer': ['1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'id': 282,
#   'question': 'when was a series of unfortunate events published',
#   'answer': ['September 1999'],
#   'ans_type': 'DATE',
#   'prediction': 'september 30, 1999'},
#  {'id': 992,
#   'question': 'how many seasons of from dusk till dawn are there',
#   'answer': ['third season'],
#   'ans_type': 'DATE',
#   'prediction': 'third season',
#   'human': 1},
#  {'id': 459,
#   'question': 'when did frank sinatra first sing new york new york',
#   'answer': ['1980', '1979'],
#   'ans_type': 'DATE',
#   'prediction': 'october 1978'},
#  {'id': 2823,
#   'question': 'mount and blade with fire and sword time period',
#   'answer': ['1648-51'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1648 - - 1651'},
#  {'id': 1828,
#   'question': 'how many us states currently use capital punishment',
#   'answer': ['31 states', '31'],
#   'ans_type': 'CARDINAL',
#   'prediction': '31',
#   'human': 1},
#  {'id': 771,
#   'question': 'how many gallons of water in the gulf of mexico',
#   'answer': ['660 quadrillion US gallons'],
#   'ans_type': 'QUANTITY',
#   'prediction': '660 quadrillion us gallons',
#   'human': 1},
#  {'id': 2007,
#   'question': 'when was the mission san antonio de valero built',
#   'answer': ['the 18th century', '1718'],
#   'ans_type': 'DATE',
#   'prediction': '1718',
#   'human': 1},
#  {'id': 1806,
#   'question': 'when did end of the road come out',
#   'answer': ['1992', 'June\xa030,\xa01992'],
#   'ans_type': 'DATE',
#   'prediction': 'june 30, 1992',
#   'human': 1},
#  {'id': 2864,
#   'question': 'when did linkin park release one more light',
#   'answer': ['May 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'may 19, 2017',
#   'human': 1},
#  {'id': 3340,
#   'question': 'when is season 7 race to the edge coming out',
#   'answer': ['February 16, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'july 11, 2017'},
#  {'id': 1964,
#   'question': 'how many series of diary of a wimpy kid are there',
#   'answer': ['12'],
#   'ans_type': 'CARDINAL',
#   'prediction': '12',
#   'human': 1},
#  {'id': 2892,
#   'question': 'when did south sudan join east african community',
#   'answer': ['April 2016', '2016'],
#   'ans_type': 'DATE',
#   'prediction': '5 september'},
#  {'id': 994,
#   'question': 'when did martial law in the philippines end',
#   'answer': ['1981', '81'],
#   'ans_type': 'DATE',
#   'prediction': 'january 17, 1981',
#   'human': 1},
#  {'id': 3088,
#   'question': 'when does the second half of vikings season 5 air',
#   'answer': ['2018', 'in 2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'id': 243,
#   'question': "a single period of precession of earth's axis is completed in about",
#   'answer': ['approximately 26,000 years', '26,000 years'],
#   'ans_type': 'DATE',
#   'prediction': '25, 772 years'},
#  {'id': 136,
#   'question': 'how tall is the actor who plays hagrid in harry potter',
#   'answer': ['6ft 1in'],
#   'ans_type': 'QUANTITY',
#   'prediction': '6 ft 9in'},
#  {'id': 2392,
#   'question': 'when does the implantation of the embryo occur',
#   'answer': ['around 9 days after ovulation'],
#   'ans_type': 'DATE',
#   'prediction': 'around 9 days after ovulation',
#   'human': 1},
#  {'id': 3382,
#   'question': 'when was the seat moved to the capitol',
#   'answer': ['November 17, 1800', '1800', 'December 1800'],
#   'ans_type': 'DATE',
#   'prediction': 'december 1800',
#   'human': 1},
#  {'id': 3123,
#   'question': 'eukaryotes have how many origins of dna replication',
#   'answer': ['up to 100,000'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'as many as one thousand'},
#  {'id': 919,
#   'question': 'when did the crucifix become the symbol of christianity',
#   'answer': ['in the 2nd century', '4th century', 'the 4th century'],
#   'ans_type': 'DATE',
#   'prediction': 'the 6th century ad'},
#  {'id': 2504,
#   'question': 'the first significant restriction on free immigration in u.s. history was the',
#   'answer': ['Naturalization Act of 1790', 'Chinese Exclusion Act in 1882'],
#   'ans_type': 'DATE',
#   'prediction': 'chinese exclusion act of 1882'},
#  {'id': 3122,
#   'question': 'when did the legal drinking age changed to 21',
#   'answer': ['By mid-1988', 'October 1986'],
#   'ans_type': 'DATE',
#   'prediction': 'mid - 1988'},
#  {'id': 725,
#   'question': 'number of films in lord of the rings',
#   'answer': ['three'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'three',
#   'human': 1},
#  {'id': 93,
#   'question': 'when did amnesia the dark descent come out',
#   'answer': ['8 September 2010'],
#   'ans_type': 'DATE',
#   'prediction': '2010'},
#  {'id': 3513,
#   'question': 'when was fingerprinting first used by the police',
#   'answer': ['the early 20th century', 'In 1840'],
#   'ans_type': 'DATE',
#   'prediction': 'late nineteenth century'},
#  {'id': 496,
#   'question': 'when was the last time michigan won the championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 1},
#  {'id': 3263,
#   'question': 'when was the taj mahal built and completed',
#   'answer': ['1632–53'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1653'},
#  {'id': 3521,
#   'question': 'when is beyblade burst super z coming out',
#   'answer': ['April 2, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'december 19, 2016'},
#  {'id': 610,
#   'question': 'when was the book pride and prejudice written',
#   'answer': ['28 January 1813', '1813'],
#   'ans_type': 'DATE',
#   'prediction': 'between october 1796 and august 1797'},
#  {'id': 487,
#   'question': 'when was the first election held in india',
#   'answer': ['1951–52'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1951 - - 52'},
#  {'id': 1225,
#   'question': 'when were cigarette ads banned from tv uk',
#   'answer': ['1 August 1965'],
#   'ans_type': 'DATE',
#   'prediction': '1 august 1965',
#   'human': 1},
#  {'id': 2118,
#   'question': 'when was the lupus foundation of america founded',
#   'answer': ['1977'],
#   'ans_type': 'DATE',
#   'prediction': '1977',
#   'human': 1},
#  {'id': 3036,
#   'question': 'how many episodes are there in season six of nashville',
#   'answer': ['16', '16 episodes'],
#   'ans_type': 'CARDINAL',
#   'prediction': '16',
#   'human': 1},
#  {'id': 360,
#   'question': 'when did gaurdians of the galaxy 2 come out',
#   'answer': ['2017', 'May\xa05,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'may 5, 2017',
#   'human': 1},
#  {'id': 2754,
#   'question': 'when does the champions league round of 16 start',
#   'answer': ['13 February'],
#   'ans_type': 'DATE',
#   'prediction': '13 february 2018',
#   'human': 1},
#  {'id': 2825,
#   'question': 'when was looking for a sunset bird in winter written',
#   'answer': ['1923'],
#   'ans_type': 'DATE',
#   'prediction': 'between 2002 and 2006'},
#  {'id': 1906,
#   'question': 'what is the number of total presidential electoral votes',
#   'answer': ['538'],
#   'ans_type': 'CARDINAL',
#   'prediction': '538',
#   'human': 1},
#  {'id': 440,
#   'question': 'when was the last time the jets won a playoff game',
#   'answer': ['2010'],
#   'ans_type': 'DATE',
#   'prediction': 'april 20, 2018'},
#  {'id': 1506,
#   'question': 'when was the electronic funds transfer act signed into law',
#   'answer': ['in 1978', 'November 10, 1978', '1978'],
#   'ans_type': 'DATE',
#   'prediction': 'signed by president jimmy carter'},
#  {'id': 1690,
#   'question': 'when did the right to buy scheme start',
#   'answer': ['1980'],
#   'ans_type': 'DATE',
#   'prediction': '1980',
#   'human': 1},
#  {'id': 791,
#   'question': 'when was the nobel prize for literature first awarded',
#   'answer': ['1901'],
#   'ans_type': 'DATE',
#   'prediction': '1901',
#   'human': 1},
#  {'id': 1963,
#   'question': 'when did bihar bifurcate from bengal and some parts of chota nagpur merged into bengal',
#   'answer': ['1912'],
#   'ans_type': 'DATE',
#   'prediction': '1912',
#   'human': 1},
#  {'id': 156,
#   'question': 'when was the minimum wage established in the united states',
#   'answer': ['1938', '1933', '1912'],
#   'ans_type': 'DATE',
#   'prediction': 'july 24, 2009'},
#  {'id': 3457,
#   'question': 'when was the chain first used for f1',
#   'answer': ['1978'],
#   'ans_type': 'DATE',
#   'prediction': '1950'},
#  {'id': 471,
#   'question': 'when was the $1 000 bill discontinued',
#   'answer': ['1969', 'December 27, 1945', 'July 14, 1969'],
#   'ans_type': 'DATE',
#   'prediction': 'july 14, 1969',
#   'human': 1},
#  {'id': 3484,
#   'question': 'latest season on keeping up with the kardashians',
#   'answer': ['fourteen', '14'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'fourteenth',
#   'human': 1},
#  {'id': 1050,
#   'question': 'when did italy enter the second world war',
#   'answer': ['10 June 1940'],
#   'ans_type': 'DATE',
#   'prediction': '10 june 1940',
#   'human': 1},
#  {'id': 22,
#   'question': 'how many seasons of vampire diaries r there',
#   'answer': ['eight', '8'],
#   'ans_type': 'CARDINAL',
#   'prediction': '8',
#   'human': 1},
#  {'id': 2117,
#   'question': 'what is the enrollment at university of miami',
#   'answer': ['16,801', '16,801 students'],
#   'ans_type': 'CARDINAL',
#   'prediction': '17, 331 students'},
#  {'id': 2928,
#   'question': 'when did the term sustainability start to be used',
#   'answer': ['1987'],
#   'ans_type': 'DATE',
#   'prediction': 'the 1980s'},
#  {'id': 1640,
#   'question': 'when was the last time vancouver had an earthquake',
#   'answer': ['1946'],
#   'ans_type': 'DATE',
#   'prediction': 'june 23, 1700'},
#  {'id': 1003,
#   'question': 'when was the last amendment to the constitution passed',
#   'answer': ['May 5, 1992'],
#   'ans_type': 'DATE',
#   'prediction': 'may 5, 1992',
#   'human': 1},
#  {'id': 652,
#   'question': 'when did jack mccoy join law and order',
#   'answer': ['1994'],
#   'ans_type': 'DATE',
#   'prediction': '1994',
#   'human': 1},
#  {'id': 2725,
#   'question': 'in photosynthesis the carbon in co2 is initially fixed to what molecule',
#   'answer': ['3-phosphoglycerate'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'phosphoenolpyruvate'},
#  {'id': 2177,
#   'question': 'when will miraculous season 2 episode 11 be released',
#   'answer': ['30\xa0March\xa02018', '27\xa0October\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': '26 december 2017'},
#  {'id': 1066,
#   'question': 'when did ibuprofen become available over the counter',
#   'answer': ['1983', '1984'],
#   'ans_type': 'DATE',
#   'prediction': '1984',
#   'human': 1},
#  {'id': 2898,
#   'question': 'when did hyderabad became a part of india',
#   'answer': ['24 November 1949'],
#   'ans_type': 'DATE',
#   'prediction': '1948'},
#  {'id': 171,
#   'question': 'when was coffee first made into a drink',
#   'answer': ['15th century', 'the 15th century'],
#   'ans_type': 'DATE',
#   'prediction': 'circa 1454'},
#  {'id': 3586,
#   'question': 'when did the first pair of yeezys come out',
#   'answer': ['February 14, 2015'],
#   'ans_type': 'DATE',
#   'prediction': 'february 28, 2015'},
#  {'id': 1773,
#   'question': 'when did france and belgium invade the ruhr',
#   'answer': ['11 January 1923', 'January 1923', '1923'],
#   'ans_type': 'DATE',
#   'prediction': '1923',
#   'human': 1},
#  {'id': 3408,
#   'question': 'how many students does monarch high school have',
#   'answer': ['2,406'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'approximately 300'},
#  {'id': 879,
#   'question': 'how many episodes of the white princess will there be',
#   'answer': ['eight', '8'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'eight',
#   'human': 1},
#  {'id': 552,
#   'question': 'when did the us stop drafting for the vietnam war',
#   'answer': ['1973'],
#   'ans_type': 'DATE',
#   'prediction': 'december 1972'},
#  {'id': 1696,
#   'question': 'india south africa test series 2018 highest runs',
#   'answer': ['286', 'AB de Villiers'],
#   'ans_type': 'CARDINAL',
#   'prediction': '558'},
#  {'id': 2646,
#   'question': 'how much does a new gulfstream g650 cost',
#   'answer': ['US$66.61 million', '$66.5 million'],
#   'ans_type': 'MONEY',
#   'prediction': '$66.5 million',
#   'human': 1},
#  {'id': 1065,
#   'question': 'when do love and hip hop new york come back on',
#   'answer': ['November\xa013,\xa02017', 'October 30, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'october 30, 2017',
#   'human': 1},
#  {'id': 188,
#   'question': 'what proposition made the insurance commissioner an elected position',
#   'answer': ['Proposition 103', 'Proposition 103 in 1988'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'proposition 103',
#   'human': 1},
#  {'id': 3130,
#   'question': 'when did the angel of the north get built',
#   'answer': ['1998', '1994'],
#   'ans_type': 'DATE',
#   'prediction': '1998',
#   'human': 1},
#  {'id': 3372,
#   'question': 'what is the rank of india in economic growth',
#   'answer': ['12 / 225', '12'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'sixth - largest'},
#  {'id': 1131,
#   'question': 'why did ric flair go back to wcw',
#   'answer': ['February 1993'],
#   'ans_type': 'DATE',
#   'prediction': 'having legitimate conflicts with eric bischoff'},
#  {'id': 2582,
#   'question': 'how much energy does coal produce in the us',
#   'answer': ['16.5 quadrillion BTUs', '30.4%'],
#   'ans_type': 'QUANTITY',
#   'prediction': '1, 991, 000'},
#  {'id': 3025,
#   'question': 'what is the latest version of microsoft office 2010',
#   'answer': ['14.0.7182.5000'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'codenamed office 14'},
#  {'id': 1717,
#   'question': 'how many players have scored 10000 runs in odi',
#   'answer': ['11', 'eleven'],
#   'ans_type': 'CARDINAL',
#   'prediction': '18, 426'},
#  {'id': 2298,
#   'question': 'when did colour tv come out in uk',
#   'answer': ['July 1, 1967', '1967/1969/1976', '1967'],
#   'ans_type': 'DATE',
#   'prediction': '1967',
#   'human': 1},
#  {'id': 103,
#   'question': 'when does the dlc for rainbow six siege come out',
#   'answer': ['January 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'post - launch'},
#  {'id': 2221,
#   'question': 'when is the world consumer right day celebrated',
#   'answer': ['15 March every year', '15 March'],
#   'ans_type': 'DATE',
#   'prediction': '15 march',
#   'human': 1},
#  {'id': 272,
#   'question': 'when did lionel messi play his first game for barcelona',
#   'answer': ['2002', '2001', 'October 2004'],
#   'ans_type': 'DATE',
#   'prediction': '16 november 2003'},
#  {'id': 605,
#   'question': 'when does isle of dogs come out in us',
#   'answer': ['April 13, 2018', 'March 23, 2018', 'March\xa023,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'march 23, 2018',
#   'human': 1},
#  {'id': 718,
#   'question': 'when was half life 2 episode 2 released',
#   'answer': ['in 2007', 'October 10, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'october 10, 2007',
#   'human': 1},
#  {'id': 580,
#   'question': 'when did disney art of animation resort open',
#   'answer': ['May 31, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'may 31, 2012',
#   'human': 1},
#  {'id': 2328,
#   'question': 'when did michigan last win a national championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1998'},
#  {'id': 1295,
#   'question': 'when was last time bayern munich won champions league',
#   'answer': ['2012–13', '2013', '2000–01'],
#   'ans_type': 'DATE',
#   'prediction': '2012 - - 13'},
#  {'id': 1252,
#   'question': 'how many episodes curse of oak island season 5',
#   'answer': ['18'],
#   'ans_type': 'CARDINAL',
#   'prediction': '10'},
#  {'id': 472,
#   'question': "what's the population of prince edward island",
#   'answer': ['142,907 residents', '142,907'],
#   'ans_type': 'CARDINAL',
#   'prediction': '142,907',
#   'human': 1},
#  {'id': 134,
#   'question': 'when did the royal mint move to wales',
#   'answer': ['1968', 'the 1960s.', '17 December 1968', 'the 1960s'],
#   'ans_type': 'DATE',
#   'prediction': '1967'},
#  {'id': 1089,
#   'question': 'when does the world cup of hockey start',
#   'answer': ['2020'],
#   'ans_type': 'DATE',
#   'prediction': 'every four years'},
#  {'id': 560,
#   'question': 'when were birth certificates first issued in the united states',
#   'answer': ['1902', '1900', 'From 1900 to 1946'],
#   'ans_type': 'DATE',
#   'prediction': '1900',
#   'human': 1},
#  {'id': 2347,
#   'question': 'hart of dixie season 4 how many episodes',
#   'answer': ['10'],
#   'ans_type': 'CARDINAL',
#   'prediction': '10',
#   'human': 1},
#  {'id': 1006,
#   'question': 'when did the first marvel vs capcom come out',
#   'answer': ['1998', 'in 1996', '1996'],
#   'ans_type': 'DATE',
#   'prediction': '1994'},
#  {'id': 2832,
#   'question': 'when was the last god of war made',
#   'answer': ['2018', 'March 12, 2013'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'id': 2590,
#   'question': 'when did are you smarter than a 5th grader first air',
#   'answer': ['February 27, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'february 27, 2007',
#   'human': 1},
#  {'id': 1781,
#   'question': 'what do mobile numbers start with in the uk',
#   'answer': ['0'],
#   'ans_type': 'CARDINAL',
#   'prediction': '07xxx xxxxxx',
#   'human': 1},
#  {'id': 532,
#   'question': 'when was the reaper invented by cyrus mccormick',
#   'answer': ['1837', '1834'],
#   'ans_type': 'DATE',
#   'prediction': '1831'},
#  {'id': 315,
#   'question': 'when did seat belts become law in ontario',
#   'answer': ['January 1, 1976'],
#   'ans_type': 'DATE',
#   'prediction': 'january 1, 1976',
#   'human': 1},
#  {'id': 1610,
#   'question': 'when does the next warrior book come out',
#   'answer': ['April 10, 2018'],
#   'ans_type': 'DATE',
#   'prediction': '6 november 2018'},
#  {'id': 2648,
#   'question': 'when did congress passes legislation to fund the national cancer institute',
#   'answer': ['August 5, 1937'],
#   'ans_type': 'DATE',
#   'prediction': 'december 23, 1971'},
#  {'id': 1554,
#   'question': 'when did the first fleet arive in australia',
#   'answer': ['18 January 1788', '1788'],
#   'ans_type': 'DATE',
#   'prediction': '18 to 20 january 1788',
#   'human': 1},
#  {'id': 3460,
#   'question': 'one piece english dubbed episode 564 release date',
#   'answer': ['September 16, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'november 3, 2004'},
#  {'id': 125,
#   'question': 'how many seasons of rules of engagement is there',
#   'answer': ['7', 'seven'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven',
#   'human': 1},
#  {'id': 2291,
#   'question': 'one piece episode 534 english dubbed release date',
#   'answer': ['February 5, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'july 24, 2004'},
#  {'id': 1224,
#   'question': 'when does the new saw 8 come out',
#   'answer': ['October 27, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'october 27, 2017',
#   'human': 1},
#  {'id': 1614,
#   'question': 'how many pitchers does a major league team have',
#   'answer': ['five starting pitchers', 'seven relief pitchers'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'five'},
#  {'id': 2382,
#   'question': 'when did ford change the f150 body style',
#   'answer': ['the 2009 model year', '1957'],
#   'ans_type': 'DATE',
#   'prediction': '1997'},
#  {'id': 1903,
#   'question': 'how many lines of symmetry are there in a equilateral triangle',
#   'answer': ['3'],
#   'ans_type': 'CARDINAL',
#   'prediction': '3',
#   'human': 1},
#  {'id': 1467,
#   'question': 'who is the founder of google and when was it founded',
#   'answer': ['1998',
#    'Sergey Brin',
#    'Larry Page',
#    'Larry Page and Sergey Brin'],
#   'ans_type': 'DATE',
#   'prediction': 'september 4, 1998',
#   'human': 1},
#  {'id': 3467,
#   'question': 'when does the nba season end this year',
#   'answer': ['April 11, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'april 11, 2018',
#   'human': 1},
#  {'id': 2737,
#   'question': 'how many seasons of the smurfs are there',
#   'answer': ['9'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'no further series'},
#  {'id': 1624,
#   'question': 'when was the worlds first laptop computer introduced in the market and by whom',
#   'answer': ['September 1980', 'R2E Micral CCMC'],
#   'ans_type': 'DATE',
#   'prediction': 'september 1980',
#   'human': 1},
#  {'id': 3214,
#   'question': 'when will the flash season 4 be released',
#   'answer': ['October 10, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'october 10, 2017',
#   'human': 1},
#  {'id': 481,
#   'question': 'when do the new episodes of supernatural start',
#   'answer': ['May\xa010,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'april 26, 2018'},
#  {'id': 1530,
#   'question': 'when did korea separate into north and south',
#   'answer': ['1945', '17 August 1945'],
#   'ans_type': 'DATE',
#   'prediction': '1948'},
#  {'id': 598,
#   'question': 'when was national service abolished in the uk',
#   'answer': ['1960', 'November 1960', '31 December 1960'],
#   'ans_type': 'DATE',
#   'prediction': '31 december 1960',
#   'human': 1},
#  {'id': 2506,
#   'question': 'when was the last time mount etna exploded',
#   'answer': ['July–October 2012', '16 March 2017'],
#   'ans_type': 'DATE',
#   'prediction': '16 march 2017',
#   'human': 1},
#  {'id': 883,
#   'question': 'how long were the pyramids the tallest structure',
#   'answer': ['over 3,800', 'over 3,800 years'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'for over 3, 800 years',
#   'human': 1},
# ...
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven alphanumeric characters'},
#  {'id': 74,
#   'question': 'when was corporal punishment banned in south africa',
#   'answer': ['1997'],
#   'ans_type': 'DATE',
#   'prediction': '1997',
#   'human': 1},
#  {'id': 1565,
#   'question': 'what is the average salary for a us congressman',
#   'answer': ['$174,000'],
#   'ans_type': 'MONEY',
#   'prediction': '$174,000',
#   'human': 1},
#  {'id': 3072,
#   'question': 'when did red bull come to the united states',
#   'answer': ['1997'],
#   'ans_type': 'DATE',
#   'prediction': '1997',
#   'human': 1},
#  {'id': 3552,
#   'question': 'what episode does marnie come back in geordie shore',
#   'answer': ['5'],
#   'ans_type': 'CARDINAL',
#   'prediction': '12'},
#  {'id': 2018,
#   'question': 'when does the regular season start in mlb',
#   'answer': ['March 29, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'march 29, 2018',
#   'human': 1},
#  {'id': 2228,
#   'question': 'what is the latest version of chrome for linux',
#   'answer': ['67.0.3396', '67.0'],
#   'ans_type': 'CARDINAL',
#   'prediction': '23 august 2015'},
#  {'id': 1174,
#   'question': 'when is the strictly come dancing results show recorded',
#   'answer': ['Saturday', 'Sunday night'],
#   'ans_type': 'DATE',
#   'prediction': 'on saturday',
#   'human': 1},
#  {'id': 1768,
#   'question': 'how old do you have to be to get a gun licence in nz',
#   'answer': ['16 or older'],
#   'ans_type': 'DATE',
#   'prediction': '18'},
#  {'id': 2929,
#   'question': 'when did the cowboys start playing on thanksgiving day',
#   'answer': ['In 1966', '1966', '1978'],
#   'ans_type': 'DATE',
#   'prediction': '1966',
#   'human': 1},
#  {'id': 2889,
#   'question': 'total goals scored by ronaldo in la liga',
#   'answer': ['309'],
#   'ans_type': 'CARDINAL',
#   'prediction': '311'},
#  {'id': 1750,
#   'question': 'how many episodes of sabrina the teenage witch are there',
#   'answer': ['163'],
#   'ans_type': 'CARDINAL',
#   'prediction': '67'},
#  {'id': 783,
#   'question': 'how long are the episodes in stranger things season 1',
#   'answer': ['42–62 minutes'],
#   'ans_type': 'TIME',
#   'prediction': 'eight'},
#  {'id': 724,
#   'question': 'when did reba mcentire record back to god',
#   'answer': ['February 3, 2017', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 2973,
#   'question': 'when did the song the joker come out',
#   'answer': ['1973', 'October 1973'],
#   'ans_type': 'DATE',
#   'prediction': '1973',
#   'human': 1},
#  {'id': 270,
#   'question': 'when was the last year the eagles went to the superbowl',
#   'answer': ['following the 2017 season', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 2801,
#   'question': 'when was the last time the denver nuggets made the playoffs',
#   'answer': ['2012–13', '2009–10', '1994–95'],
#   'ans_type': 'DATE',
#   'prediction': '2012 - - 13'},
#  {'id': 3282,
#   'question': 'when was the r10+20 summit in rio de janeiro held',
#   'answer': ['June 2012', '13 to 22 June 2012'],
#   'ans_type': 'DATE',
#   'prediction': '2012'},
#  {'id': 2031,
#   'question': 'when did toyota first come to the united states',
#   'answer': ['1957'],
#   'ans_type': 'DATE',
#   'prediction': '1957',
#   'human': 1},
#  {'id': 2445,
#   'question': 'when was the first underwater cable laid beneath the english channel',
#   'answer': ['1850'],
#   'ans_type': 'DATE',
#   'prediction': '1851'},
#  {'id': 1995,
#   'question': 'how many wins does tiger woods have on the pga tour',
#   'answer': ['79'],
#   'ans_type': 'CARDINAL',
#   'prediction': '80'},
#  {'id': 715,
#   'question': 'when did they stop saying mass in latin',
#   'answer': ['from 1967 onwards', '1967'],
#   'ans_type': 'DATE',
#   'prediction': '1967',
#   'human': 1},
#  {'id': 1373,
#   'question': 'when does the new adventure time come out',
#   'answer': ['April 21, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 17, 2017'},
#  {'id': 2309,
#   'question': 'when does the 2017 college football season end',
#   'answer': ['December 9, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'december 9, 2017',
#   'human': 1},
#  {'id': 939,
#   'question': 'when was the last time villanova won the ncaa basketball championship',
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'id': 629,
#   'question': 'when did fortnite battle royal come out on xbox',
#   'answer': ['September 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 2017',
#   'human': 1},
#  {'id': 1695,
#   'question': 'wolf of wall street number of f words',
#   'answer': ['569'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'between 506 and 569',
#   'human': 1},
#  {'id': 2184,
#   'question': 'when did chicano studies become major studies programs on college campuses',
#   'answer': ['By 1975', '1972'],
#   'ans_type': 'DATE',
#   'prediction': '1970s'},
#  {'id': 3045,
#   'question': 'how many players in football hall of fame',
#   'answer': ['318', '318 individuals'],
#   'ans_type': 'CARDINAL',
#   'prediction': '318',
#   'human': 1},
#  {'id': 71,
#   'question': "how many games in a row have the uconn women's basketball team won",
#   'answer': ['111 straight wins', '111', '90'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four in a row'},
#  {'id': 458,
#   'question': 'when does like cage season 2 come out',
#   'answer': ['June 22, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'june 22, 2018',
#   'human': 1},
#  {'id': 1160,
#   'question': 'how long is the famous suspension bridge in san francisco and what is it called',
#   'answer': ['one-mile-wide', 'Golden Gate Bridge'],
#   'ans_type': 'QUANTITY',
#   'prediction': 'the golden gate bridge',
#   'human': 1},
#  {'id': 2125,
#   'question': 'how many points are scored for a touchdown in american football',
#   'answer': ['six', 'six points'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'six',
#   'human': 1},
#  {'id': 3445,
#   'question': 'what year did return of the mack come out',
#   'answer': ['18\xa0March\xa01996', 'March 1996', '1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'id': 1218,
#   'question': 'when was the last time the vikings made the superbowl',
#   'answer': ['in the 1970s'],
#   'ans_type': 'DATE',
#   'prediction': 'january 9, 1977'},
#  {'id': 3254,
#   'question': 'university of michigan school of public health ranking',
#   'answer': ['#4'],
#   'ans_type': 'MONEY',
#   'prediction': '#4',
#   'human': 1},
#  {'id': 2256,
#   'question': 'krypton-85 decays by emission of a beta particle. the product of this decay is',
#   'answer': ['rubidium-85'],
#   'ans_type': 'DATE',
#   'prediction': 'gamma ray emission'},
#  {'id': 1844,
#   'question': 'when was the last time a hurricane hit massachusetts',
#   'answer': ['November 3, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'hurricane earl'},
#  {'id': 3479,
#   'question': 'when do new episodes of ncis los angeles return',
#   'answer': ['May\xa013,\xa02018', 'October 1, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'april 30, 2018'},
#  {'id': 770,
#   'question': 'how many episodes in series 7 of game of thrones are there',
#   'answer': ['7', 'seven'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven',
#   'human': 1},
#  {'id': 1342,
#   'question': 'most assists in an nba all star game',
#   'answer': ['60', '22'],
#   'ans_type': 'CARDINAL',
#   'prediction': '22',
#   'human': 1},
#  {'id': 1866,
#   'question': 'when was the movie the king and i made',
#   'answer': ['1956'],
#   'ans_type': 'DATE',
#   'prediction': '1956',
#   'human': 1},
#  {'id': 1451,
#   'question': 'when did the name of bombay change to mumbai',
#   'answer': ['1995'],
#   'ans_type': 'DATE',
#   'prediction': '1995',
#   'human': 1},
#  {'id': 1590,
#   'question': 'when did refrigerator perry play for the bears',
#   'answer': ['1985–1993'],
#   'ans_type': 'DATE',
#   'prediction': '1985 - - 1990'},
#  {'id': 1186,
#   'question': 'when does kubo and the two strings release',
#   'answer': ['August 19, 2016', 'August\xa019,\xa02016'],
#   'ans_type': 'DATE',
#   'prediction': 'august 19, 2016',
#   'human': 1},
#  {'id': 1228,
#   'question': 'when did india win their first cricket match',
#   'answer': ['1952'],
#   'ans_type': 'DATE',
#   'prediction': '25 june 1932'},
#  {'id': 43,
#   'question': 'last episode of what happens to my family',
#   'answer': ['53'],
#   'ans_type': 'CARDINAL',
#   'prediction': "` ` family matters''"},
#  {'id': 2659,
#   'question': 'when does the flash season 4 episode 3 air',
#   'answer': ['October\xa024,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'november 19, 2017'},
#  {'id': 3256,
#   'question': 'when was the immigration act passed in canada',
#   'answer': ['1923'],
#   'ans_type': 'DATE',
#   'prediction': 'july 1, 1867'},
#  {'id': 1664,
#   'question': 'when was the last time stock market crashed',
#   'answer': ['27 Oct 1997', '18 August 2015'],
#   'ans_type': 'DATE',
#   'prediction': 'september 16, 2008'},
#  {'id': 1600,
#   'question': 'when was the movie the wizard of oz made',
#   'answer': ['1939', 'August\xa025,\xa01939'],
#   'ans_type': 'DATE',
#   'prediction': '1939',
#   'human': 1},
#  {'id': 2571,
#   'question': 'when did the movie peter pan come out',
#   'answer': ['2003', '25\xa0December\xa02003'],
#   'ans_type': 'DATE',
#   'prediction': '1953'},
#  {'id': 167,
#   'question': 'when was united nations convention on the rights of the child created',
#   'answer': ['20 November 1989'],
#   'ans_type': 'DATE',
#   'prediction': '20 november 1989',
#   'human': 1},
#  {'id': 2486,
#   'question': 'when does planet of the apes come out 2017',
#   'answer': ['July 14, 2017', 'July\xa014,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'july 14, 2017',
#   'human': 1},
#  {'id': 193,
#   'question': 'when does body temperature tend to be lowest',
#   'answer': ['11 p.m. to 3 a.m.'],
#   'ans_type': 'TIME',
#   'prediction': 'around 4 a. m.'},
#  {'id': 2337,
#   'question': 'when was the last time michigan basketball won the championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 1},
#  {'id': 2869,
#   'question': 'how many games does a football team have to win to be bowl eligible',
#   'answer': ['5'],
#   'ans_type': 'CARDINAL',
#   'prediction': '5 - 7',
#   'human': 1},
#  {'id': 1071,
#   'question': 'when did muhammad ali win an olympic gold medal',
#   'answer': ['1960'],
#   'ans_type': 'DATE',
#   'prediction': '1960',
#   'human': 1},
#  {'id': 3267,
#   'question': 'when did cybermen first appear in doctor who',
#   'answer': ['in 1966', '1966'],
#   'ans_type': 'DATE',
#   'prediction': '1966',
#   'human': 1},
#  {'id': 1411,
#   'question': "who played joey's agent estelle on friends",
#   'answer': ['June Gable'],
#   'ans_type': 'DATE',
#   'prediction': 'june gable',
#   'human': 1},
#  {'id': 1430,
#   'question': 'when does season 8 for blue bloods start',
#   'answer': ['September 29, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'september 29, 2017',
#   'human': 1},
#  {'id': 2231,
#   'question': 'how many nfl games were played in london',
#   'answer': ['21'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four'},
#  {'id': 47,
#   'question': 'when was the last time oklahoma won a national championship in football',
#   'answer': ['2003', '2000'],
#   'ans_type': 'DATE',
#   'prediction': '2000',
#   'human': 1},
#  {'id': 1181,
#   'question': 'how many quarterbacks have a receiving touchdown in the superbowl',
#   'answer': ['1'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'roger staubach'},
#  {'id': 2371,
#   'question': "when does the men's worlds curling start",
#   'answer': ['March 31'],
#   'ans_type': 'DATE',
#   'prediction': 'march 31',
#   'human': 1},
#  {'id': 3350,
#   'question': 'what is the minimum dollar amount for federal court',
#   'answer': ['$75,000'],
#   'ans_type': 'MONEY',
#   'prediction': '$75,000',
#   'human': 1},
#  {'id': 1571,
#   'question': 'when does season 3 of the riveras start',
#   'answer': ['March\xa011,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'in 2018'},
#  {'id': 1025,
#   'question': 'when did the us dollar leave the gold standard',
#   'answer': ['October 1976', 'August 15, 1971', '1934'],
#   'ans_type': 'DATE',
#   'prediction': 'october 1976',
#   'human': 1},
#  {'id': 2522,
#   'question': 'what is the salary of us secretary of state',
#   'answer': ['$205,700', '$205,700 annually'],
#   'ans_type': 'MONEY',
#   'prediction': '$ 210, 700'},
#  {'id': 3073,
#   'question': 'how long has tom brady been the patriots quarterback',
#   'answer': ['2001', '16 seasons'],
#   'ans_type': 'DATE',
#   'prediction': '18 - season career'},
#  {'id': 1343,
#   'question': 'when is the next episode of flash airing',
#   'answer': ['May\xa08,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'october 10, 2017'},
#  {'id': 2043,
#   'question': 'when does zay come to girl meets world',
#   'answer': ['May\xa013,\xa02015'],
#   'ans_type': 'DATE',
#   'prediction': "` ` sparks fly''"},
#  {'id': 1605,
#   'question': 'when does the sword art online movie take place',
#   'answer': ['2026', 'the year 2026'],
#   'ans_type': 'CARDINAL',
#   'prediction': '2026',
#   'human': 1},
#  {'id': 2639,
#   'question': 'when did come fly with me come out',
#   'answer': ['25 December 2010'],
#   'ans_type': 'DATE',
#   'prediction': '1958'},
#  {'id': 2937,
#   'question': 'when was the first time the internet was used',
#   'answer': ['1969', 'November 22, 1977'],
#   'ans_type': 'DATE',
#   'prediction': '1969',
#   'human': 1},
#  {'id': 2719,
#   'question': 'when are the next commonwealth games going to be held',
#   'answer': ['2022'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 2688,
#   'question': 'when is the last time congress passed a complete budget',
#   'answer': ['FY2010', 'March 23, 2013'],
#   'ans_type': 'DATE',
#   'prediction': '1997'},
#  {'id': 266,
#   'question': 'when did the united states host the world cup',
#   'answer': ['1994'],
#   'ans_type': 'DATE',
#   'prediction': '1994',
#   'human': 1},
#  {'id': 1370,
#   'question': 'when does the mlb season start and finish',
#   'answer': ['March 29', 'October 31, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'march 29, 2018',
#   'human': 1},
#  {'id': 657,
#   'question': "what is alpha centauri's approximate distance from earth",
#   'answer': ['4.37 light-years'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'about 13, 000 astronomical units'},
#  {'id': 2008,
#   'question': 'what is the current rate of interest on ppf',
#   'answer': ['7.6% Per Annum', '7.6%'],
#   'ans_type': 'PERCENT',
#   'prediction': '8. 0 %'},
#  {'id': 1665,
#   'question': 'during which season does cape town receive rainfall',
#   'answer': ['winter', 'summer'],
#   'ans_type': 'DATE',
#   'prediction': 'winter',
#   'human': 1},
#  {'id': 386,
#   'question': 'when is the met office leaving the bbc',
#   'answer': ['31 March 2018'],
#   'ans_type': 'DATE',
#   'prediction': '23 august 2015'},
#  {'id': 1287,
#   'question': "when did the song rapper's delight come out",
#   'answer': ['1979', 'September 16, 1979'],
#   'ans_type': 'DATE',
#   'prediction': '1979',
#   'human': 1},
#  {'id': 642,
#   'question': 'when was kudzu introduced to the united states',
#   'answer': ['1876', 'in 1876'],
#   'ans_type': 'DATE',
#   'prediction': '1876',
#   'human': 1},
#  {'id': 1714,
#   'question': 'dark parables return of the salt princess release date',
#   'answer': ['September 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'march 15, 2018'},
#  {'id': 2413,
#   'question': 'when did the broncos win the super bowl',
#   'answer': ['1998', '2015', '1997'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 1},
#  {'id': 2387,
#   'question': "when does ellen's new game show start",
#   'answer': ['December 18, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'january 2, 2018'},
#  {'id': 2908,
#   'question': 'when was the last time that the eagles were at the super bowl',
#   'answer': ['2017', '2017 season'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 1434,
#   'question': 'how many times have the golden state warriors been to the playoffs',
#   'answer': ['nine'],
#   'ans_type': 'CARDINAL',
#   'prediction': '64'},
#  {'id': 683,
#   'question': 'when did beds become popular in france and germany',
#   'answer': ['the 12th century'],
#   'ans_type': 'DATE',
#   'prediction': 'the 18th century'},
#  {'id': 1623,
#   'question': 'who invented the printing press and what year',
#   'answer': ['circa 1439', 'Johannes Gutenberg'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'circa 1439',
#   'human': 1}]

# %%
rd150
# Out:
# [{'question': 'what was the population of the roman empire at its height',
#   'answer': ['50 to 90\xa0million inhabitants',
#    '70\xa0million',
#    '55–60 million',
#    'an estimated 70\xa0million people'],
#   'ans_type': 'CARDINAL',
#   'prediction': '70 million people',
#   'human': 1},
#  {'question': 'when does wonder woman come out on blue ray',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 19, 2017',
#   'human': 1},
#  {'question': 'when was the tower of london finished being built',
#   'answer': ['1078'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1078',
#   'human': 1},
#  {'question': 'how many times have the winter olympics been in the usa since 1924',
#   'answer': ['1960', '2002', 'four', 'four times', '1932', '1980'],
#   'ans_type': 'DATE',
#   'prediction': 'four',
#   'human': 1},
#  {'question': 'when will the la sagrada familia be finished',
#   'answer': ['by 2026', '2026', '2026–2028'],
#   'ans_type': 'DATE',
#   'prediction': '2026',
#   'human': 1},
#  {'question': 'when did canada get rid of the death penalty',
#   'answer': ['July 14, 1976', '1976', '1998'],
#   'ans_type': 'DATE',
#   'prediction': 'July 14, 1976',
#   'human': 1},
#  {'question': 'when does rick and morty play on tv',
#   'answer': ['late-night'],
#   'ans_type': 'TIME',
#   'prediction': 'April 1, 2017',
#   'human': 0},
#  {'question': 'when was the last time the seattle seahawks won the superbowl',
#   'answer': ['2013'],
#   'ans_type': 'DATE',
#   'prediction': '2013',
#   'human': 1},
#  {'question': 'how many grams of alcohol in one beer',
#   'answer': ['14', 'about 14 grams of alcohol', '14 grams'],
#   'ans_type': 'CARDINAL',
#   'prediction': '15.2',
#   'human': 0},
#  {'question': 'when will the next episode of flash be aired',
#   'answer': ['May\xa015,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2017',
#   'human': 0},
#  {'question': 'where does the donkey talk in the bible',
#   'answer': ['Numbers 22:28'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Numbers 22:28',
#   'human': 1},
#  {'question': 'when does the new season of lost in space come out',
#   'answer': ['April 13, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'April 13, 2018',
#   'human': 1},
#  {'question': 'when is the flash coming back after christmas',
#   'answer': ['January\xa016,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'question': 'when did hollywood video go out of business',
#   'answer': ['2005.', 'May 2010'],
#   'ans_type': 'DATE',
#   'prediction': 'May 2010',
#   'human': 1},
#  {'question': 'when is the opening ceremonies of the olympics 2018',
#   'answer': ['9 February 2018'],
#   'ans_type': 'DATE',
#   'prediction': '9 February 2018',
#   'human': 1},
#  {'question': "when does season 13 of america's got talent premiere",
#   'answer': ['May 29, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'May 29, 2018',
#   'human': 1},
#  {'question': 'when does season 8 of shameless come back',
#   'answer': ['November 5, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'November 8, 2017',
#   'human': 0},
#  {'question': 'the atomic number of indium which belongs to 5th period is',
#   'answer': ['49'],
#   'ans_type': 'CARDINAL',
#   'prediction': '49',
#   'human': 1},
#  {'question': 'when did the tv show the waltons first air',
#   'answer': ['September 1972'],
#   'ans_type': 'DATE',
#   'prediction': 'September 1972',
#   'human': 1},
#  {'question': 'when did the smoking ban in public places start',
#   'answer': ['August 2, 1990', '1995'],
#   'ans_type': 'DATE',
#   'prediction': '1 June 2013',
#   'human': 0},
#  {'question': 'when does the good doctor episode 8 air',
#   'answer': ['November\xa020,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 0},
#  {'question': 'when was the cleveland browns last winning game',
#   'answer': ['2016'],
#   'ans_type': 'DATE',
#   'prediction': '2016',
#   'human': 1},
#  {'question': 'when is season 2 of jessica jones being released',
#   'answer': ['March 8, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'March 8, 2018',
#   'human': 1},
#  {'question': 'what is the share of agriculture in indian economy',
#   'answer': ['17.32%', '23%'],
#   'ans_type': 'PERCENT',
#   'prediction': '15.4%',
#   'human': 0},
#  {'question': 'the old man and the sea page count',
#   'answer': ['127'],
#   'ans_type': 'CARDINAL',
#   'prediction': '173',
#   'human': 0},
#  {'question': 'how many strong verbs are there in german',
#   'answer': ['more than 200', 'more than 200 strong'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'two',
#   'human': 0},
#  {'question': "what's the nba record for most points in a half",
#   'answer': ['59'],
#   'ans_type': 'CARDINAL',
#   'prediction': '58',
#   'human': 0},
#  {'question': 'when did where are you now come out',
#   'answer': ['February 27, 2015', 'February\xa027,\xa02015'],
#   'ans_type': 'DATE',
#   'prediction': 'February 27, 2015',
#   'human': 1},
#  {'question': "when did i'm like a bird come out",
#   'answer': ['October\xa024,\xa02000'],
#   'ans_type': 'DATE',
#   'prediction': '2001',
#   'human': 0},
#  {'question': 'how old is baby in dirty dancing movie',
#   'answer': ['17-year-old', '17'],
#   'ans_type': 'DATE',
#   'prediction': '17',
#   'human': 1},
#  {'question': 'when did krakow become the capital of poland',
#   'answer': ['1038'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1596',
#   'human': 0},
#  {'question': 'when was the peak to peak gondola built',
#   'answer': ['in 2007 and 2008'],
#   'ans_type': 'DATE',
#   'prediction': '2007',
#   'human': 1},
#  {'question': 'when did the black death end in england',
#   'answer': ['December 1349'],
#   'ans_type': 'DATE',
#   'prediction': 'December 1349',
#   'human': 1},
#  {'question': 'when is the end of the football season',
#   'answer': ['February 4, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'December or early January',
#   'human': 0},
#  {'question': 'when did the song holiday road come out',
#   'answer': ['1983', 'June 24, 1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'question': 'when did world war one begin and end',
#   'answer': ['28 July 1914', '11 November 1918'],
#   'ans_type': 'DATE',
#   'prediction': '28 July 1914',
#   'human': 1},
#  {'question': 'when did the celebrities enter the big brother house',
#   'answer': ['February\xa07,\xa02018', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'question': 'when was the first book made into a movie',
#   'answer': ['1924'],
#   'ans_type': 'DATE',
#   'prediction': '1940',
#   'human': 0},
#  {'question': 'when did marathon change its name to snickers',
#   'answer': ['19 July 1990'],
#   'ans_type': 'DATE',
#   'prediction': '1990',
#   'human': 1},
#  {'question': 'how many episodes in season 2 of fargo',
#   'answer': ['10', 'ten'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'ten',
#   'human': 1},
#  {'question': 'when will miraculous ladybug season 2 episode 12 come out',
#   'answer': ['30\xa0March\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'question': 'when was the last time new zealand had an earthquake',
#   'answer': ['11 Jul 2017'],
#   'ans_type': 'DATE',
#   'prediction': '2016',
#   'human': 0},
#  {'question': 'when did avatar the last airbender first air',
#   'answer': ['February 2005', 'February 21, 2005', 'February\xa021,\xa02005'],
#   'ans_type': 'DATE',
#   'prediction': 'February 21, 2005',
#   'human': 1},
#  {'question': 'when did the dust bowl end in oklahoma',
#   'answer': ['1940'],
#   'ans_type': 'DATE',
#   'prediction': '1939',
#   'human': 0},
#  {'question': 'when did they stop making the nissan xterra',
#   'answer': ['2015', 'after the 2015 model year'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 1},
#  {'question': 'when did seattle slew win the triple crown',
#   'answer': ['1977', 'in 1977'],
#   'ans_type': 'DATE',
#   'prediction': '1977',
#   'human': 1},
#  {'question': 'when did the golden state warriors win the finals',
#   'answer': ['1947', '1975', '1956', '2015', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'question': 'when was the last time.michigan beat ohio state',
#   'answer': ['2011'],
#   'ans_type': 'DATE',
#   'prediction': '2011',
#   'human': 1},
#  {'question': 'when was the first ford f 150 made',
#   'answer': ['1975'],
#   'ans_type': 'DATE',
#   'prediction': '1948',
#   'human': 0},
#  {'question': 'how many steps does the cn tower have',
#   'answer': ['2,579 steps', '2,579'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1,776',
#   'human': 0},
#  {'question': 'when was the first mad max movie release',
#   'answer': ['12\xa0April\xa01979', 'April 1979', '1979'],
#   'ans_type': 'DATE',
#   'prediction': '1979',
#   'human': 1},
#  {'question': 'when did mcgee became a regular on ncis',
#   'answer': ['in season two', 'season two'],
#   'ans_type': 'DATE',
#   'prediction': 'season two',
#   'human': 1},
#  {'question': 'when was nepal declared a secular state in bs',
#   'answer': ['January 15, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'January 2007',
#   'human': 1},
#  {'question': 'how many nfl teams has st louis had',
#   'answer': ['four'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'two',
#   'human': 0},
#  {'question': 'when do the walking dead comics come out',
#   'answer': ['October\xa02003\xa0– present', '2003'],
#   'ans_type': 'DATE',
#   'prediction': 'monthly',
#   'human': 0},
#  {'question': 'how much venom can a king cobra produce',
#   'answer': ['420\xa0mg', 'up to 7\xa0ml', '200 to 500\xa0mg'],
#   'ans_type': 'QUANTITY',
#   'prediction': '420 mg',
#   'human': 1},
#  {'question': 'when did response to state of the union start',
#   'answer': ['in 1966', '1966'],
#   'ans_type': 'DATE',
#   'prediction': '1966',
#   'human': 1},
#  {'question': 'how many ammendments to the constitution have there been',
#   'answer': ['Twenty-seven', 'Thirty-three'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Twenty-seven',
#   'human': 1},
#  {'question': 'when did the continental congress vote to adopt the declaration of independence',
#   'answer': ['July 2, 1776'],
#   'ans_type': 'DATE',
#   'prediction': 'July 4, 1776',
#   'human': 0},
#  {'question': 'how long did it take to build the great pyramid of egypt',
#   'answer': ['20-year period'],
#   'ans_type': 'DATE',
#   'prediction': '20 years',
#   'human': 1},
#  {'question': 'when do they put the rockefeller tree up',
#   'answer': ['mid November', 'late November or early December'],
#   'ans_type': 'DATE',
#   'prediction': 'mid November',
#   'human': 1},
#  {'question': 'what year does the quiet man take place',
#   'answer': ['the 1920s', 'In the 1920s'],
#   'ans_type': 'DATE',
#   'prediction': '1920s',
#   'human': 1},
#  {'question': 'when did fortnite save the world first come out',
#   'answer': ['July 25, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'July 25, 2017',
#   'human': 1},
#  {'question': 'what episode does goku give up against cell',
#   'answer': ['165', '180'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Dragon Ball GT',
#   'human': 0},
#  {'question': 'when was the last time tug-of-war was an official olympic sport',
#   'answer': ['1920'],
#   'ans_type': 'DATE',
#   'prediction': '1920',
#   'human': 1},
#  {'question': 'when was the first orca put in captivity',
#   'answer': ['in the 1960s', 'November 1961'],
#   'ans_type': 'DATE',
#   'prediction': '1960s',
#   'human': 1},
#  {'question': 'what age do you need to be to buy a bb gun',
#   'answer': ['18'],
#   'ans_type': 'CARDINAL',
#   'prediction': '18',
#   'human': 1},
#  {'question': 'when does the team find out prentiss is alive',
#   'answer': ['In the season seven premiere', 'the season seven premiere'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'season seven premiere',
#   'human': 1},
#  {'question': 'when did john hart play the lone ranger',
#   'answer': ['from 1952 until 1953'],
#   'ans_type': 'DATE',
#   'prediction': '1952',
#   'human': 1},
#  {'question': 'how many times have real madrid won the european cup.in paris',
#   'answer': ['twelve'],
#   'ans_type': 'CARDINAL',
#   'prediction': '13',
#   'human': 0},
#  {'question': 'when was theme from a summer place released',
#   'answer': ['1960', '1959', 'September 1959'],
#   'ans_type': 'DATE',
#   'prediction': '1959',
#   'human': 1},
#  {'question': 'when did how you remind me come out',
#   'answer': ['August\xa021,\xa02001', 'August 21, 2001'],
#   'ans_type': 'DATE',
#   'prediction': 'August 21, 2001',
#   'human': 1},
#  {'question': 'when does kc undercover season 3 episode 10 air',
#   'answer': ['November\xa010,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'July 7, 2017',
#   'human': 0},
#  {'question': 'when was the last time ny rangers won stanley cup',
#   'answer': ['1993–94'],
#   'ans_type': 'DATE',
#   'prediction': '1993 -- 94',
#   'human': 1},
#  {'question': 'who does the democratic republic of congo trade with',
#   'answer': ['Group of 77',
#    'WTO',
#    'Zimbabwe',
#    'Belgium',
#    'SADC',
#    'Kenya',
#    'South Africa',
#    'China',
#    'AU',
#    'Zambia',
#    'IMF',
#    'World Bank',
#    'African Development Bank',
#    'France'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'China',
#   'human': 1},
#  {'question': 'how many dominoes do you need for mexican train',
#   'answer': ['A double-twelve set'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'A double-twelve set',
#   'human': 1},
#  {'question': 'when was the debating club established in almora',
#   'answer': ['1871 A.D.', '1871'],
#   'ans_type': 'DATE',
#   'prediction': '1575',
#   'human': 0},
#  {'question': "when did billy don't be a hero come out",
#   'answer': ['1974'],
#   'ans_type': 'DATE',
#   'prediction': '1974',
#   'human': 1},
#  {'question': 'when did all night long come out lionel richie',
#   'answer': ['1983', 'August 31, 1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'question': "when did korn's follow the leader come out",
#   'answer': ['August 18, 1998'],
#   'ans_type': 'DATE',
#   'prediction': 'August 18, 1998',
#   'human': 1},
#  {'question': 'when did the jurassic park movies come out',
#   'answer': ['Jurassic Park (1993)',
#    '2001',
#    '2015',
#    '2018',
#    '1993',
#    'Jurassic World (2015)',
#    '1997'],
#   'ans_type': 'DATE',
#   'prediction': '1993',
#   'human': 1},
#  {'question': 'what percentage of sunlight is captured by plants to convert it into food energy',
#   'answer': ['45%', '3 to 6%'],
#   'ans_type': 'PERCENT',
#   'prediction': 'approximately 130 terawatts',
#   'human': 0},
#  {'question': 'when was the last summer olympics in the usa',
#   'answer': ['1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'question': 'when did the revolution begin in the united states',
#   'answer': ['1775', '1765'],
#   'ans_type': 'DATE',
#   'prediction': 'April 1775',
#   'human': 1},
#  {'question': 'how many seasons has greys anatomy been on tv',
#   'answer': ['14'],
#   'ans_type': 'CARDINAL',
#   'prediction': '14',
#   'human': 1},
#  {'question': 'how many pennsylvania house of representatives are there',
#   'answer': ['203', '203 members'],
#   'ans_type': 'CARDINAL',
#   'prediction': '203',
#   'human': 1},
#  {'question': 'what is small business tax rate in canada',
#   'answer': ['10.5%'],
#   'ans_type': 'PERCENT',
#   'prediction': '10%',
#   'human': 0},
#  {'question': 'how many customers does edf have in the uk',
#   'answer': ['5.7 million customer accounts', '5.7 million'],
#   'ans_type': 'CARDINAL',
#   'prediction': '5.7 million',
#   'human': 1},
#  {'question': 'when does the new season of are you the one come on',
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': 'August 15, 2018',
#   'human': 1},
#  {'question': 'how long has tom brady been playing professional football',
#   'answer': ['18-season career'],
#   'ans_type': 'DATE',
#   'prediction': '18-season',
#   'human': 1},
#  {'question': 'when did red dead redemption 1 come out',
#   'answer': ['May 18, 2010', 'May 2010'],
#   'ans_type': 'DATE',
#   'prediction': 'May 2010',
#   'human': 1},
#  {'question': 'season 2 attack on titan how many episodes',
#   'answer': ['12'],
#   'ans_type': 'CARDINAL',
#   'prediction': '12',
#   'human': 1},
#  {'question': 'when did bird is the word come out',
#   'answer': ['1963'],
#   'ans_type': 'DATE',
#   'prediction': '1963',
#   'human': 1},
#  {'question': 'how many co2 molecules are produced in aerobic respiration',
#   'answer': ['6'],
#   'ans_type': 'CARDINAL',
#   'prediction': '6',
#   'human': 1},
#  {'question': 'what time can you legally buy alcohol in michigan',
#   'answer': ['7 a.m.'],
#   'ans_type': 'TIME',
#   'prediction': 'after noon',
#   'human': 0},
#  {'question': 'when did the nfl adopt a salary cap',
#   'answer': ['the 1994 season', 'for the 1994 season', '1994', '1994 season'],
#   'ans_type': 'DATE',
#   'prediction': 'the 1994 season',
#   'human': 1},
#  {'question': 'when did the ouija board first come out',
#   'answer': ['July 1, 1890'],
#   'ans_type': 'DATE',
#   'prediction': 'July 1, 1890',
#   'human': 1},
#  {'question': 'when is season 4 of flash coming out',
#   'answer': ['October 10, 2017', 'on October 10, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2017',
#   'human': 1},
#  {'question': 'when did little polveir win the grand national',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 0},
#  {'question': 'when is the womens ice skating for the olympics',
#   'answer': ['21 February', '21–23 February', '23 February'],
#   'ans_type': 'DATE',
#   'prediction': '21 February',
#   'human': 1},
#  {'question': 'when did toyota start making cars in the us',
#   'answer': ['by the early 1980s', '1984'],
#   'ans_type': 'DATE',
#   'prediction': '1984',
#   'human': 1},
#  {'question': 'how many points did lebron james scored in his career',
#   'answer': ['31,038'],
#   'ans_type': 'CARDINAL',
#   'prediction': '30,000',
#   'human': 0},
#  {'question': 'when was to god be the glory written',
#   'answer': ['around 1872'],
#   'ans_type': 'DATE',
#   'prediction': 'around 1872',
#   'human': 1},
#  {'question': 'when does wentworth season 6 start in australia',
#   'answer': ['2019', '19 June 2018'],
#   'ans_type': 'DATE',
#   'prediction': '19 June 2018',
#   'human': 1},
#  {'question': 'when does star trek discovery air on tv',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 24, 2017',
#   'human': 0},
#  {'question': 'what is the current population of bora bora',
#   'answer': ['10,605'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'approximately 2,000 people',
#   'human': 0},
#  {'question': 'how many countries are a part of opec',
#   'answer': ['14'],
#   'ans_type': 'CARDINAL',
#   'prediction': '15',
#   'human': 0},
#  {'question': 'when did vat change from 17.5 to 20',
#   'answer': ['4 January 2011'],
#   'ans_type': 'DATE',
#   'prediction': '4 January 2011',
#   'human': 1},
#  {'question': 'when was the first super bowl the eagles ever won',
#   'answer': ['2017', '1948'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'question': 'when was harry potter and the philosophers stone published',
#   'answer': ['in 1997', '1997'],
#   'ans_type': 'DATE',
#   'prediction': '1998',
#   'human': 0},
#  {'question': 'when did a wrinkle in time start filming',
#   'answer': ['November 2, 2016'],
#   'ans_type': 'DATE',
#   'prediction': 'November 2, 2016',
#   'human': 1},
#  {'question': 'when was the original stephen king it movie made',
#   'answer': ['1990'],
#   'ans_type': 'DATE',
#   'prediction': '1990',
#   'human': 1},
#  {'question': 'when did the first pokemon game come out',
#   'answer': ['October 2000', '1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'question': 'when is the next step season 3 coming out',
#   'answer': ['March\xa016,\xa02015'],
#   'ans_type': 'DATE',
#   'prediction': 'March 16, 2015',
#   'human': 1},
#  {'question': 'when is if loving you is wrong coming back season 4',
#   'answer': ['September\xa019,\xa02017', 'March\xa07,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'September 19, 2017',
#   'human': 1},
#  {'question': 'when was the first nuclear power plant opened',
#   'answer': ['December 20, 1951',
#    'June 27, 1954',
#    'On June 27, 1954',
#    'the USSR',
#    'December 2, 1942'],
#   'ans_type': 'DATE',
#   'prediction': 'June 27, 1954',
#   'human': 1},
#  {'question': 'what is the angle of the tower of pisa',
#   'answer': ['about 3.99 degrees', '3.99 degrees', 'at about 3.99 degrees'],
#   'ans_type': 'QUANTITY',
#   'prediction': '5.5 degrees',
#   'human': 0},
#  {'question': 'how many hoops are used in a game of croquet',
#   'answer': ['six', 'eight'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'six',
#   'human': 1},
#  {'question': 'how many national parks are present in india',
#   'answer': ['103'],
#   'ans_type': 'CARDINAL',
#   'prediction': '105',
#   'human': 0},
#  {'question': 'how many seasons are there for lost girl',
#   'answer': ['5', 'five'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'five',
#   'human': 1},
#  {'question': 'when was the japanese videogame company nintendo founded',
#   'answer': ['23 September 1889'],
#   'ans_type': 'DATE',
#   'prediction': '23 September 1889',
#   'human': 1},
#  {'question': 'how long is a whale shark in meters',
#   'answer': ['12.65\xa0m', 'estimated at 9.7\xa0m', '9.7\xa0m'],
#   'ans_type': 'QUANTITY',
#   'prediction': 'approximately',
#   'human': 0},
#  {'question': 'when did season 4 of glee come out',
#   'answer': ['September 13, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'September 13, 2012',
#   'human': 1},
#  {'question': 'when did one child policy end in china',
#   'answer': ['January 1, 2016'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 0},
#  {'question': 'when does the little couples new season start',
#   'answer': ['September 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 19, 2017',
#   'human': 1},
#  {'question': 'when was the biltmore house opened to the public',
#   'answer': ['March 1930'],
#   'ans_type': 'DATE',
#   'prediction': 'March 1930',
#   'human': 1},
#  {'question': 'rizal finished all the chapters of the novel noli me tangere in',
#   'answer': ['December 1886', 'Spanish'],
#   'ans_type': 'DATE',
#   'prediction': 'December 1886',
#   'human': 1},
#  {'question': 'when did harvard become an ivy league school',
#   'answer': ['1945'],
#   'ans_type': 'DATE',
#   'prediction': '1755',
#   'human': 0},
#  {'question': 'when did day light savings start in the us',
#   'answer': ['March 31, 1918', '1918', 'March 19, 1918', 'March\xa011'],
#   'ans_type': 'DATE',
#   'prediction': '1967',
#   'human': 0},
#  {'question': 'what channel is abc on in phoenix arizona',
#   'answer': ['15'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Fox Sports Arizona',
#   'human': 0},
#  {'question': 'when did the log flume closed at alton towers',
#   'answer': ['10\xa0October\xa02015', '2015'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 1},
#  {'question': 'when does the new death of superman come out',
#   'answer': ['2019', '2018', 'in 2018 and 2019', 'late 2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'question': 'the chinese dragons are protectors of how many seas diggy',
#   'answer': ['Four Seas', 'Four'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Four',
#   'human': 1},
#  {'question': 'when did the last volcano erupt in iceland',
#   'answer': ['2010'],
#   'ans_type': 'DATE',
#   'prediction': '2004',
#   'human': 0},
#  {'question': 'when did teenage mutant ninja turtles come out',
#   'answer': ['1984'],
#   'ans_type': 'DATE',
#   'prediction': 'May 1984',
#   'human': 1},
#  {'question': 'when did slave to the rhythm come out',
#   'answer': ['May\xa08,\xa02014', '2010'],
#   'ans_type': 'DATE',
#   'prediction': '1985',
#   'human': 0},
#  {'question': 'when does the black panther movie soundtrack come out',
#   'answer': ['February 9, 2018', 'February 16, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'February 9, 2018',
#   'human': 1},
#  {'question': 'when did hollywood become the centre of the film industry',
#   'answer': ['1912', 'By 1912'],
#   'ans_type': 'DATE',
#   'prediction': '1920s',
#   'human': 0},
#  {'question': 'when was the last time someone won the super bowl back to back',
#   'answer': ['2004'],
#   'ans_type': 'DATE',
#   'prediction': '2003 -- 2004',
#   'human': 1},
#  {'question': 'when did canada sign the un declaration of indigenous rights',
#   'answer': ['May 2016', '12 November 2010'],
#   'ans_type': 'DATE',
#   'prediction': '2016',
#   'human': 1},
#  {'question': 'when was the death penalty reinstated in oregon',
#   'answer': ['1984'],
#   'ans_type': 'DATE',
#   'prediction': '1978',
#   'human': 0},
#  {'question': 'when does south by southwest start in austin texas',
#   'answer': ['mid-March'],
#   'ans_type': 'DATE',
#   'prediction': 'mid-March',
#   'human': 1},
#  {'question': 'when did the uk and us become allies',
#   'answer': ['Since 1940', '1940'],
#   'ans_type': 'DATE',
#   'prediction': '1940',
#   'human': 1},
#  {'question': "when's the last time scotland won the calcutta cup",
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'question': 'love is not love that alters when it alteration finds meaning',
#   'answer': ['Sonnet 116'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'A mondegreen',
#   'human': 0},
#  {'question': 'when was the last time giants won superbowl',
#   'answer': ['2011'],
#   'ans_type': 'DATE',
#   'prediction': '2011',
#   'human': 1},
#  {'question': 'how many indian astronauts have gone to space',
#   'answer': ['2'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'one',
#   'human': 0},
#  {'question': 'when did the steel mills closed in youngstown ohio',
#   'answer': ['September 19, 1977'],
#   'ans_type': 'DATE',
#   'prediction': 'September 19, 1977',
#   'human': 1},
#  {'id': 2351,
#   'question': 'when was the abacus invented in ancient china',
#   'answer': ['2nd century BC'],
#   'ans_type': 'DATE',
#   'prediction': '2nd century BC',
#   'human': 1},
#  {'id': 2792,
#   'question': "when did australia 2 win the america's cup",
#   'answer': ['1983'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'id': 282,
#   'question': 'when was a series of unfortunate events published',
#   'answer': ['September 1999'],
#   'ans_type': 'DATE',
#   'prediction': 'September 30, 1999'},
#  {'id': 992,
#   'question': 'how many seasons of from dusk till dawn are there',
#   'answer': ['third season'],
#   'ans_type': 'DATE',
#   'prediction': '6'},
#  {'id': 459,
#   'question': 'when did frank sinatra first sing new york new york',
#   'answer': ['1980', '1979'],
#   'ans_type': 'DATE',
#   'prediction': 'October 1978'},
#  {'id': 2823,
#   'question': 'mount and blade with fire and sword time period',
#   'answer': ['1648-51'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'early modern Europe'},
#  {'id': 1828,
#   'question': 'how many us states currently use capital punishment',
#   'answer': ['31 states', '31'],
#   'ans_type': 'CARDINAL',
#   'prediction': '31',
#   'human': 1},
#  {'id': 771,
#   'question': 'how many gallons of water in the gulf of mexico',
#   'answer': ['660 quadrillion US gallons'],
#   'ans_type': 'QUANTITY',
#   'prediction': '660 quadrillion US gallons',
#   'human': 1},
#  {'id': 2007,
#   'question': 'when was the mission san antonio de valero built',
#   'answer': ['the 18th century', '1718'],
#   'ans_type': 'DATE',
#   'prediction': 'May 1, 1718',
#   'human': 1},
#  {'id': 1806,
#   'question': 'when did end of the road come out',
#   'answer': ['1992', 'June\xa030,\xa01992'],
#   'ans_type': 'DATE',
#   'prediction': '1992',
#   'human': 1},
#  {'id': 2864,
#   'question': 'when did linkin park release one more light',
#   'answer': ['May 19, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'October 3, 2017'},
#  {'id': 3340,
#   'question': 'when is season 7 race to the edge coming out',
#   'answer': ['February 16, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'February 16, 2018',
#   'human': 1},
#  {'id': 1964,
#   'question': 'how many series of diary of a wimpy kid are there',
#   'answer': ['12'],
#   'ans_type': 'CARDINAL',
#   'prediction': '13'},
#  {'id': 2892,
#   'question': 'when did south sudan join east african community',
#   'answer': ['April 2016', '2016'],
#   'ans_type': 'DATE',
#   'prediction': 'April 2016',
#   'human': 1},
#  {'id': 994,
#   'question': 'when did martial law in the philippines end',
#   'answer': ['1981', '81'],
#   'ans_type': 'DATE',
#   'prediction': '17 January 1981',
#   'human': 1},
#  {'id': 3088,
#   'question': 'when does the second half of vikings season 5 air',
#   'answer': ['2018', 'in 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'November 28, 2018',
#   'human': 1},
#  {'id': 243,
#   'question': "a single period of precession of earth's axis is completed in about",
#   'answer': ['approximately 26,000 years', '26,000 years'],
#   'ans_type': 'DATE',
#   'prediction': '26,000 years',
#   'human': 1},
#  {'id': 136,
#   'question': 'how tall is the actor who plays hagrid in harry potter',
#   'answer': ['6ft 1in'],
#   'ans_type': 'QUANTITY',
#   'prediction': 'Robbie Coltrane'},
#  {'id': 2392,
#   'question': 'when does the implantation of the embryo occur',
#   'answer': ['around 9 days after ovulation'],
#   'ans_type': 'DATE',
#   'prediction': 'around 9 days after ovulation',
#   'human': 1},
#  {'id': 3382,
#   'question': 'when was the seat moved to the capitol',
#   'answer': ['November 17, 1800', '1800', 'December 1800'],
#   'ans_type': 'DATE',
#   'prediction': 'December 6, 1790'},
#  {'id': 3123,
#   'question': 'eukaryotes have how many origins of dna replication',
#   'answer': ['up to 100,000'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'as many as one thousand'},
#  {'id': 919,
#   'question': 'when did the crucifix become the symbol of christianity',
#   'answer': ['in the 2nd century', '4th century', 'the 4th century'],
#   'ans_type': 'DATE',
#   'prediction': 'the 4th century',
#   'human': 1},
#  {'id': 2504,
#   'question': 'the first significant restriction on free immigration in u.s. history was the',
#   'answer': ['Naturalization Act of 1790', 'Chinese Exclusion Act in 1882'],
#   'ans_type': 'DATE',
#   'prediction': 'The Page Act of 1875'},
#  {'id': 3122,
#   'question': 'when did the legal drinking age changed to 21',
#   'answer': ['By mid-1988', 'October 1986'],
#   'ans_type': 'DATE',
#   'prediction': 'mid-1988'},
#  {'id': 725,
#   'question': 'number of films in lord of the rings',
#   'answer': ['three'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'three',
#   'human': 1},
#  {'id': 93,
#   'question': 'when did amnesia the dark descent come out',
#   'answer': ['8 September 2010'],
#   'ans_type': 'DATE',
#   'prediction': '2010'},
#  {'id': 3513,
#   'question': 'when was fingerprinting first used by the police',
#   'answer': ['the early 20th century', 'In 1840'],
#   'ans_type': 'DATE',
#   'prediction': '1892'},
#  {'id': 496,
#   'question': 'when was the last time michigan won the championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 1},
#  {'id': 3263,
#   'question': 'when was the taj mahal built and completed',
#   'answer': ['1632–53'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1653'},
#  {'id': 3521,
#   'question': 'when is beyblade burst super z coming out',
#   'answer': ['April 2, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'October 9, 2017'},
#  {'id': 610,
#   'question': 'when was the book pride and prejudice written',
#   'answer': ['28 January 1813', '1813'],
#   'ans_type': 'DATE',
#   'prediction': '1813',
#   'human': 1},
#  {'id': 487,
#   'question': 'when was the first election held in india',
#   'answer': ['1951–52'],
#   'ans_type': 'CARDINAL',
#   'prediction': '1920'},
#  {'id': 1225,
#   'question': 'when were cigarette ads banned from tv uk',
#   'answer': ['1 August 1965'],
#   'ans_type': 'DATE',
#   'prediction': '1 August 1965',
#   'human': 1},
#  {'id': 2118,
#   'question': 'when was the lupus foundation of america founded',
#   'answer': ['1977'],
#   'ans_type': 'DATE',
#   'prediction': '1977',
#   'human': 1},
#  {'id': 3036,
#   'question': 'how many episodes are there in season six of nashville',
#   'answer': ['16', '16 episodes'],
#   'ans_type': 'CARDINAL',
#   'prediction': '16',
#   'human': 1},
#  {'id': 360,
#   'question': 'when did gaurdians of the galaxy 2 come out',
#   'answer': ['2017', 'May\xa05,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'May 5, 2017',
#   'human': 1},
#  {'id': 2754,
#   'question': 'when does the champions league round of 16 start',
#   'answer': ['13 February'],
#   'ans_type': 'DATE',
#   'prediction': '11 December 2017'},
#  {'id': 2825,
#   'question': 'when was looking for a sunset bird in winter written',
#   'answer': ['1923'],
#   'ans_type': 'DATE',
#   'prediction': 'December 1815'},
#  {'id': 1906,
#   'question': 'what is the number of total presidential electoral votes',
#   'answer': ['538'],
#   'ans_type': 'CARDINAL',
#   'prediction': '538',
#   'human': 1},
#  {'id': 440,
#   'question': 'when was the last time the jets won a playoff game',
#   'answer': ['2010'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 1506,
#   'question': 'when was the electronic funds transfer act signed into law',
#   'answer': ['in 1978', 'November 10, 1978', '1978'],
#   'ans_type': 'DATE',
#   'prediction': '1978',
#   'human': 1},
#  {'id': 1690,
#   'question': 'when did the right to buy scheme start',
#   'answer': ['1980'],
#   'ans_type': 'DATE',
#   'prediction': '1980',
#   'human': 1},
#  {'id': 791,
#   'question': 'when was the nobel prize for literature first awarded',
#   'answer': ['1901'],
#   'ans_type': 'DATE',
#   'prediction': '1901',
#   'human': 1},
#  {'id': 1963,
#   'question': 'when did bihar bifurcate from bengal and some parts of chota nagpur merged into bengal',
#   'answer': ['1912'],
#   'ans_type': 'DATE',
#   'prediction': '1905'},
#  {'id': 156,
#   'question': 'when was the minimum wage established in the united states',
#   'answer': ['1938', '1933', '1912'],
#   'ans_type': 'DATE',
#   'prediction': '1938',
#   'human': 1},
#  {'id': 3457,
#   'question': 'when was the chain first used for f1',
#   'answer': ['1978'],
#   'ans_type': 'DATE',
#   'prediction': '1997'},
#  {'id': 471,
#   'question': 'when was the $1 000 bill discontinued',
#   'answer': ['1969', 'December 27, 1945', 'July 14, 1969'],
#   'ans_type': 'DATE',
#   'prediction': '1969',
#   'human': 1},
#  {'id': 3484,
#   'question': 'latest season on keeping up with the kardashians',
#   'answer': ['fourteen', '14'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'The fifteenth season'},
#  {'id': 1050,
#   'question': 'when did italy enter the second world war',
#   'answer': ['10 June 1940'],
#   'ans_type': 'DATE',
#   'prediction': '10 June 1940',
#   'human': 1},
#  {'id': 22,
#   'question': 'how many seasons of vampire diaries r there',
#   'answer': ['eight', '8'],
#   'ans_type': 'CARDINAL',
#   'prediction': '8',
#   'human': 1},
#  {'id': 2117,
#   'question': 'what is the enrollment at university of miami',
#   'answer': ['16,801', '16,801 students'],
#   'ans_type': 'CARDINAL',
#   'prediction': '17,331'},
#  {'id': 2928,
#   'question': 'when did the term sustainability start to be used',
#   'answer': ['1987'],
#   'ans_type': 'DATE',
#   'prediction': '1987',
#   'human': 1},
#  {'id': 1640,
#   'question': 'when was the last time vancouver had an earthquake',
#   'answer': ['1946'],
#   'ans_type': 'DATE',
#   'prediction': '1946',
#   'human': 1},
#  {'id': 1003,
#   'question': 'when was the last amendment to the constitution passed',
#   'answer': ['May 5, 1992'],
#   'ans_type': 'DATE',
#   'prediction': 'May 5, 1992',
#   'human': 1},
#  {'id': 652,
#   'question': 'when did jack mccoy join law and order',
#   'answer': ['1994'],
#   'ans_type': 'DATE',
#   'prediction': '1994',
#   'human': 1},
#  {'id': 2725,
#   'question': 'in photosynthesis the carbon in co2 is initially fixed to what molecule',
#   'answer': ['3-phosphoglycerate'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'carbohydrate molecules'},
#  {'id': 2177,
#   'question': 'when will miraculous season 2 episode 11 be released',
#   'answer': ['30\xa0March\xa02018', '27\xa0October\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 1066,
#   'question': 'when did ibuprofen become available over the counter',
#   'answer': ['1983', '1984'],
#   'ans_type': 'DATE',
#   'prediction': '1983',
#   'human': 1},
#  {'id': 2898,
#   'question': 'when did hyderabad became a part of india',
#   'answer': ['24 November 1949'],
#   'ans_type': 'DATE',
#   'prediction': '1948'},
#  {'id': 171,
#   'question': 'when was coffee first made into a drink',
#   'answer': ['15th century', 'the 15th century'],
#   'ans_type': 'DATE',
#   'prediction': '15th century',
#   'human': 1},
#  {'id': 3586,
#   'question': 'when did the first pair of yeezys come out',
#   'answer': ['February 14, 2015'],
#   'ans_type': 'DATE',
#   'prediction': '2009'},
#  {'id': 1773,
#   'question': 'when did france and belgium invade the ruhr',
#   'answer': ['11 January 1923', 'January 1923', '1923'],
#   'ans_type': 'DATE',
#   'prediction': 'between 1923 and 1925',
#   'human': 1},
#  {'id': 3408,
#   'question': 'how many students does monarch high school have',
#   'answer': ['2,406'],
#   'ans_type': 'CARDINAL',
#   'prediction': '2,000'},
#  {'id': 879,
#   'question': 'how many episodes of the white princess will there be',
#   'answer': ['eight', '8'],
#   'ans_type': 'CARDINAL',
#   'prediction': '8',
#   'human': 1},
#  {'id': 552,
#   'question': 'when did the us stop drafting for the vietnam war',
#   'answer': ['1973'],
#   'ans_type': 'DATE',
#   'prediction': '1973',
#   'human': 1},
#  {'id': 1696,
#   'question': 'india south africa test series 2018 highest runs',
#   'answer': ['286', 'AB de Villiers'],
#   'ans_type': 'CARDINAL',
#   'prediction': '558'},
#  {'id': 2646,
#   'question': 'how much does a new gulfstream g650 cost',
#   'answer': ['US$66.61 million', '$66.5 million'],
#   'ans_type': 'MONEY',
#   'prediction': '$15 million to $32 million'},
#  {'id': 1065,
#   'question': 'when do love and hip hop new york come back on',
#   'answer': ['November\xa013,\xa02017', 'October 30, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'October 30, 2017',
#   'human': 1},
#  {'id': 188,
#   'question': 'what proposition made the insurance commissioner an elected position',
#   'answer': ['Proposition 103', 'Proposition 103 in 1988'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Proposition 103',
#   'human': 1},
#  {'id': 3130,
#   'question': 'when did the angel of the north get built',
#   'answer': ['1998', '1994'],
#   'ans_type': 'DATE',
#   'prediction': '1998',
#   'human': 1},
#  {'id': 3372,
#   'question': 'what is the rank of india in economic growth',
#   'answer': ['12 / 225', '12'],
#   'ans_type': 'CARDINAL',
#   'prediction': '139th'},
#  {'id': 1131,
#   'question': 'why did ric flair go back to wcw',
#   'answer': ['February 1993'],
#   'ans_type': 'DATE',
#   'prediction': 'Legends program'},
#  {'id': 2582,
#   'question': 'how much energy does coal produce in the us',
#   'answer': ['16.5 quadrillion BTUs', '30.4%'],
#   'ans_type': 'QUANTITY',
#   'prediction': '22%'},
#  {'id': 3025,
#   'question': 'what is the latest version of microsoft office 2010',
#   'answer': ['14.0.7182.5000'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Office 2010'},
#  {'id': 1717,
#   'question': 'how many players have scored 10000 runs in odi',
#   'answer': ['11', 'eleven'],
#   'ans_type': 'CARDINAL',
#   'prediction': '7'},
#  {'id': 2298,
#   'question': 'when did colour tv come out in uk',
#   'answer': ['July 1, 1967', '1967/1969/1976', '1967'],
#   'ans_type': 'DATE',
#   'prediction': '1967',
#   'human': 1},
#  {'id': 103,
#   'question': 'when does the dlc for rainbow six siege come out',
#   'answer': ['January 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'post-launch'},
#  {'id': 2221,
#   'question': 'when is the world consumer right day celebrated',
#   'answer': ['15 March every year', '15 March'],
#   'ans_type': 'DATE',
#   'prediction': '10 December'},
#  {'id': 272,
#   'question': 'when did lionel messi play his first game for barcelona',
#   'answer': ['2002', '2001', 'October 2004'],
#   'ans_type': 'DATE',
#   'prediction': 'October 2004',
#   'human': 1},
#  {'id': 605,
#   'question': 'when does isle of dogs come out in us',
#   'answer': ['April 13, 2018', 'March 23, 2018', 'March\xa023,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'March 23, 2018',
#   'human': 1},
#  {'id': 718,
#   'question': 'when was half life 2 episode 2 released',
#   'answer': ['in 2007', 'October 10, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2007',
#   'human': 1},
#  {'id': 580,
#   'question': 'when did disney art of animation resort open',
#   'answer': ['May 31, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'March 16, 2002'},
#  {'id': 2328,
#   'question': 'when did michigan last win a national championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 1},
#  {'id': 1295,
#   'question': 'when was last time bayern munich won champions league',
#   'answer': ['2012–13', '2013', '2000–01'],
#   'ans_type': 'DATE',
#   'prediction': '2013',
#   'human': 1},
#  {'id': 1252,
#   'question': 'how many episodes curse of oak island season 5',
#   'answer': ['18'],
#   'ans_type': 'CARDINAL',
#   'prediction': '7'},
#  {'id': 472,
#   'question': "what's the population of prince edward island",
#   'answer': ['142,907 residents', '142,907'],
#   'ans_type': 'CARDINAL',
#   'prediction': '142,907',
#   'human': 1},
#  {'id': 134,
#   'question': 'when did the royal mint move to wales',
#   'answer': ['1968', 'the 1960s.', '17 December 1968', 'the 1960s'],
#   'ans_type': 'DATE',
#   'prediction': '1980'},
#  {'id': 1089,
#   'question': 'when does the world cup of hockey start',
#   'answer': ['2020'],
#   'ans_type': 'DATE',
#   'prediction': '28 November'},
#  {'id': 560,
#   'question': 'when were birth certificates first issued in the united states',
#   'answer': ['1902', '1900', 'From 1900 to 1946'],
#   'ans_type': 'DATE',
#   'prediction': '1902',
#   'human': 1},
#  {'id': 2347,
#   'question': 'hart of dixie season 4 how many episodes',
#   'answer': ['10'],
#   'ans_type': 'CARDINAL',
#   'prediction': '10',
#   'human': 1},
#  {'id': 1006,
#   'question': 'when did the first marvel vs capcom come out',
#   'answer': ['1998', 'in 1996', '1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'id': 2832,
#   'question': 'when was the last god of war made',
#   'answer': ['2018', 'March 12, 2013'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'id': 2590,
#   'question': 'when did are you smarter than a 5th grader first air',
#   'answer': ['February 27, 2007'],
#   'ans_type': 'DATE',
#   'prediction': 'February 27, 2007',
#   'human': 1},
#  {'id': 1781,
#   'question': 'what do mobile numbers start with in the uk',
#   'answer': ['0'],
#   'ans_type': 'CARDINAL',
#   'prediction': '077',
#   'human': 1},
#  {'id': 532,
#   'question': 'when was the reaper invented by cyrus mccormick',
#   'answer': ['1837', '1834'],
#   'ans_type': 'DATE',
#   'prediction': '1831'},
#  {'id': 315,
#   'question': 'when did seat belts become law in ontario',
#   'answer': ['January 1, 1976'],
#   'ans_type': 'DATE',
#   'prediction': 'January 1, 1976',
#   'human': 1},
#  {'id': 1610,
#   'question': 'when does the next warrior book come out',
#   'answer': ['April 10, 2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 2648,
#   'question': 'when did congress passes legislation to fund the national cancer institute',
#   'answer': ['August 5, 1937'],
#   'ans_type': 'DATE',
#   'prediction': '1971'},
#  {'id': 1554,
#   'question': 'when did the first fleet arive in australia',
#   'answer': ['18 January 1788', '1788'],
#   'ans_type': 'DATE',
#   'prediction': '13 May 1787'},
#  {'id': 3460,
#   'question': 'one piece english dubbed episode 564 release date',
#   'answer': ['September 16, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'May 27, 2008'},
#  {'id': 125,
#   'question': 'how many seasons of rules of engagement is there',
#   'answer': ['7', 'seven'],
#   'ans_type': 'CARDINAL',
#   'prediction': '7',
#   'human': 1},
#  {'id': 2291,
#   'question': 'one piece episode 534 english dubbed release date',
#   'answer': ['February 5, 2012'],
#   'ans_type': 'DATE',
#   'prediction': 'May 27, 2008'},
#  {'id': 1224,
#   'question': 'when does the new saw 8 come out',
#   'answer': ['October 27, 2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017'},
#  {'id': 1614,
#   'question': 'how many pitchers does a major league team have',
#   'answer': ['five starting pitchers', 'seven relief pitchers'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'five'},
#  {'id': 2382,
#   'question': 'when did ford change the f150 body style',
#   'answer': ['the 2009 model year', '1957'],
#   'ans_type': 'DATE',
#   'prediction': '2015 model year'},
#  {'id': 1903,
#   'question': 'how many lines of symmetry are there in a equilateral triangle',
#   'answer': ['3'],
#   'ans_type': 'CARDINAL',
#   'prediction': '3',
#   'human': 1},
#  {'id': 1467,
#   'question': 'who is the founder of google and when was it founded',
#   'answer': ['1998',
#    'Sergey Brin',
#    'Larry Page',
#    'Larry Page and Sergey Brin'],
#   'ans_type': 'DATE',
#   'prediction': '1998',
#   'human': 1},
#  {'id': 3467,
#   'question': 'when does the nba season end this year',
#   'answer': ['April 11, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'April 11, 2018',
#   'human': 1},
#  {'id': 2737,
#   'question': 'how many seasons of the smurfs are there',
#   'answer': ['9'],
#   'ans_type': 'CARDINAL',
#   'prediction': '7'},
#  {'id': 1624,
#   'question': 'when was the worlds first laptop computer introduced in the market and by whom',
#   'answer': ['September 1980', 'R2E Micral CCMC'],
#   'ans_type': 'DATE',
#   'prediction': '1981'},
#  {'id': 3214,
#   'question': 'when will the flash season 4 be released',
#   'answer': ['October 10, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2017',
#   'human': 1},
#  {'id': 481,
#   'question': 'when do the new episodes of supernatural start',
#   'answer': ['May\xa010,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'October 12, 2017'},
#  {'id': 1530,
#   'question': 'when did korea separate into north and south',
#   'answer': ['1945', '17 August 1945'],
#   'ans_type': 'DATE',
#   'prediction': '1945',
#   'human': 1},
#  {'id': 598,
#   'question': 'when was national service abolished in the uk',
#   'answer': ['1960', 'November 1960', '31 December 1960'],
#   'ans_type': 'DATE',
#   'prediction': '31 December 1960',
#   'human': 1},
#  {'id': 2506,
#   'question': 'when was the last time mount etna exploded',
#   'answer': ['July–October 2012', '16 March 2017'],
#   'ans_type': 'DATE',
#   'prediction': '16 March 2017',
#   'human': 1},
#  {'id': 883,
#   'question': 'how long were the pyramids the tallest structure',
#   'answer': ['over 3,800', 'over 3,800 years'],
#   'ans_type': 'CARDINAL',
#   'prediction': '3,800 years'},
#  {'id': 338,
#   'question': 'how many languages in harry potter translated into',
#   'answer': ['over 74', 'over 74 languages'],
#   'ans_type': 'DATE',
#   'prediction': 'over 74',
#   'human': 1},
#  {'id': 1060,
#   'question': 'how many seasons are in star wars the clone wars',
#   'answer': ['6'],
#   'ans_type': 'CARDINAL',
#   'prediction': '8'},
#  {'id': 3412,
#   'question': 'when did we decide to leave the eu',
#   'answer': ['23 June 2016'],
#   'ans_type': 'DATE',
#   'prediction': '23 June 2016',
#   'human': 1},
#  {'id': 3077,
#   'question': 'when did the passion of the christ come out',
#   'answer': ['February 25, 2004', 'February\xa025,\xa02004', '2004'],
#   'ans_type': 'DATE',
#   'prediction': 'February 25, 2004',
#   'human': 1},
#  {'id': 1484,
#   'question': 'when was the suite life of zack and cody made',
#   'answer': ['March\xa018,\xa02005', 'September\xa01,\xa02008', '2005'],
#   'ans_type': 'DATE',
#   'prediction': '2005',
#   'human': 1},
#  {'id': 304,
#   'question': 'when was the latest version of chrome released',
#   'answer': ['2018-01-22'],
#   'ans_type': 'DATE',
#   'prediction': 'April 14, 2015'},
#  {'id': 537,
#   'question': 'how many kilometers of great wall of china',
#   'answer': ['8,850\xa0km', '21,196\xa0km'],
#   'ans_type': 'QUANTITY',
#   'prediction': '130'},
#  {'id': 3235,
#   'question': 'most runs ever scored in a mlb inning',
#   'answer': ['18'],
#   'ans_type': 'CARDINAL',
#   'prediction': '18',
#   'human': 1},
#  {'id': 3324,
#   'question': 'when did they start adding zinc to pennies',
#   'answer': ['1864', '1943', '1864–1942'],
#   'ans_type': 'DATE',
#   'prediction': '1943',
#   'human': 1},
#  {'id': 401,
#   'question': 'when did the east india company take control of india',
#   'answer': ['in 1757', '1757', '1799', '1612'],
#   'ans_type': 'DATE',
#   'prediction': '1757',
#   'human': 1},
#  {'id': 1191,
#   'question': 'when does brooklyn nine nine season 5 episode 12',
#   'answer': ['March\xa018,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'May 20, 2018'},
#  {'id': 307,
#   'question': 'when were the winnie the pooh books written',
#   'answer': ['1924', '1926', '1927', '1928'],
#   'ans_type': 'DATE',
#   'prediction': '1926',
#   'human': 1},
#  {'id': 3279,
#   'question': 'most home runs by 2 teammates in a season',
#   'answer': ['115',
#    'a combined 115 home runs',
#    'Roger Maris',
#    'Mickey Mantle'],
#   'ans_type': 'CARDINAL',
#   'prediction': '115',
#   'human': 1},
#  {'id': 2550,
# ...
#   'ans_type': 'DATE',
#   'prediction': 'June 1979'},
#  {'id': 2232,
#   'question': 'how many characters are present in icd-10 codes',
#   'answer': ['7'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven'},
#  {'id': 74,
#   'question': 'when was corporal punishment banned in south africa',
#   'answer': ['1997'],
#   'ans_type': 'DATE',
#   'prediction': '1997',
#   'human': 1},
#  {'id': 1565,
#   'question': 'what is the average salary for a us congressman',
#   'answer': ['$174,000'],
#   'ans_type': 'MONEY',
#   'prediction': '$169,300 annually'},
#  {'id': 3072,
#   'question': 'when did red bull come to the united states',
#   'answer': ['1997'],
#   'ans_type': 'DATE',
#   'prediction': '1997',
#   'human': 1},
#  {'id': 3552,
#   'question': 'what episode does marnie come back in geordie shore',
#   'answer': ['5'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'the twelfth series'},
#  {'id': 2018,
#   'question': 'when does the regular season start in mlb',
#   'answer': ['March 29, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'March 29, 2018',
#   'human': 1},
#  {'id': 2228,
#   'question': 'what is the latest version of chrome for linux',
#   'answer': ['67.0.3396', '67.0'],
#   'ans_type': 'CARDINAL',
#   'prediction': '26'},
#  {'id': 1174,
#   'question': 'when is the strictly come dancing results show recorded',
#   'answer': ['Saturday', 'Sunday night'],
#   'ans_type': 'DATE',
#   'prediction': 'Saturday night',
#   'human': 1},
#  {'id': 1768,
#   'question': 'how old do you have to be to get a gun licence in nz',
#   'answer': ['16 or older'],
#   'ans_type': 'DATE',
#   'prediction': '18'},
#  {'id': 2929,
#   'question': 'when did the cowboys start playing on thanksgiving day',
#   'answer': ['In 1966', '1966', '1978'],
#   'ans_type': 'DATE',
#   'prediction': '1966',
#   'human': 1},
#  {'id': 2889,
#   'question': 'total goals scored by ronaldo in la liga',
#   'answer': ['309'],
#   'ans_type': 'CARDINAL',
#   'prediction': '252'},
#  {'id': 1750,
#   'question': 'how many episodes of sabrina the teenage witch are there',
#   'answer': ['163'],
#   'ans_type': 'CARDINAL',
#   'prediction': '66'},
#  {'id': 783,
#   'question': 'how long are the episodes in stranger things season 1',
#   'answer': ['42–62 minutes'],
#   'ans_type': 'TIME',
#   'prediction': 'eight'},
#  {'id': 724,
#   'question': 'when did reba mcentire record back to god',
#   'answer': ['February 3, 2017', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 2973,
#   'question': 'when did the song the joker come out',
#   'answer': ['1973', 'October 1973'],
#   'ans_type': 'DATE',
#   'prediction': '1973',
#   'human': 1},
#  {'id': 270,
#   'question': 'when was the last year the eagles went to the superbowl',
#   'answer': ['following the 2017 season', '2017'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 2801,
#   'question': 'when was the last time the denver nuggets made the playoffs',
#   'answer': ['2012–13', '2009–10', '1994–95'],
#   'ans_type': 'DATE',
#   'prediction': '2008'},
#  {'id': 3282,
#   'question': 'when was the r10+20 summit in rio de janeiro held',
#   'answer': ['June 2012', '13 to 22 June 2012'],
#   'ans_type': 'DATE',
#   'prediction': '2012'},
#  {'id': 2031,
#   'question': 'when did toyota first come to the united states',
#   'answer': ['1957'],
#   'ans_type': 'DATE',
#   'prediction': '1957',
#   'human': 1},
#  {'id': 2445,
#   'question': 'when was the first underwater cable laid beneath the english channel',
#   'answer': ['1850'],
#   'ans_type': 'DATE',
#   'prediction': 'August 1850',
#   'human': 1},
#  {'id': 1995,
#   'question': 'how many wins does tiger woods have on the pga tour',
#   'answer': ['79'],
#   'ans_type': 'CARDINAL',
#   'prediction': '54'},
#  {'id': 715,
#   'question': 'when did they stop saying mass in latin',
#   'answer': ['from 1967 onwards', '1967'],
#   'ans_type': 'DATE',
#   'prediction': '1967',
#   'human': 1},
#  {'id': 1373,
#   'question': 'when does the new adventure time come out',
#   'answer': ['April 21, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 17, 2017'},
#  {'id': 2309,
#   'question': 'when does the 2017 college football season end',
#   'answer': ['December 9, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'December 9, 2017',
#   'human': 1},
#  {'id': 939,
#   'question': 'when was the last time villanova won the ncaa basketball championship',
#   'answer': ['2018'],
#   'ans_type': 'DATE',
#   'prediction': '2018',
#   'human': 1},
#  {'id': 629,
#   'question': 'when did fortnite battle royal come out on xbox',
#   'answer': ['September 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 2017',
#   'human': 1},
#  {'id': 1695,
#   'question': 'wolf of wall street number of f words',
#   'answer': ['569'],
#   'ans_type': 'CARDINAL',
#   'prediction': '22'},
#  {'id': 2184,
#   'question': 'when did chicano studies become major studies programs on college campuses',
#   'answer': ['By 1975', '1972'],
#   'ans_type': 'DATE',
#   'prediction': '1970s'},
#  {'id': 3045,
#   'question': 'how many players in football hall of fame',
#   'answer': ['318', '318 individuals'],
#   'ans_type': 'CARDINAL',
#   'prediction': '318',
#   'human': 1},
#  {'id': 71,
#   'question': "how many games in a row have the uconn women's basketball team won",
#   'answer': ['111 straight wins', '111', '90'],
#   'ans_type': 'CARDINAL',
#   'prediction': '111',
#   'human': 1},
#  {'id': 458,
#   'question': 'when does like cage season 2 come out',
#   'answer': ['June 22, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'June 22, 2018',
#   'human': 1},
#  {'id': 1160,
#   'question': 'how long is the famous suspension bridge in san francisco and what is it called',
#   'answer': ['one-mile-wide', 'Golden Gate Bridge'],
#   'ans_type': 'QUANTITY',
#   'prediction': 'The Golden Gate Bridge',
#   'human': 1},
#  {'id': 2125,
#   'question': 'how many points are scored for a touchdown in american football',
#   'answer': ['six', 'six points'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four'},
#  {'id': 3445,
#   'question': 'what year did return of the mack come out',
#   'answer': ['18\xa0March\xa01996', 'March 1996', '1996'],
#   'ans_type': 'DATE',
#   'prediction': '1996',
#   'human': 1},
#  {'id': 1218,
#   'question': 'when was the last time the vikings made the superbowl',
#   'answer': ['in the 1970s'],
#   'ans_type': 'DATE',
#   'prediction': 'January 9, 1977'},
#  {'id': 3254,
#   'question': 'university of michigan school of public health ranking',
#   'answer': ['#4'],
#   'ans_type': 'MONEY',
#   'prediction': 'University of Michigan'},
#  {'id': 2256,
#   'question': 'krypton-85 decays by emission of a beta particle. the product of this decay is',
#   'answer': ['rubidium-85'],
#   'ans_type': 'DATE',
#   'prediction': 'positron'},
#  {'id': 1844,
#   'question': 'when was the last time a hurricane hit massachusetts',
#   'answer': ['November 3, 2007'],
#   'ans_type': 'DATE',
#   'prediction': '1851'},
#  {'id': 3479,
#   'question': 'when do new episodes of ncis los angeles return',
#   'answer': ['May\xa013,\xa02018', 'October 1, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 30, 2018'},
#  {'id': 770,
#   'question': 'how many episodes in series 7 of game of thrones are there',
#   'answer': ['7', 'seven'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven',
#   'human': 1},
#  {'id': 1342,
#   'question': 'most assists in an nba all star game',
#   'answer': ['60', '22'],
#   'ans_type': 'CARDINAL',
#   'prediction': '8'},
#  {'id': 1866,
#   'question': 'when was the movie the king and i made',
#   'answer': ['1956'],
#   'ans_type': 'DATE',
#   'prediction': '1956',
#   'human': 1},
#  {'id': 1451,
#   'question': 'when did the name of bombay change to mumbai',
#   'answer': ['1995'],
#   'ans_type': 'DATE',
#   'prediction': 'November 1995',
#   'human': 1},
#  {'id': 1590,
#   'question': 'when did refrigerator perry play for the bears',
#   'answer': ['1985–1993'],
#   'ans_type': 'DATE',
#   'prediction': '1985'},
#  {'id': 1186,
#   'question': 'when does kubo and the two strings release',
#   'answer': ['August 19, 2016', 'August\xa019,\xa02016'],
#   'ans_type': 'DATE',
#   'prediction': 'August 19, 2016',
#   'human': 1},
#  {'id': 1228,
#   'question': 'when did india win their first cricket match',
#   'answer': ['1952'],
#   'ans_type': 'DATE',
#   'prediction': '1932'},
#  {'id': 43,
#   'question': 'last episode of what happens to my family',
#   'answer': ['53'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'February 15, 2015'},
#  {'id': 2659,
#   'question': 'when does the flash season 4 episode 3 air',
#   'answer': ['October\xa024,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2017'},
#  {'id': 3256,
#   'question': 'when was the immigration act passed in canada',
#   'answer': ['1923'],
#   'ans_type': 'DATE',
#   'prediction': 'June 22, 1869'},
#  {'id': 1664,
#   'question': 'when was the last time stock market crashed',
#   'answer': ['27 Oct 1997', '18 August 2015'],
#   'ans_type': 'DATE',
#   'prediction': 'October 19, 1987'},
#  {'id': 1600,
#   'question': 'when was the movie the wizard of oz made',
#   'answer': ['1939', 'August\xa025,\xa01939'],
#   'ans_type': 'DATE',
#   'prediction': '1939',
#   'human': 1},
#  {'id': 2571,
#   'question': 'when did the movie peter pan come out',
#   'answer': ['2003', '25\xa0December\xa02003'],
#   'ans_type': 'DATE',
#   'prediction': '1953'},
#  {'id': 167,
#   'question': 'when was united nations convention on the rights of the child created',
#   'answer': ['20 November 1989'],
#   'ans_type': 'DATE',
#   'prediction': '20 November 1989',
#   'human': 1},
#  {'id': 2486,
#   'question': 'when does planet of the apes come out 2017',
#   'answer': ['July 14, 2017', 'July\xa014,\xa02017'],
#   'ans_type': 'DATE',
#   'prediction': 'July 14, 2017',
#   'human': 1},
#  {'id': 193,
#   'question': 'when does body temperature tend to be lowest',
#   'answer': ['11 p.m. to 3 a.m.'],
#   'ans_type': 'TIME',
#   'prediction': 'around 4 a.m.'},
#  {'id': 2337,
#   'question': 'when was the last time michigan basketball won the championship',
#   'answer': ['1989'],
#   'ans_type': 'DATE',
#   'prediction': '1989',
#   'human': 1},
#  {'id': 2869,
#   'question': 'how many games does a football team have to win to be bowl eligible',
#   'answer': ['5'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'seven'},
#  {'id': 1071,
#   'question': 'when did muhammad ali win an olympic gold medal',
#   'answer': ['1960'],
#   'ans_type': 'DATE',
#   'prediction': '1960',
#   'human': 1},
#  {'id': 3267,
#   'question': 'when did cybermen first appear in doctor who',
#   'answer': ['in 1966', '1966'],
#   'ans_type': 'DATE',
#   'prediction': 'November 1966',
#   'human': 1},
#  {'id': 1411,
#   'question': "who played joey's agent estelle on friends",
#   'answer': ['June Gable'],
#   'ans_type': 'DATE',
#   'prediction': 'June Gable',
#   'human': 1},
#  {'id': 1430,
#   'question': 'when does season 8 for blue bloods start',
#   'answer': ['September 29, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'September 29, 2017',
#   'human': 1},
#  {'id': 2231,
#   'question': 'how many nfl games were played in london',
#   'answer': ['21'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'four'},
#  {'id': 47,
#   'question': 'when was the last time oklahoma won a national championship in football',
#   'answer': ['2003', '2000'],
#   'ans_type': 'DATE',
#   'prediction': '2003',
#   'human': 1},
#  {'id': 1181,
#   'question': 'how many quarterbacks have a receiving touchdown in the superbowl',
#   'answer': ['1'],
#   'ans_type': 'CARDINAL',
#   'prediction': '3'},
#  {'id': 2371,
#   'question': "when does the men's worlds curling start",
#   'answer': ['March 31'],
#   'ans_type': 'DATE',
#   'prediction': 'March 31',
#   'human': 1},
#  {'id': 3350,
#   'question': 'what is the minimum dollar amount for federal court',
#   'answer': ['$75,000'],
#   'ans_type': 'MONEY',
#   'prediction': '$75,000',
#   'human': 1},
#  {'id': 1571,
#   'question': 'when does season 3 of the riveras start',
#   'answer': ['March\xa011,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 1025,
#   'question': 'when did the us dollar leave the gold standard',
#   'answer': ['October 1976', 'August 15, 1971', '1934'],
#   'ans_type': 'DATE',
#   'prediction': 'October 1976',
#   'human': 1},
#  {'id': 2522,
#   'question': 'what is the salary of us secretary of state',
#   'answer': ['$205,700', '$205,700 annually'],
#   'ans_type': 'MONEY',
#   'prediction': '$210,700'},
#  {'id': 3073,
#   'question': 'how long has tom brady been the patriots quarterback',
#   'answer': ['2001', '16 seasons'],
#   'ans_type': 'DATE',
#   'prediction': '18-season'},
#  {'id': 1343,
#   'question': 'when is the next episode of flash airing',
#   'answer': ['May\xa08,\xa02018'],
#   'ans_type': 'DATE',
#   'prediction': 'October 10, 2017'},
#  {'id': 2043,
#   'question': 'when does zay come to girl meets world',
#   'answer': ['May\xa013,\xa02015'],
#   'ans_type': 'DATE',
#   'prediction': 'season three'},
#  {'id': 1605,
#   'question': 'when does the sword art online movie take place',
#   'answer': ['2026', 'the year 2026'],
#   'ans_type': 'CARDINAL',
#   'prediction': '2017'},
#  {'id': 2639,
#   'question': 'when did come fly with me come out',
#   'answer': ['25 December 2010'],
#   'ans_type': 'DATE',
#   'prediction': '1957'},
#  {'id': 2937,
#   'question': 'when was the first time the internet was used',
#   'answer': ['1969', 'November 22, 1977'],
#   'ans_type': 'DATE',
#   'prediction': '1969',
#   'human': 1},
#  {'id': 2719,
#   'question': 'when are the next commonwealth games going to be held',
#   'answer': ['2022'],
#   'ans_type': 'DATE',
#   'prediction': '2022',
#   'human': 1},
#  {'id': 2688,
#   'question': 'when is the last time congress passed a complete budget',
#   'answer': ['FY2010', 'March 23, 2013'],
#   'ans_type': 'DATE',
#   'prediction': '1997'},
#  {'id': 266,
#   'question': 'when did the united states host the world cup',
#   'answer': ['1994'],
#   'ans_type': 'DATE',
#   'prediction': '1994',
#   'human': 1},
#  {'id': 1370,
#   'question': 'when does the mlb season start and finish',
#   'answer': ['March 29', 'October 31, 2018'],
#   'ans_type': 'DATE',
#   'prediction': 'March 29, 2018',
#   'human': 1},
#  {'id': 657,
#   'question': "what is alpha centauri's approximate distance from earth",
#   'answer': ['4.37 light-years'],
#   'ans_type': 'CARDINAL',
#   'prediction': '11.2 AU'},
#  {'id': 2008,
#   'question': 'what is the current rate of interest on ppf',
#   'answer': ['7.6% Per Annum', '7.6%'],
#   'ans_type': 'PERCENT',
#   'prediction': '8'},
#  {'id': 1665,
#   'question': 'during which season does cape town receive rainfall',
#   'answer': ['winter', 'summer'],
#   'ans_type': 'DATE',
#   'prediction': 'Winter',
#   'human': 1},
#  {'id': 386,
#   'question': 'when is the met office leaving the bbc',
#   'answer': ['31 March 2018'],
#   'ans_type': 'DATE',
#   'prediction': '23 August 2015'},
#  {'id': 1287,
#   'question': "when did the song rapper's delight come out",
#   'answer': ['1979', 'September 16, 1979'],
#   'ans_type': 'DATE',
#   'prediction': '1979',
#   'human': 1},
#  {'id': 642,
#   'question': 'when was kudzu introduced to the united states',
#   'answer': ['1876', 'in 1876'],
#   'ans_type': 'DATE',
#   'prediction': '1876',
#   'human': 1},
#  {'id': 1714,
#   'question': 'dark parables return of the salt princess release date',
#   'answer': ['September 2017'],
#   'ans_type': 'DATE',
#   'prediction': '2018'},
#  {'id': 2413,
#   'question': 'when did the broncos win the super bowl',
#   'answer': ['1998', '2015', '1997'],
#   'ans_type': 'DATE',
#   'prediction': '2015',
#   'human': 1},
#  {'id': 2387,
#   'question': "when does ellen's new game show start",
#   'answer': ['December 18, 2017'],
#   'ans_type': 'DATE',
#   'prediction': 'December 18, 2017',
#   'human': 1},
#  {'id': 2908,
#   'question': 'when was the last time that the eagles were at the super bowl',
#   'answer': ['2017', '2017 season'],
#   'ans_type': 'DATE',
#   'prediction': '2017',
#   'human': 1},
#  {'id': 1434,
#   'question': 'how many times have the golden state warriors been to the playoffs',
#   'answer': ['nine'],
#   'ans_type': 'CARDINAL',
#   'prediction': '6'},
#  {'id': 683,
#   'question': 'when did beds become popular in france and germany',
#   'answer': ['the 12th century'],
#   'ans_type': 'DATE',
#   'prediction': '16th century'},
#  {'id': 1623,
#   'question': 'who invented the printing press and what year',
#   'answer': ['circa 1439', 'Johannes Gutenberg'],
#   'ans_type': 'CARDINAL',
#   'prediction': 'Johannes Gutenberg',
#   'human': 1}]

# %%
from datasets import load_dataset
no_context_dataset = load_dataset('trivia_qa','rc.wikipedia.nocontext')
context_dataset = load_dataset('trivia_qa','rc.wikipedia')
# Out:
# Downloading and preparing dataset trivia_qa/rc.wikipedia.nocontext to /home/donaldo9603/.cache/huggingface/datasets/trivia_qa/rc.wikipedia.nocontext/1.2.0/ee76d8a9403e71177e2a3fa7e414d1ee28a79a0970d9176f62f268798aa64b31...
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 795.13it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 267.05it/s]
# Dataset trivia_qa downloaded and prepared to /home/donaldo9603/.cache/huggingface/datasets/trivia_qa/rc.wikipedia.nocontext/1.2.0/ee76d8a9403e71177e2a3fa7e414d1ee28a79a0970d9176f62f268798aa64b31. Subsequent calls will reuse this data.
# 100%|██████████| 3/3 [00:00<00:00, 75.63it/s]
# Downloading and preparing dataset trivia_qa/rc.wikipedia to /home/donaldo9603/.cache/huggingface/datasets/trivia_qa/rc.wikipedia/1.2.0/ee76d8a9403e71177e2a3fa7e414d1ee28a79a0970d9176f62f268798aa64b31...
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 1259.55it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 522.78it/s]
# Dataset trivia_qa downloaded and prepared to /home/donaldo9603/.cache/huggingface/datasets/trivia_qa/rc.wikipedia/1.2.0/ee76d8a9403e71177e2a3fa7e414d1ee28a79a0970d9176f62f268798aa64b31. Subsequent calls will reuse this data.
# 100%|██████████| 3/3 [00:00<00:00,  7.05it/s]

# %%
no_context_dataset['train'][4]
# Out:
# {'question': 'Which was the first European country to abolish capital punishment?',
#  'question_id': 'tc_11',
#  'question_source': 'http://www.triviacountry.com/',
#  'entity_pages': {'doc_source': [],
#   'filename': [],
#   'title': [],
#   'wiki_context': []},
#  'search_results': {'description': [],
#   'filename': [],
#   'rank': [],
#   'title': [],
#   'url': [],
#   'search_context': []},
#  'answer': {'aliases': ['Norvège',
#    'Mainland Norway',
#    'Norway',
#    'Norvege',
#    'Noregur',
#    'NORWAY',
#    'Norwegian state',
#    'Etymology of Norway',
#    'Noruega',
#    'Norwegen',
#    'ISO 3166-1:NO',
#    'Noreg',
#    'Republic of Norway',
#    'Norwegian kingdom',
#    'Kongeriket Noreg',
#    'Name of Norway',
#    'Kongeriket Norge',
#    'Noorwegen',
#    'Kingdom of Norway',
#    'Sport in Norway',
#    'Norwegia',
#    'Royal Kingdom of Norway'],
#   'normalized_aliases': ['norwegen',
#    'kongeriket norge',
#    'norway',
#    'republic of norway',
#    'noorwegen',
#    'norvege',
#    'mainland norway',
#    'kingdom of norway',
#    'sport in norway',
#    'noreg',
#    'noruega',
#    'norwegia',
#    'noregur',
#    'royal kingdom of norway',
#    'name of norway',
#    'kongeriket noreg',
#    'norwegian kingdom',
#    'etymology of norway',
#    'norvège',
#    'iso 3166 1 no',
#    'norwegian state'],
#   'matched_wiki_entity_name': '',
#   'normalized_matched_wiki_entity_name': '',
#   'normalized_value': 'norway',
#   'type': 'WikipediaEntity',
#   'value': 'Norway'}}

# %%
context_dataset['train'][0]
# Out:
# {'question': 'Where in England was Dame Judi Dench born?',
#  'question_id': 'tc_3',
#  'question_source': 'http://www.triviacountry.com/',
#  'entity_pages': {'doc_source': ['TagMe', 'TagMe'],
#   'filename': ['England.txt', 'Judi_Dench.txt'],
#   'title': ['England', 'Judi Dench'],
#   'wiki_context': ['England is a country that is part of the United Kingdom.   It shares land borders with Scotland to the north and Wales to the west. The Irish Sea lies northwest of England and the Celtic Sea lies to the southwest. England is separated from continental Europe by the North Sea to the east and the English Channel to the south. The country covers much of the central and southern part of the island of Great Britain, which lies in the North Atlantic; and includes over 100 smaller islands such as the Isles of Scilly, and the Isle of Wight.\n\nThe area now called England was first inhabited by modern humans during the Upper Palaeolithic period, but takes its name from the Angles, one of the Germanic tribes who settled during the 5th and 6th centuries. England became a unified state in the 10th century, and since the Age of Discovery, which began during the 15th century, has had a significant cultural and legal impact on the wider world.  The English language, the Anglican Church, and English law – the basis for the common law legal systems of many other countries around the world – developed in England, and the country\'s parliamentary system of government has been widely adopted by other nations.  The Industrial Revolution began in 18th-century England, transforming its society into the world\'s first industrialised nation. \n\nEngland\'s terrain mostly comprises low hills and plains, especially in central and southern England. However, there are uplands in the north (for example, the mountainous Lake District, Pennines, and Yorkshire Dales) and in the south west (for example, Dartmoor and the Cotswolds). The capital is London, which is the largest metropolitan area in both the United Kingdom and the European Union.According to the European Statistical Agency, London is the largest Larger Urban Zone in the EU, a measure of metropolitan area which comprises a city\'s urban core as well as its surrounding commuting zone. London\'s municipal population is also the largest in the EU. England\'s population of over 53\xa0million comprises 84% of the population of the United Kingdom, largely concentrated around London, the South East, and conurbations in the Midlands, the North West, the North East, and Yorkshire, which each developed as major industrial regions during the 19th century.[http://www.ons.gov.uk/ons/dcp171778_270487.pdf 2011 Census – Population and household estimates for England and Wales, March 2011]. Accessed 31 May 2013.\n\nThe Kingdom of England—which after 1535 included Wales—ceased being a separate sovereign state on 1 May 1707, when the Acts of Union put into effect the terms agreed in the Treaty of Union the previous year, resulting in a political union with the Kingdom of Scotland to create the Kingdom of Great Britain.   In 1801, Great Britain was united with the Kingdom of Ireland through another Act of Union to become the United Kingdom of Great Britain and Ireland. In 1922 the Irish Free State seceded from the United Kingdom, leading to the latter being renamed the United Kingdom of Great Britain and Northern Ireland.\n\nToponymy\n\nThe name "England" is derived from the Old English name Englaland, which means "land of the Angles".  The Angles were one of the Germanic tribes that settled in Great Britain during the Early Middle Ages. The Angles came from the Angeln peninsula in the Bay of Kiel area of the Baltic Sea.  The earliest recorded use of the term, as "Engla londe", is in the late ninth century translation into Old English of Bede\'s Ecclesiastical History of the English People. The term was then used in a different sense to the modern one, meaning "the land inhabited by the English", and it included English people in what is now south-east Scotland but was then part of the English kingdom of Northumbria. The Anglo-Saxon Chronicle recorded that the Domesday Book of 1086 covered the whole of England, meaning the English kingdom, but a few years later the Chronicle stated that King Malcol ...
#    'Dame Judith Olivia "Judi" Dench,  (born 9 December 1934)  is an English actress and author.  Dench made her professional debut in 1957 with the Old Vic Company. Over the following few years she performed in several of Shakespeare\'s plays in such roles as Ophelia in Hamlet, Juliet in Romeo and Juliet and Lady Macbeth in Macbeth. Although most of her work during this period was in theatre, she also branched into film work, and won a BAFTA Award as Most Promising Newcomer. She drew strong reviews for her leading role in the musical Cabaret in 1968.\n\nOver the next two decades, Dench established herself as one of the most significant British theatre performers, working for the National Theatre Company and the Royal Shakespeare Company. She achieved success in television during this period, in the series A Fine Romance from 1981 until 1984, and in 1992 with a starring role in the romantic comedy series As Time Goes By. Her film appearances were infrequent and included supporting roles in major films such as A Room with a View (1986) supporting Maggie Smith, before she rose to international fame as M in GoldenEye (1995), a role she continued to play in James Bond films until Spectre (2015). She received her first Oscar nomination for Best Actress for her role as Queen Victoria in Mrs Brown (1997) and the following year won the Academy Award for Best Supporting Actress for Shakespeare in Love. A seven-time Oscar nominee, she has also received nominations for her roles in Chocolat (2000), Iris (2001), Mrs Henderson Presents (2005), Notes on a Scandal (2006), and Philomena (2013).\n\nDench has received many award nominations for her acting in theatre, film and television; her competitive awards include six British Academy Film Awards, four BAFTA TV Awards, seven Olivier Awards, two Screen Actors Guild Awards, two Golden Globes, an Academy Award, and a Tony Award. She has also received the BAFTA Fellowship (2001) and the Special Olivier Award (2004). In June 2011, she received a fellowship from the British Film Institute (BFI).  Dench is also a Fellow of the Royal Society of Arts (FRSA).\n\nEarly life\n\nDench was born in Heworth, North Riding of Yorkshire. Her mother, Eleanora Olive (née Jones), was born in Dublin. Her father, Reginald Arthur Dench, a doctor, was born in Dorset, and later moved to Dublin, where he was raised.   He met Dench\'s mother while he was studying medicine at Trinity College, Dublin.  \n\nDench attended The Mount School, a Quaker independent secondary school in York, and became a Quaker.   Her brothers, one of whom was actor Jeffery Dench, were born in Tyldesley, Lancashire. Her niece, Emma Dench, is a Roman historian and professor previously at Birkbeck, University of London, and currently at Harvard University. \n\nCareer\n\nIn Britain, Dench has developed a reputation as one of the greatest actresses of the post-war period, primarily through her work in theatre, which has been her forte throughout her career. She has more than once been named number one in polls for Britain\'s best actor.\n\nEarly years\n\nThrough her parents, Dench had regular contact with the theatre. Her father, a physician, was also the GP for the York theatre, and her mother was its wardrobe mistress.  Actors often stayed in the Dench household. During these years, Judi Dench was involved on a non-professional basis in the first three productions of the modern revival of the York Mystery Plays in the 1950s. In 1957, in one of the last productions in which she appeared during this period, she played the role of the Virgin Mary, performed on a fixed stage in the Museum Gardens. Though she initially trained as a set designer, she became interested in drama school as her brother Jeff attended the Central School of Speech and Drama. She applied and was accepted, where she was a classmate of Vanessa Redgrave, graduating with a first class degree in drama and four acting prizes, one being the Gold Medal as Outstanding Student.\n\nIn Sept ...
#  'search_results': {'description': [],
#   'filename': [],
#   'rank': [],
#   'title': [],
#   'url': [],
#   'search_context': []},
#  'answer': {'aliases': ['Park Grove (1895)',
#    'York UA',
#    'Yorkish',
#    'UN/LOCODE:GBYRK',
#    'York, UK',
#    'Eoforwic',
#    'Park Grove School',
#    'York Ham',
#    'The weather in York',
#    'City of York',
#    'York, England',
#    'York, Yorkshire',
#    'York ham',
#    'County Borough of York',
#    'YORK',
#    'Eoferwic',
#    'Park Grove Primary School',
#    'York, North Yorkshire',
#    'Yoisk',
#    'York',
#    'York (England)'],
#   'normalized_aliases': ['york yorkshire',
#    'eoferwic',
#    'park grove primary school',
#    'park grove school',
#    'weather in york',
#    'park grove 1895',
#    'eoforwic',
#    'county borough of york',
#    'york uk',
#    'un locode gbyrk',
#    'city of york',
#    'york england',
#    'york ua',
#    'york ham',
#    'york',
#    'yorkish',
#    'yoisk',
#    'york north yorkshire'],
#   'matched_wiki_entity_name': '',
#   'normalized_matched_wiki_entity_name': '',
#   'normalized_value': 'york',
#   'type': 'WikipediaEntity',
#   'value': 'York'}}
